# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/spacetime_gaussians5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/oppo-us-research/SpacetimeGaussians.git --recursive
# Out:
# Cloning into 'SpacetimeGaussians'...
# remote: Enumerating objects: 2854, done.
# remote: Counting objects: 100% (942/942), done.
# remote: Compressing objects: 100% (273/273), done.
# remote: Total 2854 (delta 765), reused 669 (delta 669), pack-reused 1912 (from 2)
# Receiving objects: 100% (2854/2854), 43.51 MiB | 34.65 MiB/s, done.
# Resolving deltas: 100% (1831/1831), done.
# Submodule 'thirdparty/mmcv' (https://github.com/open-mmlab/mmcv.git) registered for path 'thirdparty/mmcv'
# Cloning into '/content/SpacetimeGaussians/thirdparty/mmcv'...
# remote: Enumerating objects: 17575, done.
# remote: Counting objects: 100% (511/511), done.
# remote: Compressing objects: 100% (346/346), done.
# remote: Total 17575 (delta 357), reused 165 (delta 165), pack-reused 17064 (from 2)
# Receiving objects: 100% (17575/17575), 14.41 MiB | 19.39 MiB/s, done.
# Resolving deltas: 100% (12834/12834), done.
# Submodule path 'thirdparty/mmcv': checked out '3ba02dfd35c326306346bd9d35a887efc2b30fb0'

# %%
import os
os.chdir('SpacetimeGaussians')

# %%
print('fixed scripts [setup, pre_colmap, pren3d, helper3dg] uploaded manually')
# Out:
# fixed scripts [setup, pre_colmap, pren3d, helper3dg] uploaded manually

# %%
#########################################################################

# %%
#########################################################################

# %%
#########################################################################

# %%
#use setup_fixed1.sh
# !bash script/setup_fixed1.sh
# Out:
# --- 0. 既存環境のクリーンアップとConda初期化 ---
# script/setup_fixed1.sh: line 17: conda: command not found
# script/setup_fixed1.sh: line 18: conda: command not found
# script/setup_fixed1.sh: line 27: conda: command not found
# --- 1. feature_splatting 環境の作成 (Python 3.10) ---
# script/setup_fixed1.sh: line 38: conda: command not found

# %%
# !pip install opencv-python
# !pip install torch

# %%
# !apt-get update
# !apt-get install -y colmap
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,488 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,596 kB]
# ...

# %%
# !pip install ninja
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install mmcv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.1/479.1 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 27.6 MB/s eta 0:00:00
# ...
#   Created wheel for mmcv: filename=mmcv-2.2.0-cp312-cp312-linux_x86_64.whl size=40897643 sha256=9ffd13f511ed246851a8d3fb47e58251d15fac8bab5cb122291deb963ff2ba8d
#   Stored in directory: /root/.cache/pip/wheels/c7/bf/8d/f3122496099a7c3bf81da99fc6a800e6abe3971f65dce706c0
# Successfully built mmcv
# ...

# %%
# !pip install git+https://github.com/camenduru/simple-knn.git
# Out:
# ...
#   Cloning https://github.com/camenduru/simple-knn.git to /tmp/pip-req-build-mh1rgl_w
#   Running command git clone --filter=blob:none --quiet https://github.com/camenduru/simple-knn.git /tmp/pip-req-build-mh1rgl_w
#   Resolved https://github.com/camenduru/simple-knn.git to commit 60f461f4a56b7967e5d8045bf92f8c33f36976d0
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for simple_knn: filename=simple_knn-1.0.0-cp312-cp312-linux_x86_64.whl size=3510983 sha256=cfdf7c2939fb183a169df8d453f948687b126a545f1c3b7ae1205e1d95796572
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ynlkuw6c/wheels/5f/07/7a/3f06977508979b017ee180047dc42897847707cae601d30a54
# Successfully built simple_knn
# ...

# %%
# !pip install kornia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 45.3 MB/s eta 0:00:00
# ...

# %%
# !pip install thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch3
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch3
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization_ch3: filename=diff_gaussian_rasterization_ch3-0.0.0-cp312-cp312-linux_x86_64.whl size=3730054 sha256=6ae427cf2bee94bcbd33f3154547bc94714c6627a271777f794c2f36ecca4050
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6ywiixoy/wheels/84/a6/3a/89e7c9709aa2def67d69a39634c757e662101b0229b8340763
# Successfully built diff_gaussian_rasterization_ch3
# ...

# %%
# !pip install thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch9
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch9
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization_ch9: filename=diff_gaussian_rasterization_ch9-0.0.0-cp312-cp312-linux_x86_64.whl size=3732274 sha256=8808b97266dc01bf78c44a266fb7c2172d472bdbf7901cc14bccd8a03e1f87ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-isv_c9kq/wheels/eb/ae/46/9f5ab43b95b1c6a8435b1b623732dccec9a98f4eccac4b940d
# Successfully built diff_gaussian_rasterization_ch9
# ...

# %%
# !pip install thirdparty/gaussian_splatting/submodules/forward_lite
#pip install thirdparty/gaussian_splatting/submodules/forward_full
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/forward_lite
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for forward_lite: filename=forward_lite-0.0.0-cp312-cp312-linux_x86_64.whl size=3750197 sha256=689dc44e20e850f4a3556b4b86a616ce679d0777891497cd63033721a2481e85
#   Stored in directory: /tmp/pip-ephem-wheel-cache-92zmr5uk/wheels/bf/24/6d/966f6e962e2d05ca5b8f214357efa97093d355628b9a8c6e3b
# Successfully built forward_lite
# ...

# %%
# !pip install plyfile

# %%
# !sudo apt-get install -y \
    libgl1-mesa-glx \
    libgl1-mesa-dri \
    mesa-utils \
    libegl1-mesa \
    libgbm1
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# mesa-utils is already the newest version (8.4.0-1ubuntu1).
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgl1-mesa-dri is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libegl1-mesa is already the newest version (23.0.4-0ubuntu1~22.04.1).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 54 not upgraded.

# %%
# !apt-get install -y xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 54 not upgraded.

# %%
# !python -c "import numpy as np; print(f'NumPy version: {np.__version__}')"
# !sed -i 's/np\.NaN/np.nan/g' /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap.py
# !grep "np\.nan" /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap.py | head -n 5

# !sed -i 's/np\.NaN/np.nan/g' /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap_fixed1.py
# !grep "np\.nan" /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap_fixed1.py | head -n 5
# Out:
# NumPy version: 2.0.2
#                   prior_q=np.full(4, np.nan), prior_t=np.full(3, np.nan), image_id=None):
#                 prior_q=np.full(4, np.nan), prior_t=np.full(3, np.nan), image_id=None):

# %%
print('all libraries installed')
# Out:
# all libraries installed

# %%
#########################################################################

# %%
#########################################################################

# %%
#########################################################################

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
SOURCE_PATH='/content/drive/MyDrive/your_folder/coffee_martini'
DEST_PATH='/content/SpacetimeGaussians/source'
shutil.copytree(SOURCE_PATH, DEST_PATH, dirs_exist_ok=True)
# Out:
# '/content/SpacetimeGaussians/source'

# %%
import os

os.environ['QT_QPA_PLATFORM'] = 'offscreen'
os.environ['QT_QPA_PLATFORM_PLUGIN_PATH'] = ''
os.environ['QT_PLUGIN_PATH'] = ''
os.environ['LIBGL_ALWAYS_SOFTWARE'] = '1'

os.environ['QT_DEBUG_PLUGINS'] = '0'

# %%
# !xvfb-run -a -s "-screen 0 1280x1024x24" python script/pre_n3d_fixed1.py --videopath source --startframe 0 --endframe 50
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#
# ...
# Bundle adjustment
# ...
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.737694e+02    0.00e+00    4.99e+02   0.00e+00   0.00e+00  1.00e+04        0    3.80e-04    7.48e-04
#    1  2.516202e+02    2.21e+01    3.09e+00   3.08e-01   1.00e+00  3.00e+04        0    5.60e-04    2.64e-03
#    2  2.516179e+02    2.29e-03    1.24e-03   4.68e-03   1.00e+00  9.00e+04        0    5.52e-04    3.78e-03
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 974
#    Parameters : 495
#    Iterations : 3
#          Time : 0.0043931 [s]
#  Initial cost : 0.530167 [px]
#    Final cost : 0.508266 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000000
#
# ...
# Extracting colors
# ...
#
# ...

# %%
# !ls source/colmap_0/sparse/0/
# Out:
# cameras.bin  images.bin  points3D.bin

# %%
print('colmap worked successfully')
# Out:
# colmap worked successfully

# %%
#########################################################################

# %%
#########################################################################

# %%
#########################################################################

# %%
# !python train.py --quiet --eval --config configs/n3d_lite/coffee_martini.json --model_path ./output --source_path ./source/colmap_0
# Out:
# Overriding from config: configs/n3d_lite/coffee_martini.json
# Unknown config key 'test_iteration', skipping.
# Finished loading config.
# ...

# %%
# !python test.py --quiet --eval --skip_train --valloader colmapvalid --configpath configs/n3d_lite/coffee_martini.json --model_path ./output --source_path source/colmap_0
# Out:
# Looking for config file in ./output/cfg_args
# Config file found: ./output/cfg_args
# Rendering ./output
# Rendering and metric progress:   0% 0/50 [00:00<?, ?it/s]
#   0% 0.00/233M [00:00<?, ?B/s]
#   8% 17.8M/233M [00:00<00:01, 186MB/s]
#  17% 38.5M/233M [00:00<00:01, 204MB/s]
#  26% 59.5M/233M [00:00<00:00, 211MB/s]
#  34% 79.6M/233M [00:00<00:00, 210MB/s]
#  43% 99.8M/233M [00:00<00:00, 190MB/s]
#  51% 119M/233M [00:00<00:00, 193MB/s]
#  59% 137M/233M [00:00<00:00, 186MB/s]
#  67% 156M/233M [00:00<00:00, 189MB/s]
#  75% 175M/233M [00:00<00:00, 192MB/s]
#  83% 194M/233M [00:01<00:00, 192MB/s]
#  91% 213M/233M [00:01<00:00, 195MB/s]
# 100% 233M/233M [00:01<00:00, 194MB/s]
#
# 100% 5.87k/5.87k [00:00<00:00, 17.7MB/s]
#
#   0% 0.00/528M [00:00<?, ?B/s]
#   2% 12.2M/528M [00:00<00:04, 128MB/s]
#   6% 30.8M/528M [00:00<00:03, 166MB/s]
#   9% 49.1M/528M [00:00<00:02, 178MB/s]
#  13% 67.2M/528M [00:00<00:02, 183MB/s]
#  16% 84.8M/528M [00:00<00:02, 182MB/s]
# ...

# %%
#########################################################################
