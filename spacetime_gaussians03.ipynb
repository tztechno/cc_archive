# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/spacetime_gaussians3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !git clone https://github.com/oppo-us-research/SpacetimeGaussians.git --recursive
# Out:
# fatal: destination path 'SpacetimeGaussians' already exists and is not an empty directory.

# %%
import os
os.chdir('SpacetimeGaussians')

# %%
#use setup_fixed1.sh
# !bash script/setup_fixed1.sh
# Out:
# --- 0. 既存環境のクリーンアップとConda初期化 ---
#
# Remove all packages in environment /usr/local/envs/feature_splatting:
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/feature_splatting
#
#
# The following packages will be REMOVED:
#
#   _libgcc_mutex-0.1-conda_forge
#   _openmp_mutex-4.5-2_gnu
#   bzip2-1.0.8-hda65f42_8
#   ca-certificates-2025.11.12-hbd8a1cb_0
#   icu-75.1-he02047a_0
#   ld_impl_linux-64-2.45-default_hbd61a6d_104
#   libexpat-2.7.3-hecca717_0
#   libffi-3.5.2-h9ec8514_0
#   libgcc-15.2.0-he0feb66_12
#   libgcc-ng-15.2.0-h69a702a_12
#   libgomp-15.2.0-he0feb66_12
#   liblzma-5.8.1-hb9d3cd8_2
#   libnsl-2.0.1-hb9d3cd8_1
#   libsqlite-3.51.0-hee844dc_0
#   libstdcxx-15.2.0-h934c35e_12
#   libstdcxx-ng-15.2.0-hdf11a46_12
#   libuuid-2.41.2-he9a06e4_0
#   libxcrypt-4.4.36-hd590300_1
#   libzlib-1.3.1-hb9d3cd8_2
#   ncurses-6.5-h2d0b736_3
#   openssl-3.6.0-h26f9b46_0
#   pip-25.3-pyh8b19718_0
#   python-3.10.19-h3c07f61_2_cpython
#   readline-8.2-h8c095d6_2
# ...

# %%
# !python -c "import numpy as np; print(f'NumPy version: {np.__version__}')"
# !sed -i 's/np\.NaN/np.nan/g' /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap.py
# !grep "np\.nan" /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap.py | head -n 5
# Out:
# NumPy version: 2.2.6
#                 prior_q=np.full(4, np.nan), prior_t=np.full(3, np.nan), image_id=None):

# %%
# !pip install torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
SOURCE_PATH='/content/drive/MyDrive/your_folder/coffee_martini'
DEST_PATH='/content/SpacetimeGaussians/source'
shutil.copytree(SOURCE_PATH, DEST_PATH, dirs_exist_ok=True)
# Out:
# '/content/SpacetimeGaussians/source'

# %%
# !apt-get update
# !apt-get install -y colmap
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !cd /content/SpacetimeGaussians && QT_QPA_PLATFORM=offscreen DISPLAY= python script/pre_n3d.py --videopath source --startframe 0 --endframe 50
