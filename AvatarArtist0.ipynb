# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/AvatarArtist0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tztechno/AvaterArtist.git
# Out:
# Cloning into 'AvaterArtist'...
# remote: Enumerating objects: 12495, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 12495 (delta 2), reused 6 (delta 1), pack-reused 12488 (from 2)
# Receiving objects: 100% (12495/12495), 1.12 GiB | 38.06 MiB/s, done.
# Resolving deltas: 100% (2565/2565), done.
# Updating files: 100% (11938/11938), done.

# %%
import os
os.chdir('AvaterArtist')

# %%
# 絶対パスを直接指定
mmcv_path = '/content/AvatarArtist/thirdparty'

# パスが存在するか確認してから追加
if os.path.isdir(mmcv_path):
    # sys.pathの先頭にパスを追加
    sys.path.insert(0, mmcv_path)
    print(f"✅ パス '{mmcv_path}' を sys.path に追加しました。")

    # 動作確認（この後にMMCVのimportを試みてください）
    try:
        import mmcv
        print(f"✅ MMCVのインポートに成功しました。パス: {mmcv.__file__}")
    except ImportError:
        print("❌ MMCVのインポートに失敗しました。thirdpartyフォルダ内にMMCVがあるか確認してください。")

else:
    print(f"❌ エラー: 指定されたパス '{mmcv_path}' が見つかりません。")
# Out:
# ❌ エラー: 指定されたパス '/content/AvatarArtist/thirdparty' が見つかりません。

# %%
# !apt-get update
# !apt-get install -y python3.9 python3.9-distutils
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 1
# !update-alternatives --config python3
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 129 kB in 1s (118 kB/s)
# Reading package lists... Done
# ...

# %%
# !python3.9 -c "import sys; print(sys.version)"
# Out:
# 3.9.25 (main, Nov  7 2025, 18:07:57)
# [GCC 11.4.0]

# %%
# !python --version
# Out:
# Python 3.9.25

# %%
# !apt install python3-pip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   javascript-common libjs-sphinxdoc libjs-underscore libpython3.10
#   libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib python3-dev
#   python3-pkg-resources python3-setuptools python3-wheel python3.10
#   python3.10-dev python3.10-minimal
# Suggested packages:
#   apache2 | lighttpd | httpd python-setuptools-doc python3.10-venv
#   python3.10-doc binfmt-support
# The following NEW packages will be installed:
#   javascript-common libjs-sphinxdoc libjs-underscore python3-dev python3-pip
#   python3-setuptools python3-wheel python3.10-dev
# The following packages will be upgraded:
#   libpython3.10 libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib
#   python3-pkg-resources python3.10 python3.10-minimal
# 7 upgraded, 8 newly installed, 0 to remove and 51 not upgraded.
# Need to get 15.0 MB of archives.
# ...

# %%
# PyTorch & torchvision (CUDA 12.1対応)
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121

# PyTorch3Dをソースからビルド
# !pip install "git+https://github.com/facebookresearch/pytorch3d.git@stable"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 4, in <module>
#     from pip._internal.cli.main import main
# ModuleNotFoundError: No module named 'pip'
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 4, in <module>
#     from pip._internal.cli.main import main
# ModuleNotFoundError: No module named 'pip'

# %%
# 残りをまとめてインストール
# !pip install -r requirements_colab.txt
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 4, in <module>
#     from pip._internal.cli.main import main
# ModuleNotFoundError: No module named 'pip'

# %%
# !python3 app.py
# Out:
# Traceback (most recent call last):
#   File "/content/AvaterArtist/AvaterArtist/app.py", line 10, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'
