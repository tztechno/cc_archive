# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/spacetime_gaussians09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
############ 20251129 00:48 #### coffee martini 10 frames #####################

# %%
# !git clone https://github.com/tztechno/SpacetimeGaussians.git --recursive
# Out:
# Cloning into 'SpacetimeGaussians'...
# remote: Enumerating objects: 2976, done.
# remote: Counting objects: 100% (972/972), done.
# remote: Compressing objects: 100% (303/303), done.
# remote: Total 2976 (delta 779), reused 669 (delta 669), pack-reused 2004 (from 3)
# Receiving objects: 100% (2976/2976), 43.56 MiB | 15.50 MiB/s, done.
# Resolving deltas: 100% (1898/1898), done.
# Submodule 'thirdparty/mmcv' (https://github.com/open-mmlab/mmcv.git) registered for path 'thirdparty/mmcv'
# Cloning into '/content/SpacetimeGaussians/thirdparty/mmcv'...
# remote: Enumerating objects: 17575, done.
# remote: Counting objects: 100% (508/508), done.
# remote: Compressing objects: 100% (344/344), done.
# remote: Total 17575 (delta 356), reused 164 (delta 164), pack-reused 17067 (from 2)
# Receiving objects: 100% (17575/17575), 14.49 MiB | 9.31 MiB/s, done.
# Resolving deltas: 100% (12796/12796), done.
# Submodule path 'thirdparty/mmcv': checked out '3ba02dfd35c326306346bd9d35a887efc2b30fb0'

# %%
import os
os.chdir('SpacetimeGaussians')

# %%
#use setup_fixed1.sh
# !bash script/setup_fixed5.sh
# Out:
# === Kaggle環境セットアップ開始 ===
# プロジェクトルート: /content/SpacetimeGaussians
# --- 1. システムパッケージの更新 ---
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
print('all libraries installed')
# Out:
# all libraries installed

# %%
########################load data#################################################

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
SOURCE_PATH='/content/drive/MyDrive/your_folder/coffee_martini_10'
DEST_PATH='/content/SpacetimeGaussians/source'
shutil.copytree(SOURCE_PATH, DEST_PATH, dirs_exist_ok=True)
# Out:
# '/content/SpacetimeGaussians/source'

# %%
###################process data######################################################

# %%
import os
os.environ['QT_QPA_PLATFORM'] = 'offscreen'
os.environ['LIBGL_ALWAYS_SOFTWARE'] = '1'

# %%
# !xvfb-run -a -s "-screen 0 1280x1024x24" python script/pre_n3d_fixed1.py --videopath source --startframe 0 --endframe 10
# Out:
# params: startframe=0 - endframe=10 - downscale=1 - videopath=source
# start extracting 300 frames from videos
# Extract frames from videos: 100% 10/10 [14:46<00:00, 88.68s/it]
# start preparing colmap image input
# start preparing colmap database input
# convertdynerftocolmapdb: 100% 10/10 [00:01<00:00,  6.38it/s]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ...
# Feature extraction
# ...
#
# Processed file [1/10]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4330
# Processed file [2/10]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.097, LON=1.144, ALT=2.128
#   Features:        4216
# Processed file [3/10]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
# ...

# %%
# !ls source/colmap_0/sparse/0/
# Out:
# cameras.bin  images.bin  points3D.bin

# %%
print('colmap worked successfully')
# Out:
# colmap worked successfully

# %%
#######################################################################

# %%
# !python train.py --quiet --eval --config configs/n3d_lite/coffee_martini.json --model_path ./output --source_path ./source/colmap_0
# Out:
# Overriding from config: configs/n3d_lite/coffee_martini.json
# Unknown config key 'test_iteration', skipping.
# Finished loading config.
# ...

# %%
# !python test_fixed2.py --quiet --eval --skip_train --valloader colmapvalid --configpath configs/n3d_lite/coffee_martini.json --model_path ./output --source_path source/colmap_0

# %%
#########################################################################
