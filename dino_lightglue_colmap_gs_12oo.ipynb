# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/dino_lightglue_colmap_gs_12oo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **dino-lightglue-colmap-gs-11**
# 2026/01/10

# %% [markdown]
# # **setup**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
import subprocess
from PIL import Image

def run_cmd(cmd, check=True, capture=False):
    """Run command with better error handling"""
    print(f"Running: {' '.join(cmd)}")
    result = subprocess.run(
        cmd,
        capture_output=capture,
        text=True,
        check=False
    )
    if check and result.returncode != 0:
        print(f"❌ Command failed with code {result.returncode}")
        if capture:
            print(f"STDOUT: {result.stdout}")
            print(f"STDERR: {result.stderr}")
    return result

def setup_environment():
    """
    Colab environment setup for Gaussian Splatting + LightGlue + pycolmap
    Python 3.12 compatible version (v8)
    """

    print("🚀 Setting up COLAB environment (v8 - Python 3.12 compatible)")

    WORK_DIR = "/content/gaussian-splatting"

    # =====================================================================
    # STEP 0: NumPy FIX (Python 3.12 compatible)
    # =====================================================================
    print("\n" + "="*70)
    print("STEP 0: Fix NumPy (Python 3.12 compatible)")
    print("="*70)

    # Python 3.12 requires numpy >= 1.26
    run_cmd([sys.executable, "-m", "pip", "uninstall", "-y", "numpy"])
    run_cmd([sys.executable, "-m", "pip", "install", "numpy==1.26.4"])

    # sanity check
    run_cmd([sys.executable, "-c", "import numpy; print('NumPy:', numpy.__version__)"])

    # =====================================================================
    # STEP 1: System packages (Colab)
    # =====================================================================
    print("\n" + "="*70)
    print("STEP 1: System packages")
    print("="*70)

    run_cmd(["apt-get", "update", "-qq"])
    run_cmd([
        "apt-get", "install", "-y", "-qq",
        "colmap",
        "build-essential",
        "cmake",
        "git",
        "libopenblas-dev",
        "xvfb"
    ])

    # virtual display (COLMAP / OpenCV safety)
    os.environ["QT_QPA_PLATFORM"] = "offscreen"
    os.environ["DISPLAY"] = ":99"
    subprocess.Popen(
        ["Xvfb", ":99", "-screen", "0", "1024x768x24"],
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL
    )

    # =====================================================================
    # STEP 2: Clone Gaussian Splatting
    # =====================================================================
    print("\n" + "="*70)
    print("STEP 2: Clone Gaussian Splatting")
    print("="*70)

    if not os.path.exists(WORK_DIR):
        run_cmd([
            "git", "clone", "--recursive",
            "https://github.com/graphdeco-inria/gaussian-splatting.git",
            WORK_DIR
        ])
    else:
        print("✓ Repository already exists")

    # =====================================================================
    # STEP 3: Python packages (FIXED ORDER & VERSIONS)
    # =====================================================================
    print("\n" + "="*70)
    print("STEP 3: Python packages (VERBOSE MODE)")
    print("="*70)

    # ---- PyTorch (Colab CUDA対応) ----
    print("\n📦 Installing PyTorch...")
    run_cmd([
        sys.executable, "-m", "pip", "install",
        "torch", "torchvision", "torchaudio"
    ])

    # ---- Core utils ----
    print("\n📦 Installing core utilities...")
    run_cmd([
        sys.executable, "-m", "pip", "install",
        "opencv-python",
        "pillow",
        "imageio",
        "imageio-ffmpeg",
        "plyfile",
        "tqdm",
        "tensorboard"
    ])

    # ---- transformers (NumPy 1.26 compatible) ----
    print("\n📦 Installing transformers (NumPy 1.26 compatible)...")
    # Install transformers with proper dependencies
    run_cmd([
        sys.executable, "-m", "pip", "install",
        "transformers==4.40.0"
    ])

    # ---- LightGlue stack (GITHUB INSTALL) ----
    print("\n📦 Installing LightGlue stack...")

    # Install kornia first
    run_cmd([sys.executable, "-m", "pip", "install", "kornia"])

    # Install h5py (sometimes needed)
    run_cmd([sys.executable, "-m", "pip", "install", "h5py"])

    # Install matplotlib (LightGlue dependency)
    run_cmd([sys.executable, "-m", "pip", "install", "matplotlib"])

    # Install LightGlue directly from GitHub (more reliable)
    print("  Installing LightGlue from GitHub...")
    run_cmd([sys.executable, "-m", "pip", "install",
            "git+https://github.com/cvg/LightGlue.git"])

    # Install pycolmap
    run_cmd([sys.executable, "-m", "pip", "install", "pycolmap"])

    # =====================================================================
    # STEP 4: Build GS submodules
    # =====================================================================
    print("\n" + "="*70)
    print("STEP 4: Build Gaussian Splatting submodules")
    print("="*70)

    submodules = {
        "diff-gaussian-rasterization":
            "https://github.com/graphdeco-inria/diff-gaussian-rasterization.git",
        "simple-knn":
            "https://github.com/camenduru/simple-knn.git"
    }

    for name, repo in submodules.items():
        print(f"\n📦 Installing {name}...")
        path = os.path.join(WORK_DIR, "submodules", name)
        if not os.path.exists(path):
            run_cmd(["git", "clone", repo, path])
        run_cmd([sys.executable, "-m", "pip", "install", path])

    # =====================================================================
    # STEP 5: Detailed Verification
    # =====================================================================
    print("\n" + "="*70)
    print("STEP 5: Detailed Verification")
    print("="*70)

    # NumPy (verify version first)
    print("\n🔍 Testing NumPy...")
    try:
        import numpy as np
        print(f"  ✓ NumPy: {np.__version__}")
    except Exception as e:
        print(f"  ❌ NumPy failed: {e}")

    # PyTorch
    print("\n🔍 Testing PyTorch...")
    try:
        import torch
        print(f"  ✓ PyTorch: {torch.__version__}")
        print(f"  ✓ CUDA available: {torch.cuda.is_available()}")
        if torch.cuda.is_available():
            print(f"  ✓ CUDA version: {torch.version.cuda}")
    except Exception as e:
        print(f"  ❌ PyTorch failed: {e}")

    # transformers
    print("\n🔍 Testing transformers...")
    try:
        import transformers
        print(f"  ✓ transformers version: {transformers.__version__}")
        from transformers import AutoModel
        print(f"  ✓ AutoModel import: OK")
    except Exception as e:
        print(f"  ❌ transformers failed: {e}")
        print(f"  Attempting detailed diagnosis...")
        result = run_cmd([
            sys.executable, "-c",
            "import transformers; print(transformers.__version__)"
        ], capture=True)
        print(f"  Output: {result.stdout}")
        print(f"  Error: {result.stderr}")

    # LightGlue
    print("\n🔍 Testing LightGlue...")
    try:
        from lightglue import LightGlue, ALIKED
        print(f"  ✓ LightGlue: OK")
        print(f"  ✓ ALIKED: OK")
    except Exception as e:
        print(f"  ❌ LightGlue failed: {e}")
        print(f"  Attempting detailed diagnosis...")
        result = run_cmd([
            sys.executable, "-c",
            "from lightglue import LightGlue"
        ], capture=True)
        print(f"  Output: {result.stdout}")
        print(f"  Error: {result.stderr}")

    # pycolmap
    print("\n🔍 Testing pycolmap...")
    try:
        import pycolmap
        print(f"  ✓ pycolmap: OK")
    except Exception as e:
        print(f"  ❌ pycolmap failed: {e}")

    # kornia
    print("\n🔍 Testing kornia...")
    try:
        import kornia
        print(f"  ✓ kornia: {kornia.__version__}")
    except Exception as e:
        print(f"  ❌ kornia failed: {e}")

    print("\n" + "="*70)
    print("✅ SETUP COMPLETE")
    print("="*70)
    print(f"Working dir: {WORK_DIR}")

    return WORK_DIR


if __name__ == "__main__":
    setup_environment()
# Out:
# 🚀 Setting up COLAB environment (v8 - Python 3.12 compatible)
#
# ======================================================================
# STEP 0: Fix NumPy (Python 3.12 compatible)
# ======================================================================
# Running: /usr/bin/python3 -m pip uninstall -y numpy
# Running: /usr/bin/python3 -m pip install numpy==1.26.4
# Running: /usr/bin/python3 -c import numpy; print('NumPy:', numpy.__version__)
#
# ======================================================================
# STEP 1: System packages
# ======================================================================
# Running: apt-get update -qq
# Running: apt-get install -y -qq colmap build-essential cmake git libopenblas-dev xvfb
#
# ======================================================================
# STEP 2: Clone Gaussian Splatting
# ======================================================================
# Running: git clone --recursive https://github.com/graphdeco-inria/gaussian-splatting.git /content/gaussian-splatting
#
# ======================================================================
# STEP 3: Python packages (VERBOSE MODE)
# ======================================================================
#
# 📦 Installing PyTorch...
# Running: /usr/bin/python3 -m pip install torch torchvision torchaudio
#
# 📦 Installing core utilities...
# Running: /usr/bin/python3 -m pip install opencv-python pillow imageio imageio-ffmpeg plyfile tqdm tensorboard
#
# 📦 Installing transformers (NumPy 1.26 compatible)...
# Running: /usr/bin/python3 -m pip install transformers==4.40.0
#
# 📦 Installing LightGlue stack...
# Running: /usr/bin/python3 -m pip install kornia
# Running: /usr/bin/python3 -m pip install h5py
# Running: /usr/bin/python3 -m pip install matplotlib
#   Installing LightGlue from GitHub...
# Running: /usr/bin/python3 -m pip install git+https://github.com/cvg/LightGlue.git
# Running: /usr/bin/python3 -m pip install pycolmap
#
# ======================================================================
# STEP 4: Build Gaussian Splatting submodules
# ======================================================================
#
# 📦 Installing diff-gaussian-rasterization...
# Running: /usr/bin/python3 -m pip install /content/gaussian-splatting/submodules/diff-gaussian-rasterization
#
# 📦 Installing simple-knn...
# Running: /usr/bin/python3 -m pip install /content/gaussian-splatting/submodules/simple-knn
#
# ======================================================================
# STEP 5: Detailed Verification
# ======================================================================
#
# 🔍 Testing NumPy...
#   ✓ NumPy: 2.0.2
#
# 🔍 Testing PyTorch...
#   ✓ PyTorch: 2.9.0+cu126
#   ✓ CUDA available: True
#   ✓ CUDA version: 12.6
#
# 🔍 Testing transformers...
#   ✓ transformers version: 4.40.0
#   ✓ AutoModel import: OK
#
# 🔍 Testing LightGlue...
#   ✓ LightGlue: OK
#   ✓ ALIKED: OK
#
# 🔍 Testing pycolmap...
#   ✓ pycolmap: OK
#
# 🔍 Testing kornia...
#   ✓ kornia: 0.8.2
#
# ======================================================================
# ✅ SETUP COMPLETE
# ======================================================================
# Working dir: /content/gaussian-splatting

# %%
import os

# %cd /content/gaussian-splatting

files = ['database.py', 'h5_to_db.py', 'metric.py']
base_url = 'https://huggingface.co/stpete2/imc25_utils/resolve/main/'

for file in files:
    if not os.path.exists(file):
        # !wget -q {base_url + file}
        print(f"✓ {file} download complete")
    else:
        print(f"✓ {file} already exists")
# Out:
# /content/gaussian-splatting
# ✓ database.py download complete
# ✓ h5_to_db.py download complete
# ✓ metric.py download complete

# %% [markdown]
# # **install libraries**

# %%
from database import COLMAPDatabase, image_ids_to_pair_id
from h5_to_db import add_keypoints, add_matches
from metric import *

# %%
"""
Gaussian Splatting Pipeline
Simple and robust pipeline: LightGlue → COLMAP → Gaussian Splatting
"""

import os
import sys
import gc
import h5py
import numpy as np
import torch
import torch.nn.functional as F
from tqdm import tqdm
from pathlib import Path
import subprocess

# LightGlue
from lightglue import ALIKED, LightGlue
from lightglue.utils import load_image

# Transformers for DINO
from transformers import AutoImageProcessor, AutoModel


# ============================================================================
# Configuration
# ============================================================================
class Config:
    # Feature extraction
    N_KEYPOINTS = 8192
    IMAGE_SIZE = 1024

    # Pair selection
    GLOBAL_TOPK = 200
    MIN_MATCHES = 10
    RATIO_THR = 1.2

    # Paths
    DINO_MODEL = "facebook/dinov2-base"  # Change if using local path

    # Device
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# ============================================================================
# Step 0: images_square
# ============================================================================

def preprocess_images_square(input_dir, output_dir, size=1024, background='black'):
    """
    Standardize all images to a square format (maintaining aspect ratio with padding).

    Args:
        input_dir (str): Directory containing input images.
        output_dir (str): Directory to save processed images.
        size (int): Target square dimension (default: 1024).
        background (str): Background style: 'black', 'white', or 'blur'.
    """
    from PIL import Image, ImageFilter
    import os
    from tqdm import tqdm

    print(f"\n=== Preprocessing to {size}x{size} Square Images ===")

    os.makedirs(output_dir, exist_ok=True)

    image_files = sorted([
        f for f in os.listdir(input_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ])

    stats = {
        'total': len(image_files),
        'landscape': 0,
        'portrait': 0,
        'square': 0,
        'resized': 0,
    }

    for img_file in tqdm(image_files, desc="Converting to square"):
        img_path = os.path.join(input_dir, img_file)
        img = Image.open(img_path).convert('RGB')

        width, height = img.size

        # Statistics
        if width > height:
            stats['landscape'] += 1
        elif width < height:
            stats['portrait'] += 1
        else:
            stats['square'] += 1

        # Resize based on the longest side
        max_dim = max(width, height)
        if max_dim != size:
            scale = size / max_dim
            new_width = int(width * scale)
            new_height = int(height * scale)
            img = img.resize((new_width, new_height), Image.LANCZOS)
            stats['resized'] += 1
        else:
            new_width, new_height = width, height

        # Create background
        if background == 'black':
            canvas = Image.new('RGB', (size, size), (0, 0, 0))
        elif background == 'white':
            canvas = Image.new('RGB', (size, size), (255, 255, 255))
        elif background == 'blur':
            # Use a blurred version of the image as background for a professional look
            canvas = img.resize((size, size), Image.LANCZOS)
            canvas = canvas.filter(ImageFilter.GaussianBlur(radius=20))
        else:
            canvas = Image.new('RGB', (size, size), (0, 0, 0))

        # Center the image
        offset_x = (size - new_width) // 2
        offset_y = (size - new_height) // 2
        canvas.paste(img, (offset_x, offset_y))

        # Save output
        output_path = os.path.join(output_dir, img_file)
        canvas.save(output_path, quality=95, optimize=True)

    print(f"\n✓ Preprocessing complete:")
    print(f"  Total images: {stats['total']}")
    print(f"  Landscape: {stats['landscape']} / Portrait: {stats['portrait']} / Square: {stats['square']}")
    print(f"  Resized: {stats['resized']}")
    print(f"  Output size: {size}x{size}")

    return output_dir

# %%
def normalize_image_sizes_biplet(input_dir, output_dir=None, size=1024):
    """
    Generates two square crops (Left & Right or Top & Bottom)
    from each image in a directory.
    """
    if output_dir is None:
        output_dir = input_dir

    os.makedirs(output_dir, exist_ok=True)

    print(f"Generating 2 cropped squares (Left/Right or Top/Bottom) for each image...")
    print()

    converted_count = 0
    size_stats = {}

    for img_file in sorted(os.listdir(input_dir)):
        if not img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
            continue

        input_path = os.path.join(input_dir, img_file)

        try:
            img = Image.open(input_path)
            original_size = img.size

            size_key = f"{original_size[0]}x{original_size[1]}"
            size_stats[size_key] = size_stats.get(size_key, 0) + 1

            # Generate 2 crops
            crops = generate_two_crops(img, size)

            base_name, ext = os.path.splitext(img_file)
            for mode, cropped_img in crops.items():
                output_path = os.path.join(output_dir, f"{base_name}_{mode}{ext}")
                cropped_img.save(output_path, quality=95)

            converted_count += 1
            print(f"  ✓ {img_file}: {original_size} → 2 square images generated")

        except Exception as e:
            print(f"  ✗ Error processing {img_file}: {e}")

    print(f"\nProcessing complete: {converted_count} source images processed")
    print(f"Original size distribution: {size_stats}")
    return converted_count


def generate_two_crops(img, size):
    """
    Crops the image into a square and returns 2 variations
    (Left/Right for landscape, Top/Bottom for portrait).
    """
    width, height = img.size
    crop_size = min(width, height)
    crops = {}

    if width > height:
        # Landscape → Left & Right
        positions = {
            'left': 0,
            'right': width - crop_size
        }
        for mode, x_offset in positions.items():
            box = (x_offset, 0, x_offset + crop_size, crop_size)
            crops[mode] = img.crop(box).resize(
                (size, size),
                Image.Resampling.LANCZOS
            )

    else:
        # Portrait or Square → Top & Bottom
        positions = {
            'top': 0,
            'bottom': height - crop_size
        }
        for mode, y_offset in positions.items():
            box = (0, y_offset, crop_size, y_offset + crop_size)
            crops[mode] = img.crop(box).resize(
                (size, size),
                Image.Resampling.LANCZOS
            )

    return crops

# %%
# ============================================================================
# Step 1: Image Pair Selection (DINO + ALIKED local verify)
# ============================================================================

def load_torch_image(fname, device):
    """Load image as torch tensor"""
    from PIL import Image
    import torchvision.transforms as T

    img = Image.open(fname).convert('RGB')
    transform = T.Compose([
        T.ToTensor(),
    ])
    return transform(img).unsqueeze(0).to(device)

def extract_dino_global(image_paths, model_path, device):
    """Extract DINO global descriptors"""
    print("\n=== Extracting DINO Global Features ===")

    processor = AutoImageProcessor.from_pretrained(model_path)
    model = AutoModel.from_pretrained(model_path).eval().to(device)

    global_descs = []
    for img_path in tqdm(image_paths):
        img = load_torch_image(img_path, device)
        with torch.no_grad():
            inputs = processor(images=img, return_tensors="pt", do_rescale=False).to(device)
            outputs = model(**inputs)
            desc = F.normalize(outputs.last_hidden_state[:, 1:].max(dim=1)[0], dim=1, p=2)
            global_descs.append(desc.cpu())

    global_descs = torch.cat(global_descs, dim=0)

    del model
    torch.cuda.empty_cache()
    gc.collect()

    return global_descs

def build_topk_pairs(global_feats, k, device):
    """Build top-k similar pairs from global features"""
    g = global_feats.to(device)
    sim = g @ g.T
    sim.fill_diagonal_(-1)

    N = sim.size(0)
    k = min(k, N - 1)

    topk_indices = torch.topk(sim, k, dim=1).indices.cpu()

    pairs = []
    for i in range(N):
        for j in topk_indices[i]:
            j = j.item()
            if i < j:
                pairs.append((i, j))

    return list(set(pairs))

def extract_aliked_features(image_paths, device):
    """Extract ALIKED local features"""
    print("\n=== Extracting ALIKED Local Features ===")

    extractor = ALIKED(
        model_name="aliked-n16",
        max_num_keypoints=Config.N_KEYPOINTS,
        detection_threshold=0.01,
        resize=Config.IMAGE_SIZE
    ).eval().to(device)

    features = []
    for img_path in tqdm(image_paths):
        img = load_torch_image(img_path, device)
        with torch.no_grad():
            feats = extractor.extract(img)
            kpts = feats['keypoints'].reshape(-1, 2).cpu()
            descs = feats['descriptors'].reshape(len(kpts), -1).cpu()
            features.append({'keypoints': kpts, 'descriptors': descs})

    del extractor
    torch.cuda.empty_cache()
    gc.collect()

    return features

def verify_pairs_locally(pairs, features, device, threshold=Config.MIN_MATCHES):
    """Verify pairs using local descriptor matching"""
    print("\n=== Verifying Pairs with Local Features ===")

    verified = []
    for i, j in tqdm(pairs):
        desc1 = features[i]['descriptors'].to(device)
        desc2 = features[j]['descriptors'].to(device)

        if len(desc1) == 0 or len(desc2) == 0:
            continue

        # Simple mutual nearest neighbor
        dist = torch.cdist(desc1, desc2, p=2)
        min_dist = dist.min(dim=1)[0]
        n_matches = (min_dist < Config.RATIO_THR).sum().item()

        if n_matches >= threshold:
            verified.append((i, j))

    return verified

def get_image_pairs(image_paths):
    """Main pair selection pipeline"""
    device = Config.DEVICE

    # 1. DINO global
    global_feats = extract_dino_global(image_paths, Config.DINO_MODEL, device)
    pairs = build_topk_pairs(global_feats, Config.GLOBAL_TOPK, device)

    print(f"Initial pairs from global features: {len(pairs)}")

    # 2. ALIKED local
    features = extract_aliked_features(image_paths, device)

    # 3. Local verification
    verified_pairs = verify_pairs_locally(pairs, features, device)

    print(f"Verified pairs: {len(verified_pairs)}")

    return verified_pairs, features

# %%
# ============================================================================
# Step 2: Feature Matching (ALIKED + LightGlue)
# ============================================================================

def match_pairs_lightglue(image_paths, pairs, features, output_dir):
    """
    Match image pairs using LightGlue
    """
    print("\n=== Matching with LightGlue ===")

    os.makedirs(output_dir, exist_ok=True)
    keypoints_path = os.path.join(output_dir, 'keypoints.h5')
    matches_path = os.path.join(output_dir, 'matches.h5')

    if os.path.exists(keypoints_path):
        os.remove(keypoints_path)
    if os.path.exists(matches_path):
        os.remove(matches_path)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    extractor = ALIKED(max_num_keypoints=4096, detection_threshold=0.2, nms_radius=2).eval().to(device)
    matcher = LightGlue(features='aliked').eval().to(device)

    if isinstance(features, dict):
        all_keypoints = features['keypoints']
        all_descriptors = features['descriptors']
    elif isinstance(features, list):
        all_keypoints = [f['keypoints'] for f in features]
        all_descriptors = [f['descriptors'] for f in features]
    else:
        raise ValueError(f"Unsupported features type: {type(features)}")

    with h5py.File(keypoints_path, 'w') as f_kp:
        for idx, img_path in enumerate(tqdm(image_paths, desc="Saving keypoints")):
            img_name = os.path.splitext(os.path.basename(img_path))[0]

            kp = all_keypoints[idx]
            if torch.is_tensor(kp):
                kp = kp.cpu().numpy()
            f_kp.create_dataset(img_name, data=kp)

    # Match pairs
    with h5py.File(matches_path, 'w') as f_match:
        for idx1, idx2 in tqdm(pairs, desc="Matching"):
            with torch.no_grad():
                kp0 = all_keypoints[idx1]
                kp1 = all_keypoints[idx2]
                desc0 = all_descriptors[idx1]
                desc1 = all_descriptors[idx2]

                if isinstance(kp0, np.ndarray):
                    kp0 = torch.from_numpy(kp0).float().to(device)
                    kp1 = torch.from_numpy(kp1).float().to(device)
                    desc0 = torch.from_numpy(desc0).float().to(device)
                    desc1 = torch.from_numpy(desc1).float().to(device)
                else:
                    kp0 = kp0.float().to(device)
                    kp1 = kp1.float().to(device)
                    desc0 = desc0.float().to(device)
                    desc1 = desc1.float().to(device)

                feats0 = {
                    'keypoints': kp0.unsqueeze(0) if kp0.dim() == 2 else kp0,
                    'descriptors': desc0.unsqueeze(0) if desc0.dim() == 2 else desc0,
                }
                feats1 = {
                    'keypoints': kp1.unsqueeze(0) if kp1.dim() == 2 else kp1,
                    'descriptors': desc1.unsqueeze(0) if desc1.dim() == 2 else desc1,
                }

                matches01 = matcher({'image0': feats0, 'image1': feats1})

                if 'matches0' in matches01:
                    matches0 = matches01['matches0'].cpu().numpy()
                    if matches0.ndim > 1:
                        matches0 = matches0[0]
                    valid = matches0 > -1
                    matches = np.stack([np.where(valid)[0], matches0[valid]], axis=1)
                elif 'matches' in matches01:
                    m = matches01['matches']
                    if isinstance(m, list):
                        matches = np.array(m)
                    elif hasattr(m, 'cpu'):
                        matches = m.cpu().numpy()
                    else:
                        matches = np.array(m)
                else:
                    continue

                if len(matches) > 0:
                    img_name1 = os.path.splitext(os.path.basename(image_paths[idx1]))[0]
                    img_name2 = os.path.splitext(os.path.basename(image_paths[idx2]))[0]
                    pair_key = f"{img_name1}_{img_name2}"
                    f_match.create_dataset(pair_key, data=matches)

    print(f"✓ Matches saved to {matches_path}")

# %%
# ============================================================================
# Step 3: Import to COLMAP
# ============================================================================

def import_to_colmap(image_dir, feature_dir, database_path, single_camera=True):
    """
    Import features and matches to COLMAP database

    Args:
            image_dir (str): Directory containing the images.
            feature_dir (str): Directory to save/load extracted features.
            database_path (str): Path to the database file.
            single_camera (bool): Set to True if all images have the same dimensions (e.g., pre-resized).
    """
    print("\n=== Creating COLMAP Database ===")

    if os.path.exists(database_path):
        os.remove(database_path)
        print(f"✓ Removed existing database")

    db = COLMAPDatabase.connect(database_path)
    db.create_tables()

    print(f"Single camera mode: {single_camera}")

    image_files = [f for f in os.listdir(image_dir)
                   if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if not image_files:
        raise ValueError(f"No images found in {image_dir}")

    first_image = sorted(image_files)[0]
    img_ext = os.path.splitext(first_image)[1]
    print(f"Detected image extension: '{img_ext}'")

    fname_to_id = add_keypoints(
        db,
        feature_dir,
        image_dir,
        img_ext,
        'PINHOLE',
        single_camera=single_camera
    )

    add_matches(db, feature_dir, fname_to_id)
    db.commit()
    db.close()

    print(f"✓ Database created: {database_path}")

# ============================================================================
# Step 4: Run COLMAP Mapper
# ============================================================================

def run_colmap_mapper(database_path, image_dir, output_dir):
    """
    Run COLMAP mapper with verbose output
    """
    print("\n=== Running COLMAP Reconstruction ===")
    os.makedirs(output_dir, exist_ok=True)
    cmd = [
        'colmap', 'mapper',
        '--database_path', database_path,
        '--image_path', image_dir,
        '--output_path', output_dir,
        '--Mapper.ba_refine_focal_length', '0',
        '--Mapper.ba_refine_principal_point', '0',
        '--Mapper.ba_refine_extra_params', '0',
        '--Mapper.min_num_matches', '15',
        '--Mapper.init_min_num_inliers', '50',
        '--Mapper.max_num_models', '1',
        '--Mapper.num_threads', '16',
    ]
    print(f"Command: {' '.join(cmd)}\n")

    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
    for line in process.stdout:
        print(line, end='')
    process.wait()
    if process.returncode == 0:
        model_dir = os.path.join(output_dir, '0')
        if os.path.exists(model_dir):
            print(f"\n✓ COLMAP reconstruction complete: {model_dir}")
            return model_dir
    raise RuntimeError("COLMAP reconstruction failed")

# %%
# ============================================================================
# Step 5: Convert to Gaussian Splatting Format (if needed)
# ============================================================================

def convert_to_gs_format(colmap_model_dir, output_dir):
    """
    Verify COLMAP output and prepare paths for Gaussian Splatting.

    Args:
        colmap_model_dir (str): Path to the COLMAP sparse/0 directory.
                                Example: /content/output/colmap/sparse/0
        output_dir (str): Base output directory.

    Returns:
        colmap_parent_dir (str): The path to be passed to Gaussian Splatting.
                                 Example: /content/output/colmap (Parent directory containing 'sparse/')
    """
    print("\n=== Verifying COLMAP Model for Gaussian Splatting ===")

    import pycolmap
    reconstruction = pycolmap.Reconstruction(colmap_model_dir)

    print(f"Registered images: {len(reconstruction.images)}")
    print(f"3D points: {len(reconstruction.points3D)}")

    # Check for files required by Gaussian Splatting
    required_files = ['cameras.bin', 'images.bin', 'points3D.bin']
    for file in required_files:
        file_path = os.path.join(colmap_model_dir, file)
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"Required file not found: {file}")
        print(f"  ✓ {file}")

    # Return the grandparent directory of sparse/0
    # /content/output/colmap/sparse/0 -> /content/output/colmap
    colmap_parent_dir = os.path.dirname(os.path.dirname(colmap_model_dir))

    print(f"\n✓ COLMAP model ready for Gaussian Splatting")
    print(f"  Source path: {colmap_parent_dir}")

    return colmap_parent_dir

# %%
def train_gaussian_splatting(colmap_dir, image_dir, output_dir, iterations=30000):
    """
    Train a Gaussian Splatting model.

    Args:
        colmap_dir (str): COLMAP parent directory (the directory containing 'sparse/').
                          Example: /content/output/colmap
        image_dir (str): Directory containing training images.
                         Example: /content/output/processed_images
        output_dir (str): Base directory for Gaussian Splatting output.
        iterations (int): Total number of training iterations.

    Returns:
        gs_output_dir (str): Path to the generated Gaussian Splatting output.
    """
    print("\n=== Training Gaussian Splatting ===")

    gs_output_dir = os.path.join(output_dir, 'gs_output')
    os.makedirs(gs_output_dir, exist_ok=True)

    # Verify the Gaussian Splatting directory structure
    sparse_dir = os.path.join(colmap_dir, 'sparse', '0')
    if not os.path.exists(sparse_dir):
        raise FileNotFoundError(f"COLMAP sparse directory not found: {sparse_dir}")

    print(f"COLMAP sparse model: {sparse_dir}")
    print(f"Training images: {image_dir}")
    print(f"Output: {gs_output_dir}")
    print(f"Iterations: {iterations}")

    # Gaussian Splatting command
    cmd = [
        'python', 'train.py',
        '-s', colmap_dir,            # Source directory (must contain 'sparse/')
        '--images', image_dir,       # Explicitly specify the images directory
        '-m', gs_output_dir,          # Model output directory
        '--iterations', str(iterations),
        '--test_iterations', str(iterations//2), str(iterations),
        '--save_iterations', str(iterations//2), str(iterations),
    ]

    print(f"\nCommand: {' '.join(cmd)}\n")

    result = subprocess.run(cmd, capture_output=True, text=True)

    print(result.stdout)
    if result.stderr:
        print("STDERR:", result.stderr)

    if result.returncode != 0:
        raise RuntimeError("Gaussian Splatting training failed")

    # Check for the existence of the generated PLY file
    ply_path = os.path.join(gs_output_dir, 'point_cloud', f'iteration_{iterations}', 'point_cloud.ply')
    if os.path.exists(ply_path):
        size_mb = os.path.getsize(ply_path) / (1024 * 1024)
        print(f"\n✓ Training complete!")
        print(f"  PLY file: {ply_path}")
        print(f"  Size: {size_mb:.2f} MB")
    else:
        print(f"⚠️  Warning: PLY file not found at the expected location")

    return gs_output_dir

# %% [markdown]
# # **main**

# %%
def main_pipeline(image_dir, output_dir, square_size=1024):
    """
    Complete pipeline: Images → Square Processing → COLMAP → Gaussian Splatting
    """
    print("="*70)
    print("Gaussian Splatting Preparation Pipeline")
    print("="*70)

    # Step 0: Standardize images to square format
    #processed_dir = os.path.join(output_dir, 'processed_images')
    #processed_image_dir = preprocess_images_square(image_dir, processed_dir, size=square_size)

    processed_image_dir = os.path.join(output_dir, "processed_images")

    normalize_image_sizes_biplet(
    input_dir=image_dir,
    output_dir=processed_image_dir,
    size=square_size
)

    # Setup paths
    feature_dir = os.path.join(output_dir, 'features')
    colmap_dir = os.path.join(output_dir, 'colmap')
    database_path = os.path.join(colmap_dir, 'database.db')
    sparse_dir = os.path.join(colmap_dir, 'sparse')

    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(colmap_dir, exist_ok=True)

    # Get image paths
    image_paths = sorted([
        os.path.join(processed_image_dir, f)
        for f in os.listdir(processed_image_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ])

    print(f"\n📸 Found {len(image_paths)} images")

    # Step 1: Generate image pairs
    pairs, features = get_image_pairs(image_paths)

    # Step 2: Feature matching with LightGlue
    match_pairs_lightglue(image_paths, pairs, features, feature_dir)

    # Step 3: Import data into COLMAP
    # (single_camera=True assumes uniform image dimensions)
    import_to_colmap(processed_image_dir, feature_dir, database_path, single_camera=True)

    # Step 4: Run COLMAP Sparse Reconstruction
    model_dir = run_colmap_mapper(database_path, processed_image_dir, sparse_dir)

    # Step 5: Verify and prepare for Gaussian Splatting
    colmap_parent = convert_to_gs_format(model_dir, output_dir)

    # Step 6: Train Gaussian Splatting model
    gs_output = train_gaussian_splatting(
        colmap_dir=colmap_parent,
        image_dir=processed_image_dir,
        output_dir=output_dir,
        iterations=6000
    )

    print("\n" + "="*70)
    print("✅ Full Pipeline Successfully Completed!")
    print("="*70)
    print(f"\nGaussian Splatting model saved at: {gs_output}")

    return gs_output


# Example usage
if __name__ == "__main__":
    # Example: Tourist photos with varying resolutions/aspect ratios
    IMAGE_DIR = "/content/drive/MyDrive/your_folder/grand_place"
    OUTPUT_DIR = "/content/output"

    gs_output = main_pipeline(IMAGE_DIR, OUTPUT_DIR, square_size=1024)
# Out:
# ======================================================================
# Gaussian Splatting Preparation Pipeline
# ======================================================================
# Generating 2 cropped squares (Left/Right or Top/Bottom) for each image...
#
#   ✓ 30060098_13881136865.jpg: (1045, 776) → 2 square images generated
#   ✓ 30932426_9182415658.jpg: (1066, 693) → 2 square images generated
#   ✓ 31608163_6102133633.jpg: (1013, 757) → 2 square images generated
#   ✓ 32234104_183977071.jpg: (1056, 780) → 2 square images generated
#   ✓ 54689750_8177752931.jpg: (780, 1056) → 2 square images generated
#   ✓ 54789298_4426358141.jpg: (1041, 774) → 2 square images generated
#   ✓ 54924303_8694631531.jpg: (1020, 680) → 2 square images generated
#   ✓ 55042300_2998445423.jpg: (780, 1056) → 2 square images generated
#   ✓ 56336675_12025095504.jpg: (1030, 693) → 2 square images generated
#   ✓ 56571846_8147517032.jpg: (1039, 773) → 2 square images generated
#   ✓ 56929508_8486048059.jpg: (1021, 765) → 2 square images generated
#   ✓ 57895262_5823807439.jpg: (1072, 786) → 2 square images generated
#   ✓ 57903036_6034663613.jpg: (1014, 758) → 2 square images generated
#   ✓ 58370062_228935435.jpg: (1047, 776) → 2 square images generated
#   ✓ 60409409_9335730523.jpg: (1032, 684) → 2 square images generated
#   ✓ 61195081_2862626518.jpg: (506, 377) → 2 square images generated
#   ✓ 61353083_128372808.jpg: (606, 816) → 2 square images generated
#   ✓ 61442570_1877638298.jpg: (935, 1081) → 2 square images generated
#   ✓ 61931752_11269229804.jpg: (374, 501) → 2 square images generated
#   ✓ 62109065_5110187734.jpg: (1021, 769) → 2 square images generated
#   ✓ 63023054_7575192460.jpg: (777, 1049) → 2 square images generated
#   ✓ 63358653_3107448586.jpg: (1021, 683) → 2 square images generated
#   ✓ 63732276_3020022441.jpg: (692, 1068) → 2 square images generated
#   ✓ 63831138_11531850475.jpg: (1057, 689) → 2 square images generated
#   ✓ 63879656_8828566618.jpg: (1026, 768) → 2 square images generated
#   ✓ 64133734_1372277262.jpg: (1047, 688) → 2 square images generated
#   ✓ 64177922_6939801959.jpg: (1065, 651) → 2 square images generated
#   ✓ 64512286_144258707.jpg: (689, 1050) → 2 square images generated
#   ✓ 64752693_9379071376.jpg: (760, 1027) → 2 square images generated
#   ✓ 65596895_2998348333.jpg: (786, 1072) → 2 square images generated
#   ✓ 65600629_2179631506.jpg: (1041, 774) → 2 square images generated
#   ✓ 65723931_2797767702.jpg: (1061, 782) → 2 square images generated
#   ✓ 66906958_589662361.jpg: (1053, 779) → 2 square images generated
#   ✓ 67684501_389553533.jpg: (1020, 764) → 2 square images generated
#   ✓ 68173000_3055082929.jpg: (719, 1052) → 2 square images generated
#   ✓ 68388628_416361462.jpg: (1067, 784) → 2 square images generated
#   ✓ 68664732_743450957.jpg: (778, 1052) → 2 square images generated
#   ✓ 69151734_8072413114.jpg: (1021, 677) → 2 square images generated
#   ✓ 69241373_2334905294.jpg: (1047, 776) → 2 square images generated
#   ✓ 69675366_3578017198.jpg: (1057, 780) → 2 square images generated
#   ✓ 70032246_6347641014.jpg: (117, 204) → 2 square images generated
#   ✓ 70699652_8066487031.jpg: (204, 114) → 2 square images generated
#   ✓ 71316394_5233978047.jpg: (1033, 771) → 2 square images generated
#   ✓ 71521166_8226626351.jpg: (1013, 757) → 2 square images generated
#   ✓ 72075679_2232424648.jpg: (1045, 776) → 2 square images generated
#   ✓ 72598875_8072411042.jpg: (680, 1032) → 2 square images generated
#   ✓ 72646474_2231631573.jpg: (1048, 777) → 2 square images generated
#   ✓ 73543943_6819377449.jpg: (1064, 783) → 2 square images generated
#   ✓ 74323184_6819378543.jpg: (1061, 782) → 2 square images generated
#   ✓ 74379252_3524899450.jpg: (1066, 784) → 2 square images generated
#   ✓ 74949128_744301420.jpg: (1055, 780) → 2 square images generated
#   ✓ 75556369_8486047615.jpg: (756, 1009) → 2 square images generated
#   ✓ 75670494_10532227934.jpg: (1045, 776) → 2 square images generated
#   ✓ 75795010_1073028.jpg: (513, 380) → 2 square images generated
#   ✓ 75963148_11531980813.jpg: (1062, 690) → 2 square images generated
#   ✓ 76012163_5234572012.jpg: (1057, 780) → 2 square images generated
#   ✓ 76033783_4998492930.jpg: (1075, 694) → 2 square images generated
#   ✓ 76893682_2999450842.jpg: (1036, 772) → 2 square images generated
#   ✓ 77082765_2334078741.jpg: (780, 1055) → 2 square images generated
#   ✓ 77322980_4097421297.jpg: (775, 1044) → 2 square images generated
#   ✓ 77502589_7155532159.jpg: (1010, 1010) → 2 square images generated
#   ✓ 78461576_2179633616.jpg: (1044, 776) → 2 square images generated
#   ✓ 78756975_2797764270.jpg: (1060, 782) → 2 square images generated
#   ✓ 80159334_3432556478.jpg: (610, 822) → 2 square images generated
#   ✓ 80238669_11531890454.jpg: (1026, 680) → 2 square images generated
#   ✓ 80394863_159173947.jpg: (1048, 777) → 2 square images generated
#   ✓ 80419518_5109586935.jpg: (1026, 772) → 2 square images generated
#   ✓ 80486775_7794448262.jpg: (1007, 756) → 2 square images generated
#   ✓ 80637823_2178834461.jpg: (773, 1039) → 2 square images generated
#   ✓ 82494139_2231488841.jpg: (1040, 774) → 2 square images generated
#   ✓ 82619588_2231634419.jpg: (1041, 774) → 2 square images generated
#   ✓ 83049944_6012584465.jpg: (689, 1047) → 2 square images generated
#   ✓ 83295590_2999194388.jpg: (1061, 782) → 2 square images generated
#   ✓ 83393115_2713666377.jpg: (1057, 691) → 2 square images generated
#   ✓ 83494299_9338552580.jpg: (1032, 684) → 2 square images generated
#   ✓ 83683619_338844451.jpg: (1060, 782) → 2 square images generated
#   ✓ 83880039_8704930508.jpg: (1065, 696) → 2 square images generated
#   ✓ 84280780_9149810125.jpg: (698, 1070) → 2 square images generated
#   ✓ 84416532_1372248960.jpg: (1047, 689) → 2 square images generated
#   ✓ 85875165_3423168615.jpg: (1009, 670) → 2 square images generated
#   ✓ 87021942_9387960095.jpg: (692, 1060) → 2 square images generated
#   ✓ 87218542_4659693663.jpg: (1051, 690) → 2 square images generated
#   ✓ 87247686_240007777.jpg: (1056, 780) → 2 square images generated
#   ✓ 87692684_217109210.jpg: (613, 454) → 2 square images generated
#   ✓ 88392746_217109207.jpg: (612, 454) → 2 square images generated
#   ✓ 89270148_8703811409.jpg: (1064, 696) → 2 square images generated
#   ✓ 89428328_415853343.jpg: (1041, 774) → 2 square images generated
#   ✓ 89821764_2714509360.jpg: (768, 1026) → 2 square images generated
#   ✓ 89912815_3055922954.jpg: (1021, 543) → 2 square images generated
#   ✓ 90349736_2179635862.jpg: (1038, 773) → 2 square images generated
#   ✓ 90437703_2231631681.jpg: (776, 1046) → 2 square images generated
#   ✓ 90505934_1674425132.jpg: (781, 595) → 2 square images generated
#   ✓ 90635649_2575304688.jpg: (1033, 683) → 2 square images generated
#   ✓ 90975523_4819480082.jpg: (1070, 698) → 2 square images generated
#   ✓ 91086090_6251487936.jpg: (774, 1041) → 2 square images generated
#   ✓ 91147360_7119433063.jpg: (756, 1012) → 2 square images generated
#   ✓ 91223537_687114481.jpg: (696, 1078) → 2 square images generated
#   ✓ 91887585_2717484563.jpg: (1024, 628) → 2 square images generated
#   ✓ 91966016_2575756133.jpg: (1054, 779) → 2 square images generated
#   ✓ 92092453_6346876777.jpg: (644, 1094) → 2 square images generated
#   ✓ 92332702_2575760403.jpg: (1056, 780) → 2 square images generated
#   ✓ 93176024_7794453938.jpg: (975, 563) → 2 square images generated
#   ✓ 93452424_2796919411.jpg: (783, 1064) → 2 square images generated
#   ✓ 93855352_2178846945.jpg: (1047, 777) → 2 square images generated
#   ✓ 94589793_5911133174.jpg: (971, 643) → 2 square images generated
#   ✓ 94608068_9152036176.jpg: (1029, 686) → 2 square images generated
#   ✓ 95763587_2232280810.jpg: (1043, 775) → 2 square images generated
#   ✓ 95912681_1074872458.jpg: (1199, 556) → 2 square images generated
#   ✓ 96196686_8643079931.jpg: (1035, 772) → 2 square images generated
#   ✓ 96969581_4970715984.jpg: (1004, 1004) → 2 square images generated
#   ✓ 97044761_5284916914.jpg: (689, 1047) → 2 square images generated
#   ✓ 97169342_4819482004.jpg: (1020, 683) → 2 square images generated
#   ✓ 97408314_4660309480.jpg: (1052, 778) → 2 square images generated
#   ✓ 97679107_216044726.jpg: (1028, 769) → 2 square images generated
#   ✓ 98096144_7465571668.jpg: (1035, 1035) → 2 square images generated
#   ✓ 98217251_4097423171.jpg: (1032, 770) → 2 square images generated
#   ✓ 98347882_247481604.jpg: (1057, 691) → 2 square images generated
#   ✓ 98365344_176581376.jpg: (1049, 777) → 2 square images generated
#   ✓ 98413296_389554202.jpg: (1059, 781) → 2 square images generated
#   ✓ 99829338_590024774.jpg: (1055, 780) → 2 square images generated
#
# Processing complete: 120 source images processed
# Original size distribution: {'1045x776': 3, '1066x693': 1, '1013x757': 2, '1056x780': 3, '780x1056': 2, '1041x774': 4, '1020x680': 1, '1030x693': 1, '1039x773': 1, '1021x765': 1, '1072x786': 1, '1014x758': 1, '1047x776': 2, '1032x684': 2, '506x377': 1, '606x816': 1, '935x1081': 1, '374x501': 1, '1021x769': 1, '777x1049': 1, '1021x683': 1, '692x1068': 1, '1057x689': 1, '1026x768': 1, '1047x688': 1, '1065x651': 1, '689x1050': 1, '760x1027': 1, '786x1072': 1, '1061x782': 3, '1053x779': 1, '1020x764': 1, '719x1052': 1, '1067x784': 1, '778x1052': 1, '1021x677': 1, '1057x780': 2, '117x204': 1, '204x114': 1, '1033x771': 1, '680x1032': 1, '1048x777': 2, '1064x783': 1, '1066x784': 1, '1055x780': 2, '756x1009': 1, '513x380': 1, '1062x690': 1, '1075x694': 1, '1036x772': 1, '780x1055': 1, '775x1044': 1, '1010x1010': 1, '1044x776': 1, '1060x782': 2, '610x822': 1, '1026x680': 1, '1026x772': 1, '1007x756': 1, '773x1039': 1, '1040x774': 1, '689x1047': 2, '1057x691': 2, '1065x696': 1, '698x1070': 1, '1047x689': 1, '1009x670': 1, '692x1060': 1, '1051x690': 1, '613x454': 1, '612x454': 1, '1064x696': 1, '768x1026': 1, '1021x543': 1, '1038x773': 1, '776x1046': 1, '781x595': 1, '1033x683': 1, '1070x698': 1, '774x1041': 1, '756x1012': 1, '696x1078': 1, '1024x628': 1, '1054x779': 1, '644x1094': 1, '975x563': 1, '783x1064': 1, '1047x777': 1, '971x643': 1, '1029x686': 1, '1043x775': 1, '1199x556': 1, '1035x772': 1, '1004x1004': 1, '1020x683': 1, '1052x778': 1, '1028x769': 1, '1035x1035': 1, '1032x770': 1, '1049x777': 1, '1059x781': 1}
#
# 📸 Found 240 images
#
# === Extracting DINO Global Features ===
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/436 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# 100%|██████████| 240/240 [00:39<00:00,  6.14it/s]
# Initial pairs from global features: 23780
#
# === Extracting ALIKED Local Features ===
# Downloading: "https://github.com/Shiaoming/ALIKED/raw/main/models/aliked-n16.pth" to /root/.cache/torch/hub/checkpoints/aliked-n16.pth
# 100%|██████████| 2.61M/2.61M [00:00<00:00, 194MB/s]
# 100%|██████████| 240/240 [00:22<00:00, 10.50it/s]
# === Verifying Pairs with Local Features ===
# 100%|██████████| 23780/23780 [04:45<00:00, 83.38it/s]
# Verified pairs: 23780
#
# === Matching with LightGlue ===
# Downloading: "https://github.com/cvg/LightGlue/releases/download/v0.1_arxiv/aliked_lightglue.pth" to /root/.cache/torch/hub/checkpoints/aliked_lightglue_v0-1_arxiv.pth
# 100%|██████████| 45.4M/45.4M [00:02<00:00, 19.5MB/s]
# Saving keypoints: 100%|██████████| 240/240 [00:00<00:00, 4643.48it/s]
# Matching: 100%|██████████| 23780/23780 [1:00:40<00:00,  6.53it/s]
# ✓ Matches saved to /content/output/features/matches.h5
#
# === Creating COLMAP Database ===
# Single camera mode: True
# Detected image extension: '.jpg'
# 100%|██████████| 240/240 [00:00<00:00, 2687.80it/s]
# Camera created: PINHOLE, f=1024.0, cx=512.0, cy=512.0
# Importing matches to database: 100%|██████████| 23749/23749 [00:07<00:00, 3170.73it/s]
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   => Merged observations: 375
#   => Completed observations: 506
#   => Filtered observations: 53
#   => Changed observations: 0.019963
#
# ==============================================================================
# Registering image #207 (198)
# ==============================================================================
#
#   => Image sees 4925 / 7486 points
#
# Pose refinement report
# ----------------------
#     Residuals : 58400
#    Parameters : 6
#    Iterations : 13
#          Time : 0.71978 [s]
#  Initial cost : 0.847703 [px]
#    Final cost : 0.84013 [px]
#   Termination : Convergence
#
#   => Continued observations: 4579
#   => Added observations: 9241
#
# Bundle adjustment report
# ------------------------
#     Residuals : 95804
#    Parameters : 11807
#    Iterations : 26
#          Time : 2.08403 [s]
#  Initial cost : 1.20361 [px]
#    Final cost : 1.15741 [px]
#   Termination : No convergence
#
#   => Merged observations: 240
#   => Completed observations: 465
#   => Filtered observations: 8989
#   => Changed observations: 0.189343
#
# Bundle adjustment report
# ------------------------
#     Residuals : 74354
#    Parameters : 6587
#    Iterations : 4
#          Time : 0.431877 [s]
#  Initial cost : 1.06453 [px]
#    Final cost : 1.04323 [px]
#   Termination : Convergence
#
#   => Merged observations: 525
#   => Completed observations: 601
#   => Filtered observations: 79
#   => Changed observations: 0.027180
#
# ==============================================================================
# Registering image #152 (199)
# ==============================================================================
#
#   => Image sees 7396 / 7790 points
#
# Pose refinement report
# ----------------------
#     Residuals : 87446
#    Parameters : 6
#    Iterations : 21
#          Time : 1.70119 [s]
#  Initial cost : 0.882396 [px]
#    Final cost : 0.869806 [px]
#   Termination : Convergence
#
#   => Continued observations: 6723
#   => Added observations: 22783
#
# Bundle adjustment report
# ------------------------
#     Residuals : 151266
#    Parameters : 25652
#    Iterations : 26
#          Time : 2.6321 [s]
#  Initial cost : 1.48015 [px]
#    Final cost : 1.42425 [px]
#   Termination : No convergence
#
#   => Merged observations: 1183
#   => Completed observations: 1235
#   => Filtered observations: 22097
#   => Changed observations: 0.296817
#
# Bundle adjustment report
# ------------------------
#     Residuals : 113368
#    Parameters : 17162
#    Iterations : 3
#          Time : 0.294377 [s]
#  Initial cost : 1.0741 [px]
#    Final cost : 1.03486 [px]
#   Termination : Convergence
#
#   => Merged observations: 1809
#   => Completed observations: 1413
#   => Filtered observations: 192
#   => Changed observations: 0.055961
#
# ==============================================================================
# Registering image #214 (200)
# ==============================================================================
#
#   => Image sees 5012 / 6822 points
#
# Pose refinement report
# ----------------------
#     Residuals : 39878
#    Parameters : 6
#    Iterations : 14
#          Time : 0.501581 [s]
#  Initial cost : 0.894381 [px]
#    Final cost : 0.884349 [px]
#   Termination : Convergence
#
#   => Continued observations: 4266
#   => Added observations: 18341
#
# Bundle adjustment report
# ------------------------
#     Residuals : 128076
#    Parameters : 20531
#    Iterations : 26
#          Time : 2.78292 [s]
#  Initial cost : 1.50836 [px]
#    Final cost : 1.45326 [px]
#   Termination : No convergence
#
#   => Merged observations: 407
#   => Completed observations: 1136
#   => Filtered observations: 17889
#   => Changed observations: 0.273105
#
# Bundle adjustment report
# ------------------------
#     Residuals : 95406
#    Parameters : 14519
#    Iterations : 4
#          Time : 0.551502 [s]
#  Initial cost : 1.03683 [px]
#    Final cost : 0.998045 [px]
#   Termination : Convergence
#
#   => Merged observations: 1213
#   => Completed observations: 1191
#   => Filtered observations: 55
#   => Changed observations: 0.048077
#
# ==============================================================================
# Registering image #11 (201)
# ==============================================================================
#
#   => Image sees 4884 / 6769 points
#
# Pose refinement report
# ----------------------
#     Residuals : 61486
#    Parameters : 6
#    Iterations : 18
#          Time : 1.12547 [s]
#  Initial cost : 0.885408 [px]
#    Final cost : 0.871276 [px]
#   Termination : Convergence
#
#   => Continued observations: 4447
#   => Added observations: 20810
#
# Bundle adjustment report
# ------------------------
#     Residuals : 129256
#    Parameters : 19469
#    Iterations : 26
#          Time : 2.18901 [s]
#  Initial cost : 1.5932 [px]
#    Final cost : 1.53558 [px]
#   Termination : No convergence
#
#   => Merged observations: 642
#   => Completed observations: 1198
#   => Filtered observations: 19917
#   => Changed observations: 0.302475
#
# Bundle adjustment report
# ------------------------
#     Residuals : 93022
#    Parameters : 12401
#    Iterations : 3
#          Time : 0.235273 [s]
#  Initial cost : 1.08961 [px]
#    Final cost : 1.05305 [px]
#   Termination : Convergence
#
#   => Merged observations: 1534
#   => Completed observations: 1147
#   => Filtered observations: 73
#   => Changed observations: 0.051154
#
# ==============================================================================
# Registering image #48 (202)
# ==============================================================================
#
#   => Image sees 6002 / 7386 points
#
# Pose refinement report
# ----------------------
#     Residuals : 45412
#    Parameters : 6
#    Iterations : 19
#          Time : 0.802261 [s]
#  Initial cost : 0.901706 [px]
#    Final cost : 0.894925 [px]
#   Termination : Convergence
#
#   => Continued observations: 4601
#   => Added observations: 20337
#
# Bundle adjustment report
# ------------------------
#     Residuals : 132188
#    Parameters : 24359
#    Iterations : 26
#          Time : 2.34801 [s]
#  Initial cost : 1.55215 [px]
#    Final cost : 1.48674 [px]
#   Termination : No convergence
#
#   => Merged observations: 530
#   => Completed observations: 1306
#   => Filtered observations: 19774
#   => Changed observations: 0.302039
#
# Bundle adjustment report
# ------------------------
#     Residuals : 92612
#    Parameters : 16217
#    Iterations : 4
#          Time : 0.543702 [s]
#  Initial cost : 1.10045 [px]
#    Final cost : 1.05842 [px]
#   Termination : Convergence
#
#   => Merged observations: 1470
#   => Completed observations: 1385
#   => Filtered observations: 63
#   => Changed observations: 0.058064
#
# ==============================================================================
# Registering image #130 (203)
# ==============================================================================
#
#   => Image sees 4966 / 6403 points
#
# Pose refinement report
# ----------------------
#     Residuals : 53640
#    Parameters : 6
#    Iterations : 24
#          Time : 1.44726 [s]
#  Initial cost : 0.940419 [px]
#    Final cost : 0.905263 [px]
#   Termination : Convergence
#
#   => Continued observations: 4670
#   => Added observations: 9298
#
# Bundle adjustment report
# ------------------------
#     Residuals : 99020
#    Parameters : 13727
#    Iterations : 26
#          Time : 1.78242 [s]
#  Initial cost : 1.18995 [px]
#    Final cost : 1.12716 [px]
#   Termination : No convergence
#
#   => Merged observations: 626
#   => Completed observations: 460
#   => Filtered observations: 9196
#   => Changed observations: 0.184991
#
# Bundle adjustment report
# ------------------------
#     Residuals : 85208
#    Parameters : 8549
#    Iterations : 4
#          Time : 0.300362 [s]
#  Initial cost : 1.06004 [px]
#    Final cost : 1.04436 [px]
#   Termination : Convergence
#
#   => Merged observations: 856
#   => Completed observations: 1246
#   => Filtered observations: 88
#   => Changed observations: 0.044556
#
# ==============================================================================
# Registering image #47 (204)
# ==============================================================================
#
#   => Image sees 6814 / 7497 points
#
# Pose refinement report
# ----------------------
#     Residuals : 67318
#    Parameters : 6
#    Iterations : 21
#          Time : 1.28249 [s]
#  Initial cost : 0.870017 [px]
#    Final cost : 0.838325 [px]
#   Termination : Convergence
#
#   => Continued observations: 4851
#   => Added observations: 13803
#
# Bundle adjustment report
# ------------------------
#     Residuals : 109704
#    Parameters : 19031
#    Iterations : 26
#          Time : 1.9459 [s]
#  Initial cost : 1.35086 [px]
#    Final cost : 1.25335 [px]
#   Termination : No convergence
#
#   => Merged observations: 1157
#   => Completed observations: 871
#   => Filtered observations: 13382
#   => Changed observations: 0.248112
#
# Bundle adjustment report
# ------------------------
#     Residuals : 89462
#    Parameters : 11816
#    Iterations : 4
#          Time : 0.288447 [s]
#  Initial cost : 1.0562 [px]
#    Final cost : 1.0286 [px]
#   Termination : Convergence
#
#   => Merged observations: 2012
#   => Completed observations: 991
#   => Filtered observations: 93
#   => Changed observations: 0.059907
#
# ==============================================================================
# Registering image #180 (205)
# ==============================================================================
#
#   => Image sees 5329 / 6870 points
#
# Pose refinement report
# ----------------------
#     Residuals : 74550
#    Parameters : 6
#    Iterations : 25
#          Time : 2.67407 [s]
#  Initial cost : 0.892928 [px]
#    Final cost : 0.866896 [px]
#   Termination : Convergence
#
#   => Continued observations: 5179
#   => Added observations: 11019
#
# Bundle adjustment report
# ------------------------
#     Residuals : 96202
#    Parameters : 12905
#    Iterations : 26
#          Time : 1.67744 [s]
#  Initial cost : 1.29725 [px]
#    Final cost : 1.25405 [px]
#   Termination : No convergence
#
#   => Merged observations: 1001
#   => Completed observations: 686
#   => Filtered observations: 10515
#   => Changed observations: 0.224922
#
# Bundle adjustment report
# ------------------------
#     Residuals : 75198
#    Parameters : 6944
#    Iterations : 3
#          Time : 0.204422 [s]
#  Initial cost : 1.077 [px]
#    Final cost : 1.05681 [px]
#   Termination : Convergence
#
#   => Merged observations: 1539
#   => Completed observations: 749
#   => Filtered observations: 93
#   => Changed observations: 0.054437
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 7296
#   => Merged observations: 3557
#   => Retriangulated observations: 82502
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.972747e+07    0.00e+00    4.18e+06   0.00e+00   0.00e+00  1.00e+04        0    1.64e+00    7.10e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 5.5179e+08
#     Nonzeros in L:       7.1272e+05
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       1.6
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 5.5179e+08
#         nnz(L):     7.1272e+05
#   OK
#    1  3.191435e+09   -3.16e+09    4.18e+06   1.83e+02  -2.28e+02  5.00e+03        1    7.58e+00    1.47e+01
#    2  3.117843e+10   -3.11e+10    4.18e+06   1.74e+02  -2.24e+03  1.25e+03        1    3.81e+00    1.85e+01
#    3  2.951485e+07    2.13e+05    4.65e+07   1.48e+02   1.54e-02  6.54e+02        1    6.83e+00    2.53e+01
#    4  1.784010e+07    1.17e+07    4.54e+06   6.18e+01   8.60e-01  1.04e+03        1    5.35e+00    3.07e+01
#    5  1.620673e+07    1.63e+06    6.52e+05   7.82e+01   8.67e-01  1.72e+03        1    6.05e+00    3.67e+01
#    6  1.599446e+07    2.12e+05    1.44e+05   1.02e+02   8.66e-01  2.83e+03        1    6.24e+00    4.30e+01
#    7  1.596101e+07    3.35e+04    8.34e+04   9.14e+01   8.16e-01  3.78e+03        1    5.34e+00    4.83e+01
#    8  1.595239e+07    8.62e+03    1.08e+06   1.26e+02   3.13e-01  3.59e+03        1    7.04e+00    5.53e+01
#    9  1.590117e+07    5.12e+04    1.30e+05   1.62e+02   7.51e-01  4.11e+03        1    5.33e+00    6.07e+01
#   10  1.614073e+07   -2.40e+05    1.30e+05   1.12e+02  -4.44e+00  2.06e+03        1    5.49e+00    6.62e+01
#   11  1.585589e+07    4.53e+04    7.12e+04   7.09e+01   8.56e-01  3.22e+03        1    5.29e+00    7.15e+01
#   12  1.588106e+07   -2.52e+04    7.12e+04   8.97e+01  -1.08e+00  1.61e+03        1    3.87e+00    7.53e+01
#   13  1.586076e+07   -4.87e+03    7.12e+04   5.60e+01  -2.18e-01  4.03e+02        1    5.48e+00    8.08e+01
#   14  1.583471e+07    2.12e+04    2.68e+04   2.05e+01   1.05e+00  1.21e+03        1    5.24e+00    8.60e+01
#   15  1.592458e+07   -8.99e+04    2.68e+04   4.59e+01  -1.60e+01  6.04e+02        1    4.67e+00    9.07e+01
#   16  1.582919e+07    5.52e+03    2.89e+04   2.66e+01   1.18e+00  1.81e+03        1    6.08e+00    9.68e+01
#   17  1.582682e+07    2.37e+03    1.64e+04   4.71e+01   7.02e-01  1.94e+03        1    5.39e+00    1.02e+02
#   18  1.582350e+07    3.33e+03    5.94e+03   1.03e+01   1.03e+00  5.82e+03        1    6.95e+00    1.09e+02
#   19  1.582156e+07    1.94e+03    1.07e+04   1.14e+01   1.06e+00  1.75e+04        1    5.36e+00    1.14e+02
#   20  1.581993e+07    1.63e+03    3.74e+04   2.29e+01   9.90e-01  5.24e+04        1    7.04e+00    1.22e+02
#   21  1.581900e+07    9.34e+02    5.08e+04   5.20e+01   9.19e-01  1.27e+05        1    5.34e+00    1.27e+02
#   22  1.581854e+07    4.62e+02    1.80e+04   1.06e+02   9.92e-01  3.81e+05        1    6.88e+00    1.34e+02
#   23  1.582402e+07   -5.48e+03    1.80e+04   2.81e+02  -3.30e+01  1.91e+05        1    3.84e+00    1.38e+02
#   24  1.581840e+07    1.38e+02    4.16e+04   1.47e+02   1.03e+00  5.72e+05        1    5.36e+00    1.43e+02
#   25  1.581831e+07    8.97e+01    8.50e+03   4.11e+02   9.53e-01  1.72e+06        1    7.07e+00    1.50e+02
#   26  1.581830e+07    1.05e+01    2.17e+06   1.19e+03   1.11e-01  1.17e+06        1    5.43e+00    1.55e+02
#   27  1.581829e+07    9.17e+00    6.13e+05   8.16e+02   8.25e-02  7.38e+05        1    7.01e+00    1.62e+02
#   28  1.581818e+07    1.08e+02    3.48e+05   5.17e+02   8.76e-01  1.29e+06        1    5.30e+00    1.68e+02
#   29  1.581815e+07    2.91e+01    8.66e+04   8.96e+02   8.71e-01  2.17e+06        1    6.92e+00    1.75e+02
#   30  1.581839e+07   -2.39e+02    8.66e+04   1.51e+03  -1.36e+01  1.08e+06        1    3.82e+00    1.79e+02
#   31  1.581814e+07    9.59e+00    1.83e+05   7.53e+02   6.46e-01  1.11e+06        1    5.34e+00    1.84e+02
#   32  1.581813e+07    1.06e+01    1.02e+04   7.71e+02   8.80e-01  1.98e+06        1    7.05e+00    1.91e+02
#   33  1.581813e+07    4.34e+00    4.44e+03   1.37e+03   6.62e-01  2.05e+06        1    5.42e+00    1.96e+02
#   34  1.581812e+07    2.32e+00    5.28e+03   1.42e+03   4.54e-01  2.05e+06        1    7.08e+00    2.03e+02
#   35  1.581812e+07    1.24e+00    1.67e+03   1.41e+03   2.73e-01  1.87e+06        1    5.33e+00    2.09e+02
#   36  1.581812e+07    6.25e-01    2.74e+03   1.29e+03   1.42e-01  1.37e+06        1    6.89e+00    2.16e+02
#   37  1.581812e+07    2.50e-01    1.06e+03   9.40e+02   5.54e-02  8.04e+05        1    5.43e+00    2.21e+02
#   38  1.581812e+07    4.37e-02    9.44e+02   5.52e+02   9.13e-03  4.13e+05        1    5.81e+00    2.27e+02
#   39  1.581812e+07   -1.05e-01    9.44e+02   2.83e+02  -2.05e-02  2.07e+05        1    5.10e+00    2.32e+02
#   40  1.581812e+07   -1.16e-01    9.44e+02   1.41e+02  -2.26e-02  5.17e+04        1    3.79e+00    2.36e+02
#   41  1.581812e+07   -9.69e-02    9.44e+02   3.53e+01  -1.89e-02  6.46e+03        1    3.88e+00    2.40e+02
#   42  1.581812e+07    1.67e-01    1.13e+03   4.47e+00   3.29e-02  3.56e+03        1    6.89e+00    2.47e+02
#   43  1.581812e+07    3.55e-01    8.91e+02   2.50e+00   7.24e-02  2.19e+03        1    5.39e+00    2.52e+02
#   44  1.581812e+07    5.08e-01    9.27e+02   1.59e+00   1.20e-01  1.52e+03        1    7.09e+00    2.59e+02
#   45  1.581812e+07    5.59e-01    6.54e+02   1.12e+00   1.74e-01  1.19e+03        1    5.46e+00    2.64e+02
#   46  1.581812e+07    4.48e-01    5.69e+02   8.80e-01   2.13e-01  1.00e+03        1    6.86e+00    2.71e+02
#   47  1.581812e+07    3.03e-01    3.75e+02   7.25e-01   2.47e-01  8.87e+02        1    5.41e+00    2.77e+02
#   48  1.581812e+07    1.74e-01    2.81e+02   6.33e-01   2.73e-01  8.11e+02        1    6.77e+00    2.84e+02
#   49  1.581812e+07    9.24e-02    1.80e+02   5.68e-01   2.97e-01  7.60e+02        1    5.54e+00    2.89e+02
#   50  1.581812e+07    4.59e-02    1.22e+02   5.28e-01   3.23e-01  7.28e+02        1    5.93e+00    2.95e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2445452
#    Parameters : 442004
#    Iterations : 51
#          Time : 295.165 [s]
#  Initial cost : 3.48658 [px]
#    Final cost : 2.5433 [px]
#   Termination : No convergence
#
#   => Completed observations: 12909
#   => Merged observations: 4478
#   => Filtered observations: 219495
#   => Changed observations: 0.193733
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.419212e+06    0.00e+00    6.74e+05   0.00e+00   0.00e+00  1.00e+04        0    1.48e+00    6.99e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 4.3201e+08
#     Nonzeros in L:       6.4083e+05
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       1.5
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 4.3201e+08
#         nnz(L):     6.4083e+05
#   OK
#    1  1.892829e+06    5.26e+05    1.71e+05   5.15e+01   9.88e-01  3.00e+04        1    7.30e+00    1.43e+01
#    2  1.882374e+06    1.05e+04    6.43e+04   1.67e+01   9.92e-01  9.00e+04        1    5.59e+00    1.99e+01
#    3  1.881640e+06    7.34e+02    5.74e+04   1.18e+01   7.83e-01  1.10e+05        1    4.37e+00    2.43e+01
#    4  1.881311e+06    3.29e+02    8.64e+03   7.29e+00   9.87e-01  3.30e+05        1    5.85e+00    3.01e+01
#    5  1.881236e+06    7.46e+01    1.18e+04   1.59e+01   9.21e-01  8.19e+05        1    4.44e+00    3.45e+01
#    6  1.881141e+06    9.54e+01    1.60e+04   3.40e+01   9.17e-01  1.94e+06        1    4.33e+00    3.89e+01
#    7  1.881025e+06    1.16e+02    3.18e+04   5.80e+01   8.15e-01  2.59e+06        1    5.99e+00    4.49e+01
#    8  1.880931e+06    9.39e+01    2.45e+04   4.93e+01   8.63e-01  4.20e+06        1    4.44e+00    4.93e+01
#    9  1.880883e+06    4.82e+01    1.73e+04   4.03e+01   8.66e-01  6.89e+06        1    4.35e+00    5.37e+01
#   10  1.880865e+06    1.81e+01    6.71e+03   2.43e+01   9.44e-01  2.07e+07        1    6.08e+00    5.97e+01
#   11  1.880862e+06    2.84e+00    1.57e+03   1.16e+01   9.85e-01  6.20e+07        1    4.39e+00    6.41e+01
#   12  1.880862e+06    1.18e-01    5.05e+01   2.02e+00   1.02e+00  1.86e+08        1    4.63e+00    6.87e+01
#   13  1.880862e+06    7.82e-04    1.70e+00   1.79e-01   1.04e+00  5.58e+08        1    5.73e+00    7.45e+01
#   14  1.880862e+06    1.54e-05    1.95e+00   1.68e-02   6.35e-01  5.69e+08        1    4.49e+00    7.90e+01
#   15  1.880862e+06    2.53e-06    1.51e+00   1.48e-03   4.52e-01  5.69e+08        1    5.20e+00    8.42e+01
#   16  1.880862e+06    7.28e-07    7.49e-01   3.21e-04   4.18e-01  5.66e+08        1    5.02e+00    8.92e+01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2029908
#    Parameters : 401309
#    Iterations : 17
#          Time : 89.3074 [s]
#  Initial cost : 1.09169 [px]
#    Final cost : 0.962588 [px]
#   Termination : Convergence
#
#   => Completed observations: 96262
#   => Merged observations: 16869
#   => Filtered observations: 5709
#   => Changed observations: 0.117089
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.270473e+06    0.00e+00    1.69e+05   0.00e+00   0.00e+00  1.00e+04        0    1.52e+00    6.40e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 4.8468e+08
#     Nonzeros in L:       6.7225e+05
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       1.5
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 4.8468e+08
#         nnz(L):     6.7225e+05
#   OK
#    1  2.175067e+06    9.54e+04    6.42e+03   1.62e+01   9.99e-01  3.00e+04        1    8.45e+00    1.49e+01
#    2  2.174705e+06    3.62e+02    5.61e+03   4.66e+00   1.01e+00  9.00e+04        1    4.82e+00    1.97e+01
#    3  2.174624e+06    8.10e+01    4.70e+03   3.42e+00   9.90e-01  2.70e+05        1    6.45e+00    2.61e+01
#    4  2.174600e+06    2.37e+01    1.42e+03   6.12e+00   1.00e+00  8.10e+05        1    4.88e+00    3.10e+01
#    5  2.174579e+06    2.10e+01    4.39e+03   1.43e+01   9.73e-01  2.43e+06        1    5.65e+00    3.66e+01
#    6  2.174560e+06    1.94e+01    8.35e+03   2.20e+01   9.12e-01  5.53e+06        1    5.64e+00    4.23e+01
#    7  2.174552e+06    7.88e+00    4.07e+03   1.52e+01   9.48e-01  1.66e+07        1    4.81e+00    4.71e+01
#    8  2.174551e+06    1.10e+00    5.84e+02   5.67e+00   9.99e-01  4.98e+07        1    6.46e+00    5.36e+01
#    9  2.174551e+06    2.23e-02    1.17e+01   7.89e-01   1.02e+00  1.49e+08        1    4.84e+00    5.84e+01
#   10  2.174551e+06    1.11e-04    1.58e+00   5.46e-02   1.09e+00  4.48e+08        1    5.61e+00    6.40e+01
#   11  2.174551e+06    2.93e-06    8.24e-01   3.75e-03   1.32e+00  1.34e+09        1    5.65e+00    6.97e+01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2210832
#    Parameters : 396905
#    Iterations : 12
#          Time : 69.7881 [s]
#  Initial cost : 1.0134 [px]
#    Final cost : 0.991761 [px]
#   Termination : Convergence
#
#   => Completed observations: 11314
#   => Merged observations: 6819
#   => Filtered observations: 3693
#   => Changed observations: 0.019745
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.217705e+06    0.00e+00    8.56e+04   0.00e+00   0.00e+00  1.00e+04        0    1.52e+00    6.42e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 4.7153e+08
#     Nonzeros in L:       6.652e+05
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       1.5
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 4.7153e+08
#         nnz(L):     6.652e+05
#   OK
#    1  2.196678e+06    2.10e+04    1.64e+03   8.01e+00   1.00e+00  3.00e+04        1    8.63e+00    1.50e+01
#    2  2.196633e+06    4.50e+01    4.97e+02   1.95e+00   1.05e+00  9.00e+04        1    4.82e+00    1.99e+01
#    3  2.196625e+06    8.65e+00    2.50e+02   1.19e+00   1.04e+00  2.70e+05        1    6.45e+00    2.63e+01
#    4  2.196621e+06    3.22e+00    2.52e+02   2.87e+00   1.02e+00  8.10e+05        1    4.77e+00    3.11e+01
#    5  2.196617e+06    4.47e+00    8.56e+02   6.61e+00   9.98e-01  2.43e+06        1    5.48e+00    3.66e+01
#    6  2.196613e+06    4.14e+00    1.71e+03   9.80e+00   9.83e-01  7.29e+06        1    5.76e+00    4.23e+01
#    7  2.196612e+06    1.32e+00    9.12e+02   7.11e+00   9.86e-01  2.19e+07        1    4.90e+00    4.72e+01
#    8  2.196611e+06    1.03e-01    7.62e+01   2.02e+00   1.01e+00  6.56e+07        1    6.37e+00    5.36e+01
#    9  2.196611e+06    1.21e-03    1.98e+00   2.17e-01   1.04e+00  1.97e+08        1    4.81e+00    5.84e+01
#   10  2.196611e+06    6.88e-06    4.86e-01   1.32e-02   1.09e+00  5.90e+08        1    5.61e+00    6.40e+01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2226034
#    Parameters : 395357
#    Iterations : 11
#          Time : 64.1931 [s]
#  Initial cost : 0.998127 [px]
#    Final cost : 0.993369 [px]
#   Termination : Convergence
#
#   => Completed observations: 4632
#   => Merged observations: 2726
#   => Filtered observations: 1713
#   => Changed observations: 0.008150
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.212629e+06    0.00e+00    5.52e+04   0.00e+00   0.00e+00  1.00e+04        0    1.52e+00    7.12e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 4.7383e+08
#     Nonzeros in L:       6.6649e+05
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       1.5
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 4.7383e+08
#         nnz(L):     6.6649e+05
#   OK
#    1  2.204675e+06    7.95e+03    4.03e+02   4.18e+00   1.00e+00  3.00e+04        1    7.80e+00    1.49e+01
#    2  2.204663e+06    1.23e+01    3.56e+02   1.13e+00   1.10e+00  9.00e+04        1    6.10e+00    2.10e+01
#    3  2.204661e+06    1.87e+00    9.55e+01   5.05e-01   1.11e+00  2.70e+05        1    4.90e+00    2.59e+01
#    4  2.204660e+06    4.98e-01    4.21e+01   1.04e+00   1.06e+00  8.10e+05        1    6.44e+00    3.24e+01
#    5  2.204660e+06    5.95e-01    9.69e+01   2.37e+00   1.01e+00  2.43e+06        1    4.82e+00    3.72e+01
#    6  2.204659e+06    5.36e-01    2.16e+02   3.49e+00   9.99e-01  7.29e+06        1    5.43e+00    4.26e+01
#    7  2.204659e+06    1.59e-01    1.14e+02   2.51e+00   1.00e+00  2.19e+07        1    5.88e+00    4.85e+01
#    8  2.204659e+06    1.03e-02    9.43e+00   7.14e-01   1.02e+00  6.56e+07        1    4.88e+00    5.34e+01
#    9  2.204659e+06    1.41e-04    1.28e+00   7.71e-02   1.06e+00  1.97e+08        1    6.42e+00    5.98e+01
#   10  2.204659e+06    1.89e-06    4.98e-01   4.79e-03   1.24e+00  5.90e+08        1    4.91e+00    6.47e+01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 2231866
#    Parameters : 394769
#    Iterations : 11
#          Time : 64.8491 [s]
#  Initial cost : 0.995681 [px]
#    Final cost : 0.993886 [px]
#   Termination : Convergence
#
#   => Completed observations: 2298
#   => Merged observations: 1170
#   => Filtered observations: 832
#   => Changed observations: 0.003853
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #12 (206)
# ==============================================================================
#
#   => Image sees 5168 / 7089 points
#
# Pose refinement report
# ----------------------
#     Residuals : 48972
#    Parameters : 6
#    Iterations : 22
#          Time : 1.01527 [s]
#  Initial cost : 0.888475 [px]
#    Final cost : 0.879095 [px]
#   Termination : Convergence
#
#   => Continued observations: 4689
#   => Added observations: 23464
#
# Bundle adjustment report
# ------------------------
#     Residuals : 674280
#    Parameters : 140360
#    Iterations : 26
#          Time : 10.5229 [s]
#  Initial cost : 0.987747 [px]
#    Final cost : 0.965324 [px]
#   Termination : No convergence
#
#   => Merged observations: 743
#   => Completed observations: 2437
#   => Filtered observations: 25996
#   => Changed observations: 0.085604
#
# Bundle adjustment report
# ------------------------
#     Residuals : 631580
#    Parameters : 132869
#    Iterations : 4
#          Time : 1.63103 [s]
#  Initial cost : 1.01995 [px]
#    Final cost : 1.00127 [px]
#   Termination : Convergence
#
#   => Merged observations: 2805
#   => Completed observations: 3292
#   => Filtered observations: 245
#   => Changed observations: 0.019945
#
# ==============================================================================
# Registering image #134 (207)
# ==============================================================================
#
#   => Image sees 6083 / 6977 points
#
# Pose refinement report
# ----------------------
#     Residuals : 90954
#    Parameters : 6
#    Iterations : 14
#          Time : 1.95722 [s]
#  Initial cost : 0.850621 [px]
#    Final cost : 0.843898 [px]
#   Termination : Convergence
#
#   => Continued observations: 5826
#   => Added observations: 17984
#
# Bundle adjustment report
# ------------------------
#     Residuals : 126962
#    Parameters : 18983
#    Iterations : 26
#          Time : 2.27506 [s]
#  Initial cost : 1.40857 [px]
#    Final cost : 1.35938 [px]
#   Termination : No convergence
#
#   => Merged observations: 538
#   => Completed observations: 1057
#   => Filtered observations: 16657
#   => Changed observations: 0.262396
#
# Bundle adjustment report
# ------------------------
#     Residuals : 97268
#    Parameters : 12152
#    Iterations : 3
#          Time : 0.253243 [s]
#  Initial cost : 1.0831 [px]
#    Final cost : 1.05174 [px]
#   Termination : Convergence
#
#   => Merged observations: 1222
#   => Completed observations: 1110
#   => Filtered observations: 127
#   => Changed observations: 0.045609
#
# ==============================================================================
# Registering image #133 (208)
# ==============================================================================
#
#   => Image sees 5953 / 7438 points
#
# Pose refinement report
# ----------------------
#     Residuals : 66802
#    Parameters : 6
#    Iterations : 15
#          Time : 1.11964 [s]
#  Initial cost : 0.854292 [px]
#    Final cost : 0.846985 [px]
#   Termination : Convergence
#
#   => Continued observations: 5494
#   => Added observations: 21072
#
# Bundle adjustment report
# ------------------------
#     Residuals : 129144
#    Parameters : 24290
#    Iterations : 26
#          Time : 2.42419 [s]
#  Initial cost : 1.47083 [px]
#    Final cost : 1.4119 [px]
#   Termination : No convergence
#
#   => Merged observations: 1177
#   => Completed observations: 1359
#   => Filtered observations: 17968
#   => Changed observations: 0.291060
#
# Bundle adjustment report
# ------------------------
#     Residuals : 98550
#    Parameters : 16931
#    Iterations : 3
#          Time : 0.340439 [s]
#  Initial cost : 1.04173 [px]
#    Final cost : 0.996805 [px]
#   Termination : Convergence
#
#   => Merged observations: 1539
#   => Completed observations: 1744
#   => Filtered observations: 99
#   => Changed observations: 0.062430
#
# ==============================================================================
# Registering image #185 (209)
# ==============================================================================
#
#   => Image sees 5719 / 6679 points
#
# Pose refinement report
# ----------------------
#     Residuals : 31062
#    Parameters : 6
#    Iterations : 16
#          Time : 0.756928 [s]
#  Initial cost : 0.859047 [px]
#    Final cost : 0.852654 [px]
#   Termination : Convergence
#
#   => Continued observations: 2435
#   => Added observations: 16558
#
# Bundle adjustment report
# ------------------------
#     Residuals : 94552
#    Parameters : 17360
#    Iterations : 26
#          Time : 2.22752 [s]
#  Initial cost : 1.55749 [px]
#    Final cost : 1.48053 [px]
#   Termination : No convergence
#
#   => Merged observations: 358
#   => Completed observations: 772
#   => Filtered observations: 14541
#   => Changed observations: 0.291885
#
# Bundle adjustment report
# ------------------------
#     Residuals : 80930
#    Parameters : 9440
#    Iterations : 4
#          Time : 0.262985 [s]
#  Initial cost : 1.05276 [px]
#    Final cost : 1.01784 [px]
#   Termination : Convergence
#
#   => Merged observations: 833
#   => Completed observations: 846
#   => Filtered observations: 48
#   => Changed observations: 0.036225
#
# ==============================================================================
# Registering image #76 (210)
# ==============================================================================
#
#   => Image sees 4833 / 6979 points
#
# Pose refinement report
# ----------------------
#     Residuals : 62976
#    Parameters : 6
#    Iterations : 27
#          Time : 1.77039 [s]
#  Initial cost : 0.899078 [px]
#    Final cost : 0.868929 [px]
#   Termination : Convergence
#
#   => Continued observations: 4486
#   => Added observations: 11880
#
# Bundle adjustment report
# ------------------------
#     Residuals : 99036
#    Parameters : 12581
#    Iterations : 26
#          Time : 1.83058 [s]
#  Initial cost : 1.38113 [px]
#    Final cost : 1.33278 [px]
#   Termination : No convergence
#
#   => Merged observations: 341
#   => Completed observations: 578
#   => Filtered observations: 11852
#   => Changed observations: 0.229142
#
# Bundle adjustment report
# ------------------------
#     Residuals : 84014
#    Parameters : 7235
#    Iterations : 3
#          Time : 0.256233 [s]
#  Initial cost : 1.05352 [px]
#    Final cost : 1.03292 [px]
#   Termination : Convergence
#
#   => Merged observations: 1004
#   => Completed observations: 601
#   => Filtered observations: 53
#   => Changed observations: 0.033675
#
# ==============================================================================
# Registering image #220 (211)
# ==============================================================================
#
#   => Image sees 6570 / 8149 points
#
# Pose refinement report
# ----------------------
#     Residuals : 88262
#    Parameters : 6
#    Iterations : 16
#          Time : 1.61504 [s]
#  Initial cost : 0.910583 [px]
#    Final cost : 0.888063 [px]
#   Termination : Convergence
#
#   => Continued observations: 6037
#   => Added observations: 37605
#
# Bundle adjustment report
# ------------------------
#     Residuals : 177272
#    Parameters : 27722
#    Iterations : 26
#          Time : 3.79779 [s]
#  Initial cost : 1.78951 [px]
#    Final cost : 1.7282 [px]
#   Termination : No convergence
#
#   => Merged observations: 77
#   => Completed observations: 1794
#   => Filtered observations: 35813
#   => Changed observations: 0.403750
#
# Bundle adjustment report
# ------------------------
#     Residuals : 111606
#    Parameters : 18155
# ...
# Training progress:  88%|████████▊ | 5290/6000 [09:41<01:22,  8.63it/s, Loss=0.2062244, Depth Loss=0.0000000]
# Training progress:  88%|████████▊ | 5300/6000 [09:41<01:20,  8.66it/s, Loss=0.2062244, Depth Loss=0.0000000]
# Training progress:  88%|████████▊ | 5300/6000 [09:42<01:20,  8.66it/s, Loss=0.1447259, Depth Loss=0.0000000]
# Training progress:  88%|████████▊ | 5310/6000 [09:42<01:18,  8.76it/s, Loss=0.1447259, Depth Loss=0.0000000]
# Training progress:  88%|████████▊ | 5310/6000 [09:43<01:18,  8.76it/s, Loss=0.1626231, Depth Loss=0.0000000]
# Training progress:  89%|████████▊ | 5320/6000 [09:43<01:19,  8.54it/s, Loss=0.1626231, Depth Loss=0.0000000]
# Training progress:  89%|████████▊ | 5320/6000 [09:44<01:19,  8.54it/s, Loss=0.1374579, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5330/6000 [09:44<01:19,  8.47it/s, Loss=0.1374579, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5330/6000 [09:45<01:19,  8.47it/s, Loss=0.1852826, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5340/6000 [09:45<01:17,  8.54it/s, Loss=0.1852826, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5340/6000 [09:46<01:17,  8.54it/s, Loss=0.1414050, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5350/6000 [09:46<01:16,  8.50it/s, Loss=0.1414050, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5350/6000 [09:48<01:16,  8.50it/s, Loss=0.1831985, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5360/6000 [09:48<01:16,  8.36it/s, Loss=0.1831985, Depth Loss=0.0000000]
# Training progress:  89%|████████▉ | 5360/6000 [09:49<01:16,  8.36it/s, Loss=0.1885982, Depth Loss=0.0000000]
# Training progress:  90%|████████▉ | 5370/6000 [09:49<01:15,  8.35it/s, Loss=0.1885982, Depth Loss=0.0000000]
# Training progress:  90%|████████▉ | 5370/6000 [09:50<01:15,  8.35it/s, Loss=0.1400640, Depth Loss=0.0000000]
# Training progress:  90%|████████▉ | 5380/6000 [09:50<01:13,  8.46it/s, Loss=0.1400640, Depth Loss=0.0000000]
# Training progress:  90%|████████▉ | 5380/6000 [09:51<01:13,  8.46it/s, Loss=0.1654131, Depth Loss=0.0000000]
# Training progress:  90%|████████▉ | 5390/6000 [09:51<01:12,  8.43it/s, Loss=0.1654131, Depth Loss=0.0000000]
# Training progress:  90%|████████▉ | 5390/6000 [09:52<01:12,  8.43it/s, Loss=0.1748908, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5400/6000 [09:52<01:10,  8.51it/s, Loss=0.1748908, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5400/6000 [09:54<01:10,  8.51it/s, Loss=0.1752135, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5410/6000 [09:54<01:10,  8.36it/s, Loss=0.1752135, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5410/6000 [09:55<01:10,  8.36it/s, Loss=0.1744643, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5420/6000 [09:55<01:09,  8.37it/s, Loss=0.1744643, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5420/6000 [09:56<01:09,  8.37it/s, Loss=0.2050068, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5430/6000 [09:56<01:07,  8.47it/s, Loss=0.2050068, Depth Loss=0.0000000]
# Training progress:  90%|█████████ | 5430/6000 [09:57<01:07,  8.47it/s, Loss=0.1524464, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5440/6000 [09:57<01:06,  8.45it/s, Loss=0.1524464, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5440/6000 [09:58<01:06,  8.45it/s, Loss=0.1781298, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5450/6000 [09:58<01:06,  8.22it/s, Loss=0.1781298, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5450/6000 [10:00<01:06,  8.22it/s, Loss=0.1603041, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5460/6000 [10:00<01:05,  8.26it/s, Loss=0.1603041, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5460/6000 [10:01<01:05,  8.26it/s, Loss=0.1781423, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5470/6000 [10:01<01:04,  8.25it/s, Loss=0.1781423, Depth Loss=0.0000000]
# Training progress:  91%|█████████ | 5470/6000 [10:02<01:04,  8.25it/s, Loss=0.1989764, Depth Loss=0.0000000]
# Training progress:  91%|█████████▏| 5480/6000 [10:02<01:04,  8.11it/s, Loss=0.1989764, Depth Loss=0.0000000]
# Training progress:  91%|█████████▏| 5480/6000 [10:03<01:04,  8.11it/s, Loss=0.1665691, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5490/6000 [10:03<01:02,  8.14it/s, Loss=0.1665691, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5490/6000 [10:05<01:02,  8.14it/s, Loss=0.1515335, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5500/6000 [10:05<01:01,  8.17it/s, Loss=0.1515335, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5500/6000 [10:06<01:01,  8.17it/s, Loss=0.2143616, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5510/6000 [10:06<00:59,  8.21it/s, Loss=0.2143616, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5510/6000 [10:07<00:59,  8.21it/s, Loss=0.1998435, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5520/6000 [10:07<00:58,  8.21it/s, Loss=0.1998435, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5520/6000 [10:08<00:58,  8.21it/s, Loss=0.2188988, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5530/6000 [10:08<00:57,  8.20it/s, Loss=0.2188988, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5530/6000 [10:09<00:57,  8.20it/s, Loss=0.1953086, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5540/6000 [10:09<00:55,  8.28it/s, Loss=0.1953086, Depth Loss=0.0000000]
# Training progress:  92%|█████████▏| 5540/6000 [10:11<00:55,  8.28it/s, Loss=0.1474084, Depth Loss=0.0000000]
# Training progress:  92%|█████████▎| 5550/6000 [10:11<00:53,  8.37it/s, Loss=0.1474084, Depth Loss=0.0000000]
# Training progress:  92%|█████████▎| 5550/6000 [10:12<00:53,  8.37it/s, Loss=0.1990496, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5560/6000 [10:12<00:52,  8.32it/s, Loss=0.1990496, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5560/6000 [10:13<00:52,  8.32it/s, Loss=0.1667281, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5570/6000 [10:13<00:51,  8.31it/s, Loss=0.1667281, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5570/6000 [10:14<00:51,  8.31it/s, Loss=0.1803382, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5580/6000 [10:14<00:51,  8.13it/s, Loss=0.1803382, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5580/6000 [10:15<00:51,  8.13it/s, Loss=0.1465887, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5590/6000 [10:15<00:49,  8.22it/s, Loss=0.1465887, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5590/6000 [10:17<00:49,  8.22it/s, Loss=0.1452190, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5600/6000 [10:17<00:47,  8.36it/s, Loss=0.1452190, Depth Loss=0.0000000]
# Training progress:  93%|█████████▎| 5600/6000 [10:18<00:47,  8.36it/s, Loss=0.1492132, Depth Loss=0.0000000]
# Training progress:  94%|█████████▎| 5610/6000 [10:18<00:46,  8.42it/s, Loss=0.1492132, Depth Loss=0.0000000]
# Training progress:  94%|█████████▎| 5610/6000 [10:19<00:46,  8.42it/s, Loss=0.1463493, Depth Loss=0.0000000]
# Training progress:  94%|█████████▎| 5620/6000 [10:19<00:44,  8.53it/s, Loss=0.1463493, Depth Loss=0.0000000]
# Training progress:  94%|█████████▎| 5620/6000 [10:20<00:44,  8.53it/s, Loss=0.1573436, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5630/6000 [10:20<00:43,  8.48it/s, Loss=0.1573436, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5630/6000 [10:21<00:43,  8.48it/s, Loss=0.1562577, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5640/6000 [10:21<00:42,  8.50it/s, Loss=0.1562577, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5640/6000 [10:22<00:42,  8.50it/s, Loss=0.1865904, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5650/6000 [10:22<00:40,  8.62it/s, Loss=0.1865904, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5650/6000 [10:23<00:40,  8.62it/s, Loss=0.1650331, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5660/6000 [10:23<00:39,  8.71it/s, Loss=0.1650331, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5660/6000 [10:25<00:39,  8.71it/s, Loss=0.1685897, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5670/6000 [10:25<00:39,  8.33it/s, Loss=0.1685897, Depth Loss=0.0000000]
# Training progress:  94%|█████████▍| 5670/6000 [10:26<00:39,  8.33it/s, Loss=0.1700377, Depth Loss=0.0000000]
# Training progress:  95%|█████████▍| 5680/6000 [10:26<00:38,  8.34it/s, Loss=0.1700377, Depth Loss=0.0000000]
# Training progress:  95%|█████████▍| 5680/6000 [10:27<00:38,  8.34it/s, Loss=0.2030695, Depth Loss=0.0000000]
# Training progress:  95%|█████████▍| 5690/6000 [10:27<00:37,  8.36it/s, Loss=0.2030695, Depth Loss=0.0000000]
# Training progress:  95%|█████████▍| 5690/6000 [10:28<00:37,  8.36it/s, Loss=0.1313777, Depth Loss=0.0000000]
# Training progress:  95%|█████████▌| 5700/6000 [10:28<00:34,  8.59it/s, Loss=0.1313777, Depth Loss=0.0000000]
# Training progress:  95%|█████████▌| 5700/6000 [10:30<00:34,  8.59it/s, Loss=0.1562235, Depth Loss=0.0000000]
# Training progress:  95%|█████████▌| 5710/6000 [10:30<00:34,  8.32it/s, Loss=0.1562235, Depth Loss=0.0000000]
# Training progress:  95%|█████████▌| 5710/6000 [10:31<00:34,  8.32it/s, Loss=0.1993736, Depth Loss=0.0000000]
# Training progress:  95%|█████████▌| 5720/6000 [10:31<00:33,  8.40it/s, Loss=0.1993736, Depth Loss=0.0000000]
# Training progress:  95%|█████████▌| 5720/6000 [10:32<00:33,  8.40it/s, Loss=0.2018383, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5730/6000 [10:32<00:32,  8.37it/s, Loss=0.2018383, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5730/6000 [10:33<00:32,  8.37it/s, Loss=0.1644900, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5740/6000 [10:33<00:30,  8.42it/s, Loss=0.1644900, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5740/6000 [10:34<00:30,  8.42it/s, Loss=0.1795801, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5750/6000 [10:34<00:29,  8.38it/s, Loss=0.1795801, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5750/6000 [10:36<00:29,  8.38it/s, Loss=0.1729787, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5760/6000 [10:36<00:28,  8.35it/s, Loss=0.1729787, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5760/6000 [10:37<00:28,  8.35it/s, Loss=0.1850190, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5770/6000 [10:37<00:28,  8.17it/s, Loss=0.1850190, Depth Loss=0.0000000]
# Training progress:  96%|█████████▌| 5770/6000 [10:38<00:28,  8.17it/s, Loss=0.1665204, Depth Loss=0.0000000]
# Training progress:  96%|█████████▋| 5780/6000 [10:38<00:27,  8.14it/s, Loss=0.1665204, Depth Loss=0.0000000]
# Training progress:  96%|█████████▋| 5780/6000 [10:39<00:27,  8.14it/s, Loss=0.2128551, Depth Loss=0.0000000]
# Training progress:  96%|█████████▋| 5790/6000 [10:39<00:25,  8.08it/s, Loss=0.2128551, Depth Loss=0.0000000]
# Training progress:  96%|█████████▋| 5790/6000 [10:41<00:25,  8.08it/s, Loss=0.1838856, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5800/6000 [10:41<00:24,  8.11it/s, Loss=0.1838856, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5800/6000 [10:42<00:24,  8.11it/s, Loss=0.1203390, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5810/6000 [10:42<00:23,  8.18it/s, Loss=0.1203390, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5810/6000 [10:43<00:23,  8.18it/s, Loss=0.1807686, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5820/6000 [10:43<00:21,  8.31it/s, Loss=0.1807686, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5820/6000 [10:44<00:21,  8.31it/s, Loss=0.2208921, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5830/6000 [10:44<00:20,  8.39it/s, Loss=0.2208921, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5830/6000 [10:45<00:20,  8.39it/s, Loss=0.1738257, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5840/6000 [10:45<00:19,  8.19it/s, Loss=0.1738257, Depth Loss=0.0000000]
# Training progress:  97%|█████████▋| 5840/6000 [10:46<00:19,  8.19it/s, Loss=0.1438059, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5850/6000 [10:46<00:18,  8.33it/s, Loss=0.1438059, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5850/6000 [10:48<00:18,  8.33it/s, Loss=0.1404028, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5860/6000 [10:48<00:16,  8.42it/s, Loss=0.1404028, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5860/6000 [10:49<00:16,  8.42it/s, Loss=0.1973775, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5870/6000 [10:49<00:15,  8.38it/s, Loss=0.1973775, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5870/6000 [10:50<00:15,  8.38it/s, Loss=0.1623694, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5880/6000 [10:50<00:14,  8.38it/s, Loss=0.1623694, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5880/6000 [10:51<00:14,  8.38it/s, Loss=0.2010772, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5890/6000 [10:51<00:13,  8.39it/s, Loss=0.2010772, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5890/6000 [10:52<00:13,  8.39it/s, Loss=0.1314353, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5900/6000 [10:52<00:11,  8.36it/s, Loss=0.1314353, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5900/6000 [10:54<00:11,  8.36it/s, Loss=0.1846567, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5910/6000 [10:54<00:10,  8.28it/s, Loss=0.1846567, Depth Loss=0.0000000]
# Training progress:  98%|█████████▊| 5910/6000 [10:55<00:10,  8.28it/s, Loss=0.1681812, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 5920/6000 [10:55<00:09,  8.30it/s, Loss=0.1681812, Depth Loss=0.0000000]
# Training progress:  99%|█████████▊| 5920/6000 [10:56<00:09,  8.30it/s, Loss=0.1418598, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5930/6000 [10:56<00:08,  8.40it/s, Loss=0.1418598, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5930/6000 [10:57<00:08,  8.40it/s, Loss=0.1544008, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5940/6000 [10:57<00:07,  8.37it/s, Loss=0.1544008, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5940/6000 [10:58<00:07,  8.37it/s, Loss=0.1740023, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5950/6000 [10:58<00:05,  8.47it/s, Loss=0.1740023, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5950/6000 [11:00<00:05,  8.47it/s, Loss=0.1483969, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5960/6000 [11:00<00:04,  8.49it/s, Loss=0.1483969, Depth Loss=0.0000000]
# Training progress:  99%|█████████▉| 5960/6000 [11:01<00:04,  8.49it/s, Loss=0.2018568, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 5970/6000 [11:01<00:03,  8.45it/s, Loss=0.2018568, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 5970/6000 [11:02<00:03,  8.45it/s, Loss=0.1532527, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 5980/6000 [11:02<00:02,  8.35it/s, Loss=0.1532527, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 5980/6000 [11:03<00:02,  8.35it/s, Loss=0.2004740, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 5990/6000 [11:03<00:01,  8.25it/s, Loss=0.2004740, Depth Loss=0.0000000]
# Training progress: 100%|█████████▉| 5990/6000 [11:04<00:01,  8.25it/s, Loss=0.1659179, Depth Loss=0.0000000]
# Training progress: 100%|██████████| 6000/6000 [11:04<00:00,  8.20it/s, Loss=0.1659179, Depth Loss=0.0000000]
# Training progress: 100%|██████████| 6000/6000 [11:04<00:00,  9.02it/s, Loss=0.1659179, Depth Loss=0.0000000]
#
#
# ✓ Training complete!
#   PLY file: /content/output/gs_output/point_cloud/iteration_6000/point_cloud.ply
#   Size: 110.53 MB
#
# ======================================================================
# ✅ Full Pipeline Successfully Completed!
# ======================================================================
#
# Gaussian Splatting model saved at: /content/output/gs_output

# %%
import torch
torch.cuda.empty_cache()

# %%
print('Congratulation! Successsfully Completed!')
# Out:
# Congratulation! Successsfully Completed!
