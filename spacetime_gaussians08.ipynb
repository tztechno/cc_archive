# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/spacetime_gaussians08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
############ 20251129 00:48 #### coffee martini 10 frames #####################

# %%
# !git clone https://github.com/tztechno/SpacetimeGaussians.git --recursive
# Out:
# fatal: destination path 'SpacetimeGaussians' already exists and is not an empty directory.

# %%
import os
os.chdir('SpacetimeGaussians')

# %%
#use setup_fixed1.sh
# !bash script/setup_fixed5.sh
# Out:
# === Kaggle環境セットアップ開始 ===
# プロジェクトルート: /content/SpacetimeGaussians
# --- 1. システムパッケージの更新 ---
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,491 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,008 kB]
# Get:15 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,222 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,835 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,290 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,539 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,596 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,876 kB]
# Fetched 37.5 MB in 4s (10.5 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# --- 2. COLMAPとOpenGLライブラリのインストール ---
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libgl1-mesa-dri is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgl1-mesa-dri set to manually installed.
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libamd2 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libcamd2 libccolamd2 libceres2
#   libcholmod3 libcolamd2 libcxsparse3 libdouble-conversion3 libevdev2
#   libfreeimage3 libgflags2.2 libglew2.2 libgoogle-glog0v5 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libilmbase25 libinput-bin
#   libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1 libopenexr25 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libraw20
#   librsvg2-common libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common
#   libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcomposite1
#   libxkbcommon-x11-0 libxtst6 mesa-utils-bin qt5-gtk-platformtheme
#   qttranslations5-l10n session-migration
# Suggested packages:
#   glew-utils gvfs qt5-image-formats-plugins qtwayland5
# The following NEW packages will be installed:
#   at-spi2-core colmap gsettings-desktop-schemas libamd2 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libcamd2 libccolamd2 libceres2
#   libcholmod3 libcolamd2 libcxsparse3 libdouble-conversion3 libegl1-mesa
#   libevdev2 libfreeimage3 libgflags2.2 libglew2.2 libgoogle-glog0v5 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libilmbase25 libinput-bin
#   libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1 libopenexr25 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libraw20
#   librsvg2-common libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common
#   libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcomposite1
#   libxkbcommon-x11-0 libxtst6 mesa-utils mesa-utils-bin qt5-gtk-platformtheme
#   qttranslations5-l10n session-migration
# 0 upgraded, 62 newly installed, 0 to remove and 55 not upgraded.
# Need to get 23.6 MB of archives.
# After this operation, 89.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdouble-conversion3 amd64 3.1.7-4 [39.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libamd2 amd64 1:5.10.1+dfsg-4build1 [21.6 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcamd2 amd64 1:5.10.1+dfsg-4build1 [23.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libccolamd2 amd64 1:5.10.1+dfsg-4build1 [25.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis5 amd64 5.1.0.dfsg-7build2 [181 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcholmod3 amd64 1:5.10.1+dfsg-4build1 [346 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcxsparse3 amd64 1:5.10.1+dfsg-4build1 [70.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags2.2 amd64 2.2.2-2 [78.1 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog0v5 amd64 0.5.0+really0.4.0-2 [60.3 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspqr2 amd64 1:5.10.1+dfsg-4build1 [71.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres2 amd64 2.0.0+dfsg1-5 [834 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraw20 amd64 0.20.2-2ubuntu2.22.04.2 [342 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libfreeimage3 amd64 3.18.0+ds2-6ubuntu5.1 [294 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew2.2 amd64 2.2.0-4 [196 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 colmap amd64 3.7-2 [2,998 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libegl1-mesa amd64 23.0.4-0ubuntu1~22.04.1 [6,484 B]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2.2 [69.6 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 mesa-utils-bin amd64 8.4.0-1ubuntu1 [53.8 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 mesa-utils amd64 8.4.0-1ubuntu1 [1,065 kB]
# Fetched 23.6 MB in 3s (7,954 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libdouble-conversion3:amd64.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../00-libdouble-conversion3_3.1.7-4_amd64.deb ...
# Unpacking libdouble-conversion3:amd64 (3.1.7-4) ...
# Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../01-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../02-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../03-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../04-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../05-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../06-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../07-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../08-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../09-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../10-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../11-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../12-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../13-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../14-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../15-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../16-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../17-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../18-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../19-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../20-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../21-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../22-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../23-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../24-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../25-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../26-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../27-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../28-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../29-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../30-libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../31-libcamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../32-libccolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../33-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../34-libmetis5_5.1.0.dfsg-7build2_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../35-libcholmod3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../36-libcxsparse3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../37-libgflags2.2_2.2.2-2_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-2) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../38-libgoogle-glog0v5_0.5.0+really0.4.0-2_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../39-libspqr2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libceres2.
# Preparing to unpack .../40-libceres2_2.0.0+dfsg1-5_amd64.deb ...
# Unpacking libceres2 (2.0.0+dfsg1-5) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../41-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../42-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../43-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libraw20:amd64.
# Preparing to unpack .../44-libraw20_0.20.2-2ubuntu2.22.04.2_amd64.deb ...
# Unpacking libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Selecting previously unselected package libfreeimage3:amd64.
# Preparing to unpack .../45-libfreeimage3_3.18.0+ds2-6ubuntu5.1_amd64.deb ...
# Unpacking libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Selecting previously unselected package libglew2.2:amd64.
# Preparing to unpack .../46-libglew2.2_2.2.0-4_amd64.deb ...
# Unpacking libglew2.2:amd64 (2.2.0-4) ...
# Selecting previously unselected package colmap.
# Preparing to unpack .../47-colmap_3.7-2_amd64.deb ...
# Unpacking colmap (3.7-2) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../48-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../49-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../50-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libegl1-mesa:amd64.
# Preparing to unpack .../51-libegl1-mesa_23.0.4-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking libegl1-mesa:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../52-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../53-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../54-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../55-libgtk-3-bin_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../56-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../57-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package mesa-utils-bin:amd64.
# Preparing to unpack .../58-mesa-utils-bin_8.4.0-1ubuntu1_amd64.deb ...
# Unpacking mesa-utils-bin:amd64 (8.4.0-1ubuntu1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../59-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../60-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Selecting previously unselected package mesa-utils.
# Preparing to unpack .../61-mesa-utils_8.4.0-1ubuntu1_amd64.deb ...
# Unpacking mesa-utils (8.4.0-1ubuntu1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libdouble-conversion3:amd64 (3.1.7-4) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libegl1-mesa:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up mesa-utils-bin:amd64 (8.4.0-1ubuntu1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Setting up libglew2.2:amd64 (2.2.0-4) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libgflags2.2 (2.2.2-2) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up mesa-utils (8.4.0-1ubuntu1) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Setting up libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libceres2 (2.0.0+dfsg1-5) ...
# Setting up colmap (3.7-2) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.6) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# --- 3. Pipツールのアップグレード ---
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 39.0 MB/s eta 0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.9 MB/s eta 0:00:00
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-25.3 setuptools-80.9.0
# --- 4. PyTorchの確認 ---
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# CUDA version: 12.6
# --- 5. ビルド用パッケージのインストール ---
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (25.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# Installing collected packages: ninja
# Successfully installed ninja-1.13.0
# --- 6. 基本的なPythonパッケージのインストール ---
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (8.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Collecting kornia
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting plyfile
#   Downloading plyfile-1.1.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Collecting kornia_rs>=0.1.9 (from kornia)
#   Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.4 MB/s  0:00:00
# Downloading plyfile-1.1.3-py3-none-any.whl (36 kB)
# Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 25.2 MB/s  0:00:00
# Installing collected packages: plyfile, kornia_rs, kornia
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [kornia]
# Successfully installed kornia-0.8.2 kornia_rs-0.1.10 plyfile-1.1.3
# --- 7. CUDA環境変数の設定 ---
# --- 8. Simple-KNNのインストール ---
#     simple-knn-main.zip を thirdparty フォルダから読み込みます
# Processing /content/SpacetimeGaussians/simple-knn-tmp/simple-knn-main
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: simple_knn
#   Building wheel for simple_knn (pyproject.toml) ... done
#   Created wheel for simple_knn: filename=simple_knn-1.0.0-cp312-cp312-linux_x86_64.whl size=3511003 sha256=9b4bf18f1f7e70acdc6cd42f5619804cd9fd22b639b1f95bd895cfb4f8d5787b
#   Stored in directory: /root/.cache/pip/wheels/fd/fc/26/ed888d1a6741e7fc33c502be1fa69fa6bebbd4f11a0e57794c
# Successfully built simple_knn
# Installing collected packages: simple_knn
# Successfully installed simple_knn-1.0.0
# --- Simple-KNN installation completed ---
# --- 9. MMCVのビルドとインストール (時間がかかります) ---
#     thirdparty/mmcv が見つかりました
#     MMCVをビルドしてインストールします...
# Using pip 25.3 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Obtaining file:///content/SpacetimeGaussians/thirdparty/mmcv
#   Running command Checking if build backend supports build_editable
#   Checking if build backend supports build_editable ... done
#   Running command Preparing editable metadata (pyproject.toml)
#   <string>:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   /usr/local/lib/python3.12/dist-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: Apache Software License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running dist_info
#   creating /tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info
#   writing /tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info/requires.txt
#   writing top-level names to /tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file '/tmp/pip-modern-metadata-zjqqvbto/mmcv.egg-info/SOURCES.txt'
#   creating '/tmp/pip-modern-metadata-zjqqvbto/mmcv-2.2.0.dist-info'
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:135: SetuptoolsDeprecationWarning: bdist_wheel.universal is deprecated
#   !!
#
#           ********************************************************************************
#           With Python 2.7 end-of-life, support for building universal wheels
#           (i.e., wheels that support both Python 2 and Python 3)
#           is being obviated.
#           Please discontinue using this option, or if you still need it,
#           file an issue with pypa/setuptools describing your use case.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#           ********************************************************************************
#
#   !!
#     self.finalize_options()
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting addict (from mmcv==2.2.0)
#   Obtaining dependency information for addict from https://files.pythonhosted.org/packages/6a/00/b08f23b7d7e1e14ce01419a467b583edbb93c6cdb8654e54a9cc579cd61f/addict-2.4.0-py3-none-any.whl.metadata
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv==2.2.0)
#   Obtaining dependency information for mmengine>=0.3.0 from https://files.pythonhosted.org/packages/98/8e/f98332248aad102511bea4ae19c0ddacd2f0a994f3ca4c82b7a369e0af8b/mmengine-0.10.7-py3-none-any.whl.metadata
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (25.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (6.0.3)
# Collecting yapf (from mmcv==2.2.0)
#   Obtaining dependency information for yapf from https://files.pythonhosted.org/packages/37/81/6acd6601f61e31cfb8729d3da6d5df966f80f374b78eff83760714487338/yapf-0.43.0-py3-none-any.whl.metadata
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (3.2.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (4.12.0.88)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.2.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.2.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.2.0) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmcv==2.2.0) (4.5.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
# Building wheels for collected packages: mmcv
#   Running command Building editable for mmcv (pyproject.toml)
#   <string>:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   /usr/local/lib/python3.12/dist-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: Apache Software License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running editable_wheel
#   creating /tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info
#   writing /tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info/requires.txt
#   writing top-level names to /tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file '/tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv.egg-info/SOURCES.txt'
#   creating '/tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv-2.2.0.dist-info'
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:135: SetuptoolsDeprecationWarning: bdist_wheel.universal is deprecated
#   !!
#
#           ********************************************************************************
#           With Python 2.7 end-of-life, support for building universal wheels
#           (i.e., wheels that support both Python 2 and Python 3)
#           is being obviated.
#           Please discontinue using this option, or if you still need it,
#           file an issue with pypa/setuptools describing your use case.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#           ********************************************************************************
#
#   !!
#     self.finalize_options()
#   creating /tmp/pip-ephem-wheel-cache-7g68ys5h/wheels/e7/78/7e/f014b819bf2afa2042b415d890a940d489b2bc480bafe87505/tmp3m0hz0_z/.tmp-ik94d2pl/mmcv-2.2.0.dist-info/WHEEL
#   running build_py
#   running build_ext
#   W1128 12:39:57.180000 4812 torch/utils/cpp_extension.py:521] The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.6). Most likely this shouldn't be a problem.
#   W1128 12:39:57.180000 4812 torch/utils/cpp_extension.py:531] There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   building 'mmcv._ext' extension
#   creating /tmp/tmp4furea9u.build-temp/mmcv/ops/csrc/pytorch
#   creating /tmp/tmp4furea9u.build-temp/mmcv/ops/csrc/pytorch/cpu
#   creating /tmp/tmp4furea9u.build-temp/mmcv/ops/csrc/pytorch/cuda
# ...
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:185:941: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     185 |           CudaRasterizer::Rasterizer::backward(P, degree, M, R,
#         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:185:985: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     185 |           CudaRasterizer::Rasterizer::backward(P, degree, M, R,
#         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:185:1027: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     185 |           CudaRasterizer::Rasterizer::backward(P, degree, M, R,
#         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:185:1066: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     185 |           CudaRasterizer::Rasterizer::backward(P, degree, M, R,
#         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:185:1109: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     185 |           CudaRasterizer::Rasterizer::backward(P, degree, M, R,
#         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:185:1155: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     185 |           CudaRasterizer::Rasterizer::backward(P, degree, M, R,
#         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu: In function ‘at::Tensor markVisible(at::Tensor&, at::Tensor&, at::Tensor&)’:
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:231:87: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     231 |         CudaRasterizer::Rasterizer::markVisible(P,
#         |                                                                                       ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:231:130: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     231 |         CudaRasterizer::Rasterizer::markVisible(P,
#         |                                                                                                                                  ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:231:173: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     231 |         CudaRasterizer::Rasterizer::markVisible(P,
#         |                                                                                                                                                                             ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   /content/SpacetimeGaussians/thirdparty/gaussian_splatting/submodules/forward_full/rasterize_points.cu:231:212: warning: ‘T* at::Tensor::data() const [with T = bool]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#     231 |         CudaRasterizer::Rasterizer::markVisible(P,
#         |                                                                                                                                                                                                                    ^
#   /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#     247 |   T * data() const {
#         | ^ ~~
#   creating /tmp/tmprzys0xoj.build-lib/forward_full
#   x86_64-linux-gnu-g++ -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /tmp/tmpbuyu3qe3.build-temp/cuda_rasterizer/backward.o /tmp/tmpbuyu3qe3.build-temp/cuda_rasterizer/forward.o /tmp/tmpbuyu3qe3.build-temp/cuda_rasterizer/rasterizer_impl.o /tmp/tmpbuyu3qe3.build-temp/ext.o /tmp/tmpbuyu3qe3.build-temp/rasterize_points.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o /tmp/tmprzys0xoj.build-lib/forward_full/_C.cpython-312-x86_64-linux-gnu.so
#   copying /tmp/tmprzys0xoj.build-lib/forward_full/_C.cpython-312-x86_64-linux-gnu.so -> forward_full
#   Editable install will be performed using a meta path finder.
#
#   Options like `package-data`, `include/exclude-package-data` or
#   `packages.find.exclude/include` may have no effect.
#
#   adding '__editable___forward_full_0_0_0_finder.py'
#   adding '__editable__.forward_full-0.0.0.pth'
#   creating '/tmp/pip-ephem-wheel-cache-ug_v_gnh/wheels/25/44/92/a609d08793ac256ff288d02a57a67f3a2bfe73e735fb28e506/tmp9w4u08fv/.tmp-azfz2tsf/forward_full-0.0.0-0.editable-cp312-cp312-linux_x86_64.whl' and adding '/tmp/tmpthpmcfzdforward_full-0.0.0-0.editable-cp312-cp312-linux_x86_64.whl' to it
#   adding 'forward_full-0.0.0.dist-info/METADATA'
#   adding 'forward_full-0.0.0.dist-info/WHEEL'
#   adding 'forward_full-0.0.0.dist-info/top_level.txt'
#   adding 'forward_full-0.0.0.dist-info/RECORD'
#   /usr/local/lib/python3.12/dist-packages/setuptools/command/editable_wheel.py:351: InformationOnly: Editable installation.
#   !!
#
#           ********************************************************************************
#           Please be careful with folders in your working directory with the same
#           name as your package as they may take precedence during imports.
#           ********************************************************************************
#
#   !!
#     with strategy, WheelFile(wheel_path, "w") as wheel_obj:
#   Building editable for forward_full (pyproject.toml) ... done
#   Created wheel for forward_full: filename=forward_full-0.0.0-0.editable-cp312-cp312-linux_x86_64.whl size=2720 sha256=27d64d5d7c6fe9ef769186e1f52eac5220d3833296b8644f1baa45c80f6ae203
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ug_v_gnh/wheels/25/44/92/a609d08793ac256ff288d02a57a67f3a2bfe73e735fb28e506
# Successfully built forward_full
# Installing collected packages: forward_full
# Successfully installed forward_full-0.0.0
# --- 12. NumPy互換性の確認と修正 ---
# NumPy version: 2.0.2
#     pre_colmap.py の修正...
#     pre_colmap_fixed1.py の修正...
# --- 13. OpenGL/Qt環境変数の設定 ---
#
# === セットアップ完了 ===
# インストールされたパッケージの確認:
# - PyTorch: 2.9.0+cu126
# - CUDA available: True
# - CUDA version: 12.6
# - OpenCV: 4.12.0
#
# 実行前に以下の環境変数を設定してください:
#
# import os
# os.environ['QT_QPA_PLATFORM'] = 'offscreen'
# os.environ['LIBGL_ALWAYS_SOFTWARE'] = '1'
#
# 準備完了です!

# %%
print('all libraries installed')
# Out:
# all libraries installed

# %%
########################load data#################################################

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
SOURCE_PATH='/content/drive/MyDrive/your_folder/coffee_martini'
DEST_PATH='/content/SpacetimeGaussians/source'
shutil.copytree(SOURCE_PATH, DEST_PATH, dirs_exist_ok=True)
# Out:
# '/content/SpacetimeGaussians/source'

# %%
###################process data######################################################

# %%
import os
os.environ['QT_QPA_PLATFORM'] = 'offscreen'
os.environ['LIBGL_ALWAYS_SOFTWARE'] = '1'

# %%
# !xvfb-run -a -s "-screen 0 1280x1024x24" python script/pre_n3d_fixed1.py --videopath source --startframe 0 --endframe 10
# Out:
# params: startframe=0 - endframe=10 - downscale=1 - videopath=source
# start extracting 300 frames from videos
# Extract frames from videos: 100% 18/18 [26:38<00:00, 88.81s/it]
# start preparing colmap image input
# start preparing colmap database input
# convertdynerftocolmapdb: 100% 10/10 [00:01<00:00,  5.30it/s]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/18]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4330
# Processed file [2/18]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.097, LON=1.144, ALT=2.128
#   Features:        4216
# Processed file [3/18]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
#   Camera:          #3 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-4.342, LON=1.139, ALT=1.682
#   Features:        4271
# Processed file [4/18]
#   Name:            cam04.png
#   Dimensions:      2704 x 2028
#   Camera:          #4 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.518, LON=1.035, ALT=0.979
#   Features:        4261
# Processed file [5/18]
#   Name:            cam05.png
#   Dimensions:      2704 x 2028
#   Camera:          #5 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.508, LON=1.082, ALT=0.534
#   Features:        4328
# Processed file [6/18]
#   Name:            cam06.png
#   Dimensions:      2704 x 2028
#   Camera:          #6 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.552, LON=1.128, ALT=0.368
#   Features:        4674
# Processed file [7/18]
#   Name:            cam07.png
#   Dimensions:      2704 x 2028
#   Camera:          #7 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=1.537, LON=1.137, ALT=0.711
#   Features:        5022
# Processed file [8/18]
#   Name:            cam08.png
#   Dimensions:      2704 x 2028
#   Camera:          #8 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.475, LON=1.116, ALT=1.272
#   Features:        5614
# Processed file [9/18]
#   Name:            cam09.png
#   Dimensions:      2704 x 2028
#   Camera:          #9 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=3.498, LON=1.143, ALT=1.151
#   Features:        6171
# Processed file [10/18]
#   Name:            cam10.png
#   Dimensions:      2704 x 2028
#   Camera:          #10 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.301, LON=1.195, ALT=1.406
#   Features:        6034
# Processed file [11/18]
#   Name:            cam11.png
#   Dimensions:      2704 x 2028
#   Camera:          #11 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-6.146, LON=-1.749, ALT=0.872
#   Features:        4163
# Processed file [12/18]
#   Name:            cam12.png
#   Dimensions:      2704 x 2028
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3821
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3891
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3926
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        4087
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4611
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        4964
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5532
# Elapsed time: 0.640 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1] in 386.735s
# Elapsed time: 6.448 [minutes]
#
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 18 in 0.000s
# Loading matches... 150 in 0.001s
# Loading images... 18 in 0.006s (connected 18)
# Building correspondence graph... in 0.010s (ignored 0)
#
# Elapsed time: 0.000 [minutes]
#
#
# ==============================================================================
# Triangulating image #1 (0)
# ==============================================================================
#
#   => Image sees 0 / 1842 points
#   => Triangulated 1339 points
#
# ==============================================================================
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 137 / 1421 points
#   => Triangulated 693 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 710 / 1669 points
#   => Triangulated 301 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1043 / 2039 points
#   => Triangulated 480 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1361 / 2228 points
#   => Triangulated 235 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 916 / 1780 points
#   => Triangulated 281 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 783 / 1921 points
#   => Triangulated 342 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 763 / 1940 points
#   => Triangulated 266 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 652 / 1929 points
#   => Triangulated 224 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 509 / 1508 points
#   => Triangulated 182 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 661 / 1550 points
#   => Triangulated 318 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 578 / 1340 points
#   => Triangulated 177 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 808 / 1494 points
#   => Triangulated 238 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1040 / 1768 points
#   => Triangulated 214 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 705 / 1369 points
#   => Triangulated 230 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 612 / 1498 points
#   => Triangulated 200 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 604 / 1645 points
#   => Triangulated 149 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 466 / 1506 points
#   => Triangulated 196 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 4
#   => Merged observations: 2882
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.686678e+05    0.00e+00    7.78e+03   0.00e+00   0.00e+00  1.00e+04        0    1.12e-02    3.42e-02
#    1  1.239746e+05    4.47e+04    7.47e+02   6.42e+01   9.92e-01  3.00e+04        0    2.60e-02    6.03e-02
#    2  1.235931e+05    3.82e+02    1.05e+01   2.07e+01   9.97e-01  9.00e+04        0    1.71e-02    7.75e-02
#    3  1.235924e+05    7.62e-01    9.51e-02   3.26e+00   9.99e-01  2.70e+05        0    2.20e-02    9.96e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 36904
#    Parameters : 12153
#    Iterations : 4
#          Time : 0.10166 [s]
#  Initial cost : 2.13786 [px]
#    Final cost : 1.83003 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 305
#   => Filtered observations: 1281
#   => Changed observations: 0.085953
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.986503e+04    0.00e+00    1.71e+03   0.00e+00   0.00e+00  1.00e+04        0    1.28e-02    2.26e-02
#    1  1.800782e+04    1.86e+03    2.13e+01   5.52e+00   1.00e+00  3.00e+04        0    1.41e-02    3.68e-02
#    2  1.800734e+04    4.76e-01    2.65e-01   5.70e-01   9.99e-01  9.00e+04        0    1.23e-02    4.91e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 34340
#    Parameters : 11472
#    Iterations : 3
#          Time : 0.049844 [s]
#  Initial cost : 0.760579 [px]
#    Final cost : 0.724143 [px]
#   Termination : Convergence
#
#   => Completed observations: 168
#   => Merged observations: 238
#   => Filtered observations: 26
#   => Changed observations: 0.025160
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.850020e+04    0.00e+00    1.35e+03   0.00e+00   0.00e+00  1.00e+04        0    9.21e-03    1.91e-02
#    1  1.819132e+04    3.09e+02    3.82e+00   1.05e+00   1.00e+00  3.00e+04        0    1.37e-02    3.28e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 34624
#    Parameters : 11385
#    Iterations : 2
#          Time : 0.0383091 [s]
#  Initial cost : 0.73097 [px]
#    Final cost : 0.724842 [px]
#   Termination : Convergence
#
#   => Completed observations: 21
#   => Merged observations: 23
#   => Filtered observations: 8
#   => Changed observations: 0.003004
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.825265e+04    0.00e+00    1.36e+03   0.00e+00   0.00e+00  1.00e+04        0    1.04e-02    2.08e-02
#    1  1.818720e+04    6.55e+01    3.33e+00   2.72e-01   1.00e+00  3.00e+04        0    1.54e-02    3.62e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 34650
#    Parameters : 11376
#    Iterations : 2
#          Time : 0.0424521 [s]
#  Initial cost : 0.725791 [px]
#    Final cost : 0.724488 [px]
#   Termination : Convergence
#
#   => Completed observations: 3
#   => Merged observations: 6
#   => Filtered observations: 2
#   => Changed observations: 0.000635
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.818641e+04    0.00e+00    6.22e+02   0.00e+00   0.00e+00  1.00e+04        0    9.05e-03    1.90e-02
#    1  1.817310e+04    1.33e+01    7.56e-01   5.10e-02   1.00e+00  3.00e+04        0    1.57e-02    3.48e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 34652
#    Parameters : 11373
#    Iterations : 2
#          Time : 0.0358331 [s]
#  Initial cost : 0.724452 [px]
#    Final cost : 0.724186 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000000
#
# ==============================================================================
# Extracting colors
# ==============================================================================
#
# colmap point_triangulator --database_path source/colmap_0/input.db --image_path source/colmap_0/input --output_path source/colmap_0/distorted/sparse --input_path source/colmap_0/manual --Mapper.ba_global_function_tolerance=0.000001
#
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 18 images and 3791 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorting image [1/18]
# Undistorted image found; copying to location: source/colmap_0/images/cam13.png
# Undistorted image found; copying to location: source/colmap_0/images/cam12.png
# Undistorted image found; copying to location: source/colmap_0/images/cam11.png
# Undistorted image found; copying to location: source/colmap_0/images/cam10.png
# Undistorting image [2/18]
# Undistorting image [3/18]
# Undistorting image [4/18]
# Undistorting image [5/18]
# Undistorted image found; copying to location: source/colmap_0/images/cam08.png
# Undistorted image found; copying to location: source/colmap_0/images/cam09.png
# Undistorted image found; copying to location: source/colmap_0/images/cam07.png
# Undistorted image found; copying to location: source/colmap_0/images/cam06.png
# Undistorting image [6/18]
# Undistorting image [7/18]
# Undistorted image found; copying to location: source/colmap_0/images/cam05.png
# Undistorting image [8/18]
# Undistorting image [9/18]Undistorted image found; copying to location: source/colmap_0/images/cam04.png
#
# Undistorting image [10/18]
# Undistorting image [11/18]
# Undistorted image found; copying to location: source/colmap_0/images/cam02.png
# Undistorted image found; copying to location: source/colmap_0/images/cam01.png
# Undistorting image [12/18]
# Undistorted image found; copying to location: Undistorting image [13/18]
# source/colmap_0/images/cam00.png
# Undistorted image found; copying to location: source/colmap_0/images/cam14.png
# Undistorted image found; copying to location: source/colmap_0/images/cam16.png
# Undistorting image [14/18]
# Undistorting image [15/18]
# Undistorted image found; copying to location: source/colmap_0/images/cam18.png
# Undistorted image found; copying to location: source/colmap_0/images/cam19.png
# Undistorted image found; copying to location: source/colmap_0/images/cam20.png
# Undistorting image [16/18]
# Undistorting image [17/18]
# Undistorting image [18/18]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.006 [minutes]
# colmap image_undistorter --image_path source/colmap_0/input --input_path source/colmap_0/distorted/sparse --output_path source/colmap_0 --output_type COLMAP
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/18]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4227
# Processed file [2/18]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.097, LON=1.144, ALT=2.128
#   Features:        4179
# Processed file [3/18]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
#   Camera:          #3 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-4.342, LON=1.139, ALT=1.682
#   Features:        4216
# Processed file [4/18]
#   Name:            cam04.png
#   Dimensions:      2704 x 2028
#   Camera:          #4 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.518, LON=1.035, ALT=0.979
#   Features:        4177
# Processed file [5/18]
#   Name:            cam05.png
#   Dimensions:      2704 x 2028
#   Camera:          #5 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.508, LON=1.082, ALT=0.534
#   Features:        4209
# Processed file [6/18]
#   Name:            cam06.png
#   Dimensions:      2704 x 2028
#   Camera:          #6 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.552, LON=1.128, ALT=0.368
#   Features:        4555
# Processed file [7/18]
#   Name:            cam07.png
#   Dimensions:      2704 x 2028
#   Camera:          #7 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=1.537, LON=1.137, ALT=0.711
#   Features:        4908
# Processed file [8/18]
#   Name:            cam08.png
#   Dimensions:      2704 x 2028
#   Camera:          #8 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.475, LON=1.116, ALT=1.272
#   Features:        5490
# Processed file [9/18]
#   Name:            cam09.png
#   Dimensions:      2704 x 2028
#   Camera:          #9 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=3.498, LON=1.143, ALT=1.151
#   Features:        6103
# Processed file [10/18]
#   Name:            cam10.png
#   Dimensions:      2704 x 2028
#   Camera:          #10 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.301, LON=1.195, ALT=1.406
#   Features:        5968
# Processed file [11/18]
#   Name:            cam11.png
#   Dimensions:      2704 x 2028
#   Camera:          #11 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-6.146, LON=-1.749, ALT=0.872
#   Features:        4076
# Processed file [12/18]
#   Name:            cam12.png
#   Dimensions:      2704 x 2028
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3721
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3747
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3897
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        4000
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4451
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        4866
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5444
# Elapsed time: 0.575 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1] in 366.119s
# Elapsed time: 6.103 [minutes]
#
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 18 in 0.000s
# Loading matches... 152 in 0.001s
# Loading images... 18 in 0.006s (connected 18)
# Building correspondence graph... in 0.009s (ignored 0)
#
# Elapsed time: 0.000 [minutes]
#
#
# ==============================================================================
# Triangulating image #1 (0)
# ==============================================================================
#
#   => Image sees 0 / 1868 points
#   => Triangulated 1359 points
#
# ==============================================================================
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 152 / 1471 points
#   => Triangulated 699 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 731 / 1721 points
#   => Triangulated 301 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1053 / 2003 points
#   => Triangulated 477 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1375 / 2215 points
#   => Triangulated 219 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 970 / 1834 points
#   => Triangulated 275 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 804 / 1958 points
#   => Triangulated 381 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 777 / 1993 points
#   => Triangulated 282 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 680 / 1952 points
#   => Triangulated 225 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 518 / 1469 points
#   => Triangulated 176 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 673 / 1554 points
#   => Triangulated 316 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 604 / 1336 points
#   => Triangulated 163 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 841 / 1499 points
#   => Triangulated 229 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1055 / 1797 points
#   => Triangulated 237 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 731 / 1389 points
#   => Triangulated 224 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 635 / 1541 points
#   => Triangulated 216 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 644 / 1742 points
#   => Triangulated 165 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 470 / 1557 points
#   => Triangulated 195 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 3
#   => Merged observations: 2887
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.690907e+05    0.00e+00    9.37e+03   0.00e+00   0.00e+00  1.00e+04        0    1.04e-02    2.22e-02
#    1  1.266206e+05    4.25e+04    3.66e+03   7.57e+01   9.57e-01  3.00e+04        0    1.42e-02    3.64e-02
#    2  1.247539e+05    1.87e+03    5.11e+02   2.51e+01   9.76e-01  9.00e+04        0    1.34e-02    4.98e-02
#    3  1.247125e+05    4.14e+01    1.84e+01   4.75e+00   9.96e-01  2.70e+05        0    1.33e-02    6.31e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 37792
#    Parameters : 12270
#    Iterations : 4
#          Time : 0.0681491 [s]
#  Initial cost : 2.11524 [px]
#    Final cost : 1.81658 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 417
#   => Filtered observations: 1280
#   => Changed observations: 0.089860
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.093428e+04    0.00e+00    1.62e+03   0.00e+00   0.00e+00  1.00e+04        0    9.30e-03    1.88e-02
#    1  1.908723e+04    1.85e+03    2.12e+01   6.25e+00   1.00e+00  3.00e+04        0    1.32e-02    3.20e-02
#    2  1.908682e+04    4.03e-01    9.95e-02   4.56e-01   9.99e-01  9.00e+04        0    1.24e-02    4.44e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35220
#    Parameters : 11565
#    Iterations : 3
#          Time : 0.0450621 [s]
#  Initial cost : 0.770964 [px]
#    Final cost : 0.73616 [px]
#   Termination : Convergence
#
#   => Completed observations: 151
#   => Merged observations: 254
#   => Filtered observations: 32
#   => Changed observations: 0.024815
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.946520e+04    0.00e+00    1.20e+03   0.00e+00   0.00e+00  1.00e+04        0    1.11e-02    2.33e-02
#    1  1.913206e+04    3.33e+02    4.74e+00   7.17e-01   1.00e+00  3.00e+04        0    1.32e-02    3.65e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35458
#    Parameters : 11481
#    Iterations : 2
#          Time : 0.0413902 [s]
#  Initial cost : 0.740922 [px]
#    Final cost : 0.734554 [px]
#   Termination : Convergence
#
#   => Completed observations: 11
#   => Merged observations: 23
#   => Filtered observations: 8
#   => Changed observations: 0.002369
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.913971e+04    0.00e+00    1.40e+03   0.00e+00   0.00e+00  1.00e+04        0    9.60e-03    1.90e-02
#    1  1.909347e+04    4.62e+01    2.01e+00   2.55e-01   1.00e+00  3.00e+04        0    1.36e-02    3.26e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35464
#    Parameters : 11472
#    Iterations : 2
#          Time : 0.037338 [s]
#  Initial cost : 0.734639 [px]
#    Final cost : 0.733751 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 0
#   => Filtered observations: 2
#   => Changed observations: 0.000169
#
# ==============================================================================
# Extracting colors
# ==============================================================================
#
# colmap point_triangulator --database_path source/colmap_1/input.db --image_path source/colmap_1/input --output_path source/colmap_1/distorted/sparse --input_path source/colmap_1/manual --Mapper.ba_global_function_tolerance=0.000001
#
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 18 images and 3824 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorted image found; copying to location: source/colmap_1/images/cam13.png
# Undistorted image found; copying to location: source/colmap_1/images/cam12.png
# Undistorting image [1/18]
# Undistorting image [2/18]
# Undistorted image found; copying to location: source/colmap_1/images/cam11.png
# Undistorted image found; copying to location: source/colmap_1/images/cam10.png
# Undistorting image [3/18]
# Undistorting image [4/18]
# Undistorting image [5/18]
# Undistorted image found; copying to location: source/colmap_1/images/cam08.png
# Undistorted image found; copying to location: source/colmap_1/images/cam09.png
# Undistorted image found; copying to location: Undistorted image found; copying to location: source/colmap_1/images/cam06.pngsource/colmap_1/images/cam07.png
#
# Undistorting image [6/18]
# Undistorting image [7/18]
# Undistorted image found; copying to location: Undistorting image [8/18]source/colmap_1/images/cam05.png
# Undistorting image [9/18]
# Undistorted image found; copying to location: source/colmap_1/images/cam04.png
#
# Undistorted image found; copying to location: source/colmap_1/images/cam02.png
# Undistorted image found; copying to location: source/colmap_1/images/cam01.png
# Undistorting image [10/18]
# Undistorting image [11/18]
# Undistorting image [12/18]
# Undistorted image found; copying to location: Undistorting image [13/18]
# source/colmap_1/images/cam00.png
# Undistorted image found; copying to location: source/colmap_1/images/cam14.png
# Undistorting image [14/18]
# Undistorted image found; copying to location: source/colmap_1/images/cam16.png
# Undistorted image found; copying to location: source/colmap_1/images/cam18.png
# Undistorting image [15/18]
# Undistorting image [16/18]
# Undistorted image found; copying to location: source/colmap_1/images/cam19.png
# Undistorted image found; copying to location: source/colmap_1/images/cam20.png
# Undistorting image [17/18]
# Undistorting image [18/18]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.006 [minutes]
# colmap image_undistorter --image_path source/colmap_1/input --input_path source/colmap_1/distorted/sparse --output_path source/colmap_1 --output_type COLMAP
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/18]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4267
# Processed file [2/18]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.097, LON=1.144, ALT=2.128
#   Features:        4160
# Processed file [3/18]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
#   Camera:          #3 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-4.342, LON=1.139, ALT=1.682
#   Features:        4270
# Processed file [4/18]
#   Name:            cam04.png
#   Dimensions:      2704 x 2028
#   Camera:          #4 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.518, LON=1.035, ALT=0.979
#   Features:        4231
# Processed file [5/18]
#   Name:            cam05.png
#   Dimensions:      2704 x 2028
#   Camera:          #5 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.508, LON=1.082, ALT=0.534
#   Features:        4149
# Processed file [6/18]
#   Name:            cam06.png
#   Dimensions:      2704 x 2028
#   Camera:          #6 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.552, LON=1.128, ALT=0.368
#   Features:        4668
# Processed file [7/18]
#   Name:            cam07.png
#   Dimensions:      2704 x 2028
#   Camera:          #7 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=1.537, LON=1.137, ALT=0.711
#   Features:        4851
# Processed file [8/18]
#   Name:            cam08.png
#   Dimensions:      2704 x 2028
#   Camera:          #8 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.475, LON=1.116, ALT=1.272
#   Features:        5494
# Processed file [9/18]
#   Name:            cam09.png
#   Dimensions:      2704 x 2028
#   Camera:          #9 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=3.498, LON=1.143, ALT=1.151
#   Features:        6180
# Processed file [10/18]
#   Name:            cam10.png
#   Dimensions:      2704 x 2028
#   Camera:          #10 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.301, LON=1.195, ALT=1.406
#   Features:        5967
# Processed file [11/18]
#   Name:            cam11.png
#   Dimensions:      2704 x 2028
#   Camera:          #11 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-6.146, LON=-1.749, ALT=0.872
#   Features:        4088
# Processed file [12/18]
#   Name:            cam12.png
#   Dimensions:      2704 x 2028
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3734
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3770
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3892
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        3942
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4553
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        4946
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5451
# Elapsed time: 0.557 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1] in 364.466s
# Elapsed time: 6.076 [minutes]
#
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 18 in 0.000s
# Loading matches... 151 in 0.001s
# Loading images... 18 in 0.010s (connected 18)
# Building correspondence graph... in 0.011s (ignored 0)
#
# Elapsed time: 0.000 [minutes]
#
#
# ==============================================================================
# Triangulating image #1 (0)
# ==============================================================================
#
#   => Image sees 0 / 1866 points
#   => Triangulated 1399 points
#
# ==============================================================================
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 155 / 1462 points
#   => Triangulated 663 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 722 / 1716 points
#   => Triangulated 283 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1047 / 2055 points
#   => Triangulated 470 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1367 / 2187 points
#   => Triangulated 210 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 976 / 1879 points
#   => Triangulated 297 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 814 / 1942 points
#   => Triangulated 354 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 799 / 2000 points
#   => Triangulated 293 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 680 / 1967 points
#   => Triangulated 233 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 493 / 1496 points
#   => Triangulated 181 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 657 / 1535 points
#   => Triangulated 339 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 598 / 1287 points
#   => Triangulated 157 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 826 / 1457 points
#   => Triangulated 223 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1063 / 1798 points
#   => Triangulated 240 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 736 / 1394 points
#   => Triangulated 232 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 616 / 1493 points
#   => Triangulated 215 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 609 / 1651 points
#   => Triangulated 139 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 468 / 1577 points
#   => Triangulated 193 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 7
#   => Merged observations: 2891
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.739475e+05    0.00e+00    9.70e+03   0.00e+00   0.00e+00  1.00e+04        0    1.80e-02    3.58e-02
#    1  1.323870e+05    4.16e+04    1.27e+04   1.20e+02   7.74e-01  1.20e+04        0    2.51e-02    6.09e-02
#    2  1.214900e+05    1.09e+04    2.87e+03   3.28e+01   8.98e-01  2.42e+04        0    2.36e-02    8.46e-02
#    3  1.203243e+05    1.17e+03    4.60e+02   1.44e+01   9.59e-01  7.26e+04        0    2.41e-02    1.09e-01
#    4  1.202762e+05    4.80e+01    2.50e+01   4.18e+00   9.95e-01  2.18e+05        0    2.36e-02    1.32e-01
#    5  1.202761e+05    1.66e-01    4.14e-02   2.81e-01   9.98e-01  6.53e+05        0    2.29e-02    1.55e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 37582
#    Parameters : 12111
#    Iterations : 6
#          Time : 0.15689 [s]
#  Initial cost : 2.15139 [px]
#    Final cost : 1.78896 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 331
#   => Filtered observations: 1349
#   => Changed observations: 0.089405
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.049834e+04    0.00e+00    1.97e+03   0.00e+00   0.00e+00  1.00e+04        0    1.46e-02    2.90e-02
#    1  1.860792e+04    1.89e+03    1.83e+01   6.08e+00   1.00e+00  3.00e+04        0    2.14e-02    5.04e-02
#    2  1.860751e+04    4.06e-01    1.10e-01   5.80e-01   1.00e+00  9.00e+04        0    2.42e-02    7.46e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 34870
#    Parameters : 11400
#    Iterations : 3
#          Time : 0.075815 [s]
#  Initial cost : 0.766714 [px]
#    Final cost : 0.730497 [px]
#   Termination : Convergence
#
#   => Completed observations: 167
#   => Merged observations: 186
#   => Filtered observations: 38
#   => Changed observations: 0.022426
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.900114e+04    0.00e+00    1.35e+03   0.00e+00   0.00e+00  1.00e+04        0    1.54e-02    2.94e-02
#    1  1.862816e+04    3.73e+02    6.80e+00   9.36e-01   1.00e+00  3.00e+04        0    2.26e-02    5.20e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35128
#    Parameters : 11334
#    Iterations : 2
#          Time : 0.0603921 [s]
#  Initial cost : 0.735467 [px]
#    Final cost : 0.728213 [px]
#   Termination : Convergence
#
#   => Completed observations: 14
#   => Merged observations: 33
#   => Filtered observations: 12
#   => Changed observations: 0.003359
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.865230e+04    0.00e+00    8.34e+02   0.00e+00   0.00e+00  1.00e+04        0    1.51e-02    3.05e-02
#    1  1.858955e+04    6.27e+01    4.29e+00   3.33e-01   1.00e+00  3.00e+04        0    2.57e-02    5.62e-02
#
#
# Bundle adjustment report
# ------------------------
# ...
#   Features:        4114
# Processed file [3/18]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
#   Camera:          #3 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-4.342, LON=1.139, ALT=1.682
#   Features:        4184
# Processed file [4/18]
#   Name:            cam04.png
#   Dimensions:      2704 x 2028
#   Camera:          #4 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.518, LON=1.035, ALT=0.979
#   Features:        4158
# Processed file [5/18]
#   Name:            cam05.png
#   Dimensions:      2704 x 2028
#   Camera:          #5 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.508, LON=1.082, ALT=0.534
#   Features:        4170
# Processed file [6/18]
#   Name:            cam06.png
#   Dimensions:      2704 x 2028
#   Camera:          #6 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.552, LON=1.128, ALT=0.368
#   Features:        4671
# Processed file [7/18]
#   Name:            cam07.png
#   Dimensions:      2704 x 2028
#   Camera:          #7 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=1.537, LON=1.137, ALT=0.711
#   Features:        4795
# Processed file [8/18]
#   Name:            cam08.png
#   Dimensions:      2704 x 2028
#   Camera:          #8 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.475, LON=1.116, ALT=1.272
#   Features:        5516
# Processed file [9/18]
#   Name:            cam09.png
#   Dimensions:      2704 x 2028
#   Camera:          #9 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=3.498, LON=1.143, ALT=1.151
#   Features:        6104
# Processed file [10/18]
#   Name:            cam10.png
#   Dimensions:      2704 x 2028
#   Camera:          #10 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.301, LON=1.195, ALT=1.406
#   Features:        5941
# Processed file [11/18]
#   Name:            cam11.png
#   Dimensions:      2704 x 2028
#   Camera:          #11 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-6.146, LON=-1.749, ALT=0.872
#   Features:        4001
# Processed file [12/18]
#   Name:            cam12.png
#   Dimensions:      2704 x 2028
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3705
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3741
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3827
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        3939
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4464
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        4922
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5467
# Elapsed time: 0.553 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1] in 351.266s
# Elapsed time: 5.856 [minutes]
#
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 18 in 0.000s
# Loading matches... 152 in 0.001s
# Loading images... 18 in 0.006s (connected 18)
# Building correspondence graph... in 0.009s (ignored 0)
#
# Elapsed time: 0.000 [minutes]
#
#
# ==============================================================================
# Triangulating image #1 (0)
# ==============================================================================
#
#   => Image sees 0 / 1878 points
#   => Triangulated 1367 points
#
# ==============================================================================
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 146 / 1471 points
#   => Triangulated 726 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 775 / 1743 points
#   => Triangulated 306 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1075 / 2057 points
#   => Triangulated 485 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1390 / 2241 points
#   => Triangulated 243 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 922 / 1841 points
#   => Triangulated 322 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 823 / 1964 points
#   => Triangulated 358 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 767 / 1936 points
#   => Triangulated 274 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 663 / 1933 points
#   => Triangulated 228 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 498 / 1495 points
#   => Triangulated 191 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 661 / 1556 points
#   => Triangulated 333 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 619 / 1364 points
#   => Triangulated 163 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 842 / 1532 points
#   => Triangulated 255 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1086 / 1818 points
#   => Triangulated 228 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 746 / 1406 points
#   => Triangulated 229 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 619 / 1517 points
#   => Triangulated 208 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 591 / 1687 points
#   => Triangulated 155 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 438 / 1518 points
#   => Triangulated 187 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 9
#   => Merged observations: 3152
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.831330e+05    0.00e+00    2.11e+04   0.00e+00   0.00e+00  1.00e+04        0    2.54e-02    5.17e-02
#    1  1.294371e+05    5.37e+04    1.36e+03   6.76e+01   9.88e-01  3.00e+04        0    2.67e-02    7.85e-02
#    2  1.288001e+05    6.37e+02    5.17e+01   1.98e+01   9.96e-01  9.00e+04        0    2.41e-02    1.03e-01
#    3  1.287983e+05    1.81e+00    6.52e-01   3.03e+00   9.99e-01  2.70e+05        0    2.17e-02    1.24e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 37922
#    Parameters : 12171
#    Iterations : 4
#          Time : 0.127409 [s]
#  Initial cost : 2.19754 [px]
#    Final cost : 1.84293 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 396
#   => Filtered observations: 1193
#   => Changed observations: 0.083856
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.915258e+04    0.00e+00    2.62e+03   0.00e+00   0.00e+00  1.00e+04        0    9.69e-03    1.95e-02
#    1  1.751038e+04    1.64e+03    1.83e+01   5.73e+00   1.00e+00  3.00e+04        0    1.50e-02    3.46e-02
#    2  1.750922e+04    1.15e+00    2.91e-01   9.29e-01   9.95e-01  9.00e+04        0    1.35e-02    4.82e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35530
#    Parameters : 11397
#    Iterations : 3
#          Time : 0.048913 [s]
#  Initial cost : 0.734203 [px]
#    Final cost : 0.701998 [px]
#   Termination : Convergence
#
#   => Completed observations: 158
#   => Merged observations: 241
#   => Filtered observations: 20
#   => Changed observations: 0.023586
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.796997e+04    0.00e+00    1.62e+03   0.00e+00   0.00e+00  1.00e+04        0    9.93e-03    1.99e-02
#    1  1.765372e+04    3.16e+02    6.00e+00   7.01e-01   1.00e+00  3.00e+04        0    1.39e-02    3.38e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35804
#    Parameters : 11331
#    Iterations : 2
#          Time : 0.0388539 [s]
#  Initial cost : 0.708448 [px]
#    Final cost : 0.702186 [px]
#   Termination : Convergence
#
#   => Completed observations: 15
#   => Merged observations: 26
#   => Filtered observations: 6
#   => Changed observations: 0.002625
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.769032e+04    0.00e+00    5.78e+02   0.00e+00   0.00e+00  1.00e+04        0    9.94e-03    1.98e-02
#    1  1.763612e+04    5.42e+01    3.71e+00   3.92e-01   1.00e+00  3.00e+04        0    1.37e-02    3.35e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35822
#    Parameters : 11325
#    Iterations : 2
#          Time : 0.0386651 [s]
#  Initial cost : 0.702737 [px]
#    Final cost : 0.70166 [px]
#   Termination : Convergence
#
#   => Completed observations: 2
#   => Merged observations: 0
#   => Filtered observations: 1
#   => Changed observations: 0.000167
#
# ==============================================================================
# Extracting colors
# ==============================================================================
#
# colmap point_triangulator --database_path source/colmap_9/input.db --image_path source/colmap_9/input --output_path source/colmap_9/distorted/sparse --input_path source/colmap_9/manual --Mapper.ba_global_function_tolerance=0.000001
#
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 18 images and 3775 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorting image [1/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam13.png
# Undistorted image found; copying to location: source/colmap_9/images/cam12.png
# Undistorted image found; copying to location: source/colmap_9/images/cam11.png
# Undistorted image found; copying to location: source/colmap_9/images/cam10.png
# Undistorting image [2/18]
# Undistorting image [3/18]
# Undistorting image [4/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam09.png
# Undistorting image [5/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam08.png
# Undistorted image found; copying to location: source/colmap_9/images/cam07.png
# Undistorted image found; copying to location: source/colmap_9/images/cam06.png
# Undistorting image [6/18]
# Undistorting image [7/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam05.png
# Undistorting image [8/18]
# Undistorting image [9/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam04.png
# Undistorting image [10/18]
# Undistorting image [11/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam02.png
# Undistorted image found; copying to location: source/colmap_9/images/cam01.png
# Undistorted image found; copying to location: source/colmap_9/images/cam00.png
# Undistorted image found; copying to location: source/colmap_9/images/cam14.png
# Undistorting image [12/18]
# Undistorting image [13/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam16.png
# Undistorting image [14/18]
# Undistorting image [15/18]Undistorted image found; copying to location:
# source/colmap_9/images/cam18.png
# Undistorted image found; copying to location: source/colmap_9/images/cam20.png
# Undistorting image [16/18]
# Undistorting image [17/18]
# Undistorted image found; copying to location: source/colmap_9/images/cam19.png
# Undistorting image [18/18]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.006 [minutes]
# colmap image_undistorter --image_path source/colmap_9/input --input_path source/colmap_9/distorted/sparse --output_path source/colmap_9 --output_type COLMAP

# %%
# !ls source/colmap_0/sparse/0/
# Out:
# cameras.bin  images.bin  points3D.bin

# %%
print('colmap worked successfully')
# Out:
# colmap worked successfully

# %%
#######################################################################

# %%
# !python train.py --quiet --eval --config configs/n3d_lite/coffee_martini.json --model_path ./output --source_path ./source/colmap_0
# Out:
# Overriding from config: configs/n3d_lite/coffee_martini.json
# Unknown config key 'test_iteration', skipping.
# Finished loading config.
# Namespace(sh_degree=3, source_path='./source/colmap_0', model_path='./output', images='images', resolution=2, white_background=False, data_device='cuda', veryrify_llff=0, eval=True, model='ours_lite', loader='colmap', iterations=30000, position_lr_init=0.00016, position_lr_final=1.6e-06, position_lr_delay_mult=0.01, position_lr_max_steps=30000, feature_lr=0.0025, featuret_lr=0.001, opacity_lr=0.05, scaling_lr=0.003, trbfc_lr=0.0001, trbfs_lr=0.03, trbfslinit=0.0, batch=2, movelr=3.5, omega_lr=0.0001, rotation_lr=0.001, percent_dense=0.01, lambda_dssim=0.2, densification_interval=100, opacity_reset_interval=3000, opacity_reset_at=10000, densify_from_iter=500, densify_until_iter=9000, densify_grad_threshold=0.0002, rgb_lr=0.0001, desicnt=6, reg=0, regl=0.0001, shrinkscale=2.0, randomfeature=0, emstype=0, radials=10.0, farray=2, emsstart=1600, losstart=200, saveemppoints=0, prunebysize=0, emsthr=0.6, opthr=0.005, selectiveview=0, preprocesspoints=3, fzrotit=8001, addsphpointsscale=0.8, gnumlimit=330000, rayends=7.5, raystart=0.7, shuffleems=1, prevpath='1', loadall=0, removescale=5, gtmask=0, gtisint8=0, convert_SHs_python=False, compute_cov3D_python=False, debug=False, ip='127.0.0.1', port=6029, debug_from=-2, detect_anomaly=False, save_iterations=[7000, 10000, 12000, 25000, 30000, 30000], test_iterations=-1, quiet=True, checkpoint_iterations=[], start_checkpoint=None, densify=2, duration=10, basicfunction='gaussian', rgbfunction='rgbv1', rdpip='train_ours_lite', configpath='configs/n3d_lite/coffee_martini.json')
# Optimizing ./output
# Training progress:  12% 3740/30000 [08:55<1:13:17,  5.97it/s, Loss=0.0352107]

# %%
# !python test_fixed1.py --quiet --eval --skip_train --valloader colmapvalid --configpath configs/n3d_lite/coffee_martini.json --model_path ./output --source_path source/colmap_0
# Out:
# Looking for config file in ./output/cfg_args
# Config file found: ./output/cfg_args
# Rendering ./output
# Traceback (most recent call last):
#   File "/content/SpacetimeGaussians/test_fixed1.py", line 235, in <module>
#     run_test(model_extract, args.test_iteration, pp_extract, args.skip_train, args.skip_test, multiview, args.duration,  rgbfunction=args.rgbfunction, rdpip=args.rdpip, loader=args.valloader)
#   File "/content/SpacetimeGaussians/test_fixed1.py", line 215, in run_test
#     scene = Scene(dataset, gaussians, load_iteration=iteration, shuffle=False, multiview=multiview, duration=duration, loader=loader)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SpacetimeGaussians/thirdparty/gaussian_splatting/scene/__init__.py", line 50, in __init__
#     scene_info = sceneLoadTypeCallbacks["Colmap"](args.source_path, args.images, args.eval, multiview, duration=duration)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SpacetimeGaussians/thirdparty/gaussian_splatting/scene/dataset_readers.py", line 788, in readColmapSceneInfo
#     cam_infos_unsorted = readColmapCameras(cam_extrinsics=cam_extrinsics, cam_intrinsics=cam_intrinsics, images_folder=os.path.join(path, reading_dir), near=near, far=far, startime=starttime, duration=duration)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/SpacetimeGaussians/thirdparty/gaussian_splatting/scene/dataset_readers.py", line 163, in readColmapCameras
#     assert os.path.exists(image_path), "Image {} does not exist!".format(image_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: Image /content/SpacetimeGaussians/source/colmap_10/images/cam20.png does not exist!

# %%
#########################################################################
