# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/spacetime_gaussians4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/oppo-us-research/SpacetimeGaussians.git --recursive
# Out:
# Cloning into 'SpacetimeGaussians'...
# remote: Enumerating objects: 2854, done.
# remote: Counting objects: 100% (932/932), done.
# remote: Compressing objects: 100% (266/266), done.
# remote: Total 2854 (delta 755), reused 666 (delta 666), pack-reused 1922 (from 2)
# Receiving objects: 100% (2854/2854), 43.51 MiB | 35.87 MiB/s, done.
# Resolving deltas: 100% (1829/1829), done.
# Submodule 'thirdparty/mmcv' (https://github.com/open-mmlab/mmcv.git) registered for path 'thirdparty/mmcv'
# Cloning into '/content/SpacetimeGaussians/thirdparty/mmcv'...
# remote: Enumerating objects: 17575, done.
# remote: Counting objects: 100% (508/508), done.
# remote: Compressing objects: 100% (343/343), done.
# remote: Total 17575 (delta 356), reused 165 (delta 165), pack-reused 17067 (from 2)
# Receiving objects: 100% (17575/17575), 14.33 MiB | 19.78 MiB/s, done.
# Resolving deltas: 100% (12821/12821), done.
# Submodule path 'thirdparty/mmcv': checked out '3ba02dfd35c326306346bd9d35a887efc2b30fb0'

# %%
import os
os.chdir('SpacetimeGaussians')

# %%
print('fixed scripts [setup, pre_colmap, pren3d, helper3dg] uploaded manually')

break

# %%
#use setup_fixed1.sh
# !bash script/setup_fixed1.sh
# Out:
# --- 0. 既存環境のクリーンアップとConda初期化 ---
# script/setup_fixed1.sh: line 17: conda: command not found
# script/setup_fixed1.sh: line 18: conda: command not found
# script/setup_fixed1.sh: line 27: conda: command not found
# --- 1. feature_splatting 環境の作成 (Python 3.10) ---
# script/setup_fixed1.sh: line 38: conda: command not found

# %%
# !pip install opencv-python
# !pip install torch

# %%
print('hello')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
SOURCE_PATH='/content/drive/MyDrive/your_folder/coffee_martini'
DEST_PATH='/content/SpacetimeGaussians/source'
shutil.copytree(SOURCE_PATH, DEST_PATH, dirs_exist_ok=True)
# Out:
# '/content/SpacetimeGaussians/source'

# %%
# !apt-get update
# !apt-get install -y colmap
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,835 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,008 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# ...

# %%
# !python -c "import numpy as np; print(f'NumPy version: {np.__version__}')"
# !sed -i 's/np\.NaN/np.nan/g' /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap.py
# !grep "np\.nan" /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap.py | head -n 5
# Out:
# NumPy version: 2.0.2
#                   prior_q=np.full(4, np.nan), prior_t=np.full(3, np.nan), image_id=None):

# %%
print('20251127 19:29')
# Out:
# 20251127 19:29

# %%
# !QT_QPA_PLATFORM=offscreen DISPLAY= python script/pre_n3d_fixed1.py --videopath source --startframe 0 --endframe 50
# Out:
# params: startframe=0 - endframe=50 - downscale=1 - videopath=source
# start extracting 300 frames from videos
# Extract frames from videos:   0% 0/3 [00:00<?, ?it/s]Already extracted all the frames in source/cam00
# Already extracted all the frames in source/cam01
# Already extracted all the frames in source/cam02
# Extract frames from videos: 100% 3/3 [00:00<00:00, 331.47it/s]
# start preparing colmap image input
# start preparing colmap database input
# convertdynerftocolmapdb: 100% 50/50 [00:04<00:00, 11.99it/s]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
# F1127 11:08:14.977506 13402 opengl_utils.cc:56] Check failed: context_.create()
# *** Check failure stack trace: ***
#     @     0x7a9bdd97bb03  google::LogMessage::Fail()
#     @     0x7a9bdd9839d1  google::LogMessage::SendToLog()
#     @     0x7a9bdd97b7c2  google::LogMessage::Flush()
#     @     0x7a9bdd97d78f  google::LogMessageFatal::~LogMessageFatal()
# ...

# %%
print('pre n3d finished 1127 20:09')

# %%
# !nvcc --version
# !python -c "import torch; print(torch.cuda.is_available()); print(torch.version.cuda)"
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# True
# 12.6

# %%
# !pip install ninja
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/camenduru/simple-knn.git
# Out:
# ...
#   Cloning https://github.com/camenduru/simple-knn.git to /tmp/pip-req-build-_u90cjkf
#   Running command git clone --filter=blob:none --quiet https://github.com/camenduru/simple-knn.git /tmp/pip-req-build-_u90cjkf
#   Resolved https://github.com/camenduru/simple-knn.git to commit 60f461f4a56b7967e5d8045bf92f8c33f36976d0
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for simple_knn: filename=simple_knn-1.0.0-cp312-cp312-linux_x86_64.whl size=3510980 sha256=dcd93199218efc26c049d4143349c400bbd0699185d3554e0c0cd3d0cb99b39d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a6p3e_27/wheels/5f/07/7a/3f06977508979b017ee180047dc42897847707cae601d30a54
# Successfully built simple_knn
# ...

# %%
# !pip install mmcv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.1/479.1 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 17.1 MB/s eta 0:00:00
# ...
#   Created wheel for mmcv: filename=mmcv-2.2.0-cp312-cp312-linux_x86_64.whl size=40897748 sha256=3d1e59407f946ef2bcc544d57e93f79bb09c1287376a477b107784f07ba64114
#   Stored in directory: /root/.cache/pip/wheels/c7/bf/8d/f3122496099a7c3bf81da99fc6a800e6abe3971f65dce706c0
# Successfully built mmcv
# ...

# %%
# !pip install plyfile
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
print('start training 1127 21:20')
# Out:
# start training 1127 21:20

# %%
# !pip install kornia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 96.2 MB/s eta 0:00:00
# ...

# %%
# プロジェクト内のカスタムラスタライザをインストール
# !pip install thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch3
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch3
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization_ch3: filename=diff_gaussian_rasterization_ch3-0.0.0-cp312-cp312-linux_x86_64.whl size=3730052 sha256=2d75830abf7e9faa56632fbc9cce84d7ee1b1deabb38c0eb5ad4f842c75176f2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-74c5e6a9/wheels/84/a6/3a/89e7c9709aa2def67d69a39634c757e662101b0229b8340763
# Successfully built diff_gaussian_rasterization_ch3
# ...

# %%
# !pip install thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch9
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch9
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization_ch9: filename=diff_gaussian_rasterization_ch9-0.0.0-cp312-cp312-linux_x86_64.whl size=3732273 sha256=3a287464bf23edfb26dd603b49235e24edbd1c7c55170fb0224b09f5d8bc2c14
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a8p8m9j3/wheels/eb/ae/46/9f5ab43b95b1c6a8435b1b623732dccec9a98f4eccac4b940d
# Successfully built diff_gaussian_rasterization_ch9
# ...

# %%
# !ls source/colmap_0/sparse/0/
# Out:
# ls: cannot access 'source/colmap_0/sparse/0/': No such file or directory

# %%
# !python train.py --quiet --eval --config configs/n3d_lite/coffee_martini.json --model_path ./output --source_path ./source
# Out:
# Overriding from config: configs/n3d_lite/coffee_martini.json
# Unknown config key 'test_iteration', skipping.
# Finished loading config.
# ...
