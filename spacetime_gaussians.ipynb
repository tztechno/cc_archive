# %% [markdown]
# <a href="https://colab.research.google.com/github/tztechno/cc_archive/blob/main/spacetime_gaussians.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/oppo-us-research/SpacetimeGaussians.git --recursive
# Out:
# Cloning into 'SpacetimeGaussians'...
# remote: Enumerating objects: 2854, done.
# remote: Counting objects: 100% (932/932), done.
# remote: Compressing objects: 100% (266/266), done.
# remote: Total 2854 (delta 755), reused 666 (delta 666), pack-reused 1922 (from 2)
# Receiving objects: 100% (2854/2854), 43.51 MiB | 16.58 MiB/s, done.
# Resolving deltas: 100% (1829/1829), done.
# Submodule 'thirdparty/mmcv' (https://github.com/open-mmlab/mmcv.git) registered for path 'thirdparty/mmcv'
# Cloning into '/content/SpacetimeGaussians/thirdparty/mmcv'...
# remote: Enumerating objects: 17575, done.
# remote: Counting objects: 100% (511/511), done.
# remote: Compressing objects: 100% (346/346), done.
# remote: Total 17575 (delta 357), reused 165 (delta 165), pack-reused 17064 (from 2)
# Receiving objects: 100% (17575/17575), 14.41 MiB | 17.25 MiB/s, done.
# Resolving deltas: 100% (12834/12834), done.
# Submodule path 'thirdparty/mmcv': checked out '3ba02dfd35c326306346bd9d35a887efc2b30fb0'

# %%
import os
os.chdir('SpacetimeGaussians')

# %%
# !ls
# Out:
# assets	 helper_model.py  LICENSE    script   thirdparty       train.py
# configs  helper_train.py  README.md  test.py  train_imdist.py

# %%
import sys
import torch
print(f"Python: {sys.version}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# Python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# PyTorch: 2.9.0+cu126
# CUDA available: True
# CUDA version: 12.6

# %%
# !pip install opencv-python natsort scipy kornia tqdm Pillow
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (8.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Collecting kornia
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Collecting kornia_rs>=0.1.9 (from kornia)
#   Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.7 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 117.4 MB/s eta 0:00:00
# Installing collected packages: kornia_rs, kornia
# Successfully installed kornia-0.8.2 kornia_rs-0.1.10

# %%
# !ls -la thirdparty/gaussian_splatting/submodules/
# Out:
# total 28
# drwxr-xr-x 7 root root 4096 Nov 25 04:11 .
# drwxr-xr-x 9 root root 4096 Nov 25 04:11 ..
# drwxr-xr-x 5 root root 4096 Nov 25 04:11 forward_full
# drwxr-xr-x 5 root root 4096 Nov 25 04:11 forward_lite
# drwxr-xr-x 5 root root 4096 Nov 25 04:11 gaussian_rasterization_ch3
# drwxr-xr-x 5 root root 4096 Nov 25 04:11 gaussian_rasterization_ch9
# drwxr-xr-x 3 root root 4096 Nov 25 04:11 simple-knn

# %%
# !pip install thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch9
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch9
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: diff_gaussian_rasterization_ch9
#   Building wheel for diff_gaussian_rasterization_ch9 (setup.py) ... done
#   Created wheel for diff_gaussian_rasterization_ch9: filename=diff_gaussian_rasterization_ch9-0.0.0-cp312-cp312-linux_x86_64.whl size=3732228 sha256=321151556b5969c87cc23fd2b7b9f520092ec4d08096c3bebeae8c153394d590
#   Stored in directory: /tmp/pip-ephem-wheel-cache-muz5gusd/wheels/eb/ae/46/9f5ab43b95b1c6a8435b1b623732dccec9a98f4eccac4b940d
# Successfully built diff_gaussian_rasterization_ch9
# Installing collected packages: diff_gaussian_rasterization_ch9
# Successfully installed diff_gaussian_rasterization_ch9-0.0.0

# %%
# !pip install thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch3
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/gaussian_rasterization_ch3
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: diff_gaussian_rasterization_ch3
#   Building wheel for diff_gaussian_rasterization_ch3 (setup.py) ... done
#   Created wheel for diff_gaussian_rasterization_ch3: filename=diff_gaussian_rasterization_ch3-0.0.0-cp312-cp312-linux_x86_64.whl size=3729960 sha256=9a1f23c96edda0b174609598ac6d4a05796ee83c9e71bdd145e13cdb257dd8b2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kulyx8pc/wheels/84/a6/3a/89e7c9709aa2def67d69a39634c757e662101b0229b8340763
# Successfully built diff_gaussian_rasterization_ch3
# Installing collected packages: diff_gaussian_rasterization_ch3
# Successfully installed diff_gaussian_rasterization_ch3-0.0.0

# %%
# !pip install thirdparty/gaussian_splatting/submodules/forward_full
# !pip install thirdparty/gaussian_splatting/submodules/forward_lite
# Out:
# Processing ./thirdparty/gaussian_splatting/submodules/forward_full
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: forward_full
#   Building wheel for forward_full (setup.py) ... done
#   Created wheel for forward_full: filename=forward_full-0.0.0-cp312-cp312-linux_x86_64.whl size=3758555 sha256=34413988383d6644a68cfa1e695159cb659ea88128e09c0466aa954a137ddfb2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y9bisyrq/wheels/25/44/92/a609d08793ac256ff288d02a57a67f3a2bfe73e735fb28e506
# Successfully built forward_full
# Installing collected packages: forward_full
# Successfully installed forward_full-0.0.0
# Processing ./thirdparty/gaussian_splatting/submodules/forward_lite
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: forward_lite
#   Building wheel for forward_lite (setup.py) ... done
#   Created wheel for forward_lite: filename=forward_lite-0.0.0-cp312-cp312-linux_x86_64.whl size=3750104 sha256=508d1b84f7473fc9c2a68c569e441c647a65ba442892c77501d2ff29424ff2bc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_g6qpmgd/wheels/bf/24/6d/966f6e962e2d05ca5b8f214357efa97093d355628b9a8c6e3b
# Successfully built forward_lite
# Installing collected packages: forward_lite
# Successfully installed forward_lite-0.0.0

# %%
# !sed -i '/#include <vector>/a #include <cfloat>' thirdparty/gaussian_splatting/submodules/simple-knn/simple_knn.cu && \
echo "✓ ファイルを修正しました" && \
head -30 thirdparty/gaussian_splatting/submodules/simple-knn/simple_knn.cu | grep -A 2 -B 2 "cfloat" && \
pip install -q ninja && \
echo "✓ ninjaをインストールしました" && \
pip install thirdparty/gaussian_splatting/submodules/simple-knn && \
python -c "import simple_knn; print('\n✓✓✓ simple_knn のインストールに成功しました! ✓✓✓')"
# Out:
# ✓ ファイルを修正しました
# #include <cub/device/device_radix_sort.cuh>
# #include <vector>
# #include <cfloat>
# #include <cfloat>
# #include <cfloat>
# #include <cfloat>
# #include <cuda_runtime_api.h>
# #include <thrust/device_vector.h>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.2 MB/s eta 0:00:00
# ✓ ninjaをインストールしました
# Processing ./thirdparty/gaussian_splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: simple_knn
#   Building wheel for simple_knn (setup.py) ... done
#   Created wheel for simple_knn: filename=simple_knn-0.0.0-cp312-cp312-linux_x86_64.whl size=3511048 sha256=c58c099b1bdd6f545ab7388cd92c06e2815b70804c0b8b350ea52cf6a792673a
#   Stored in directory: /root/.cache/pip/wheels/32/0f/f8/6305a7bf157e88fb82611d3ca89a1d3701b3c4baf47c51f2a4
# Successfully built simple_knn
# Installing collected packages: simple_knn
# Successfully installed simple_knn-0.0.0
#
# ✓✓✓ simple_knn のインストールに成功しました! ✓✓✓

# %%
# !pip install -e thirdparty/mmcv -v
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Obtaining file:///content/SpacetimeGaussians/thirdparty/mmcv
#   Running command python setup.py egg_info
#   /content/SpacetimeGaussians/thirdparty/mmcv/setup.py:5: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#     from pkg_resources import DistributionNotFound, get_distribution, parse_version
#   running egg_info
#   creating /tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info
#   writing /tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file '/tmp/pip-pip-egg-info-g86vagl4/mmcv.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Collecting addict (from mmcv==2.2.0)
#   Obtaining dependency information for addict from https://files.pythonhosted.org/packages/6a/00/b08f23b7d7e1e14ce01419a467b583edbb93c6cdb8654e54a9cc579cd61f/addict-2.4.0-py3-none-any.whl.metadata
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv==2.2.0)
#   Obtaining dependency information for mmengine>=0.3.0 from https://files.pythonhosted.org/packages/98/8e/f98332248aad102511bea4ae19c0ddacd2f0a994f3ca4c82b7a369e0af8b/mmengine-0.10.7-py3-none-any.whl.metadata
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (25.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmcv==2.2.0) (6.0.3)
# Collecting yapf (from mmcv==2.2.0)
#   Obtaining dependency information for yapf from https://files.pythonhosted.org/packages/37/81/6acd6601f61e31cfb8729d3da6d5df966f80f374b78eff83760714487338/yapf-0.43.0-py3-none-any.whl.metadata
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (3.2.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv==2.2.0) (4.12.0.88)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmcv==2.2.0) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.2.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.2.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.2.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.2.0) (1.17.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 35.5 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 25.8 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine, mmcv
#   changing mode of /usr/local/bin/yapf to 755
#   changing mode of /usr/local/bin/yapf-diff to 755
#   Running setup.py develop for mmcv
#     Running command python setup.py develop
#     /content/SpacetimeGaussians/thirdparty/mmcv/setup.py:5: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#       from pkg_resources import DistributionNotFound, get_distribution, parse_version
#     running develop
#     /usr/local/lib/python3.12/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` and ``easy_install``.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://github.com/pypa/setuptools/issues/917 for details.
#             ********************************************************************************
#
#     !!
#       easy_install.initialize_options(self)
#     /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` directly.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#             ********************************************************************************
#
#     !!
#       self.initialize_options()
#     running egg_info
#     creating mmcv.egg-info
#     writing mmcv.egg-info/PKG-INFO
#     writing dependency_links to mmcv.egg-info/dependency_links.txt
#     writing requirements to mmcv.egg-info/requires.txt
#     writing top-level names to mmcv.egg-info/top_level.txt
#     writing manifest file 'mmcv.egg-info/SOURCES.txt'
#     reading manifest file 'mmcv.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     adding license file 'LICENSE'
#     adding license file 'LICENSES.md'
#     writing manifest file 'mmcv.egg-info/SOURCES.txt'
#     running build_ext
#     W1125 04:48:30.120000 13089 torch/utils/cpp_extension.py:521] The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.6). Most likely this shouldn't be a problem.
#     W1125 04:48:30.121000 13089 torch/utils/cpp_extension.py:531] There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#     building 'mmcv._ext' extension
#     creating /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch
#     creating /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu
#     creating /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cuda
#     [1/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/assign_score_withk.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/assign_score_withk.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/assign_score_withk.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [2/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/bbox_overlaps.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/bbox_overlaps.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/bbox_overlaps.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [3/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/ball_query.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/ball_query.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/ball_query.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [4/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/active_rotated_filter.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/active_rotated_filter.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/active_rotated_filter.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [5/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/bezier_align.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/bezier_align.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/bezier_align.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [6/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/bias_act.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/bias_act.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/bias_act.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [7/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/box_iou_quadri.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/box_iou_quadri.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/box_iou_quadri.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [8/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/border_align.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/border_align.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/border_align.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [9/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/box_iou_rotated.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/box_iou_rotated.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/box_iou_rotated.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [10/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/carafe.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/carafe.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/carafe.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [11/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/carafe_naive.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/carafe_naive.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/carafe_naive.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [12/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/chamfer_distance.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/chamfer_distance.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/chamfer_distance.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [13/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/contour_expand.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/contour_expand.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/contour_expand.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [14/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/convex_iou.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/convex_iou.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/convex_iou.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [15/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/correlation.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/correlation.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/correlation.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [16/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/active_rotated_filter.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/active_rotated_filter.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/active_rotated_filter.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/active_rotated_filter.cpp:16: warning: ignoring ‘#pragma omp parallel’ [-Wunknown-pragmas]
#        16 | #pragma omp parallel for private(i, j, l, k)
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/active_rotated_filter.cpp:44: warning: ignoring ‘#pragma omp parallel’ [-Wunknown-pragmas]
#        44 | #pragma omp parallel for private(i, j, l, k)
#           |
#     [17/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/box_iou_quadri.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/box_iou_quadri.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/box_iou_quadri.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     In file included from /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/box_iou_quadri.cpp:2:
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/box_iou_rotated_utils.hpp:276: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       276 | #pragma unroll
#           |
#     [18/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/bbox_overlaps_cpu.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/bbox_overlaps_cpu.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/bbox_overlaps_cpu.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [19/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/box_iou_rotated.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/box_iou_rotated.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/box_iou_rotated.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     In file included from /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/box_iou_rotated.cpp:4:
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/box_iou_rotated_utils.hpp:276: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       276 | #pragma unroll
#           |
#     [20/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/bezier_align.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/bezier_align.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/bezier_align.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [21/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/deform_conv.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/deform_conv.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/deform_conv.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [22/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/nms.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/nms.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/nms.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [23/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/modulated_deform_conv.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/modulated_deform_conv.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/modulated_deform_conv.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [24/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/nms_quadri.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/nms_quadri.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/nms_quadri.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     In file included from /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/nms_quadri.cpp:2:
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/box_iou_rotated_utils.hpp:276: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       276 | #pragma unroll
#           |
#     [25/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/pixel_group.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/pixel_group.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/pixel_group.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [26/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/points_in_boxes.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/points_in_boxes.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/points_in_boxes.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [27/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/psamask.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/psamask.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/psamask.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [28/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/nms_rotated.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/nms_rotated.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/nms_rotated.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     In file included from /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/nms_rotated.cpp:4:
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/box_iou_rotated_utils.hpp:276: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       276 | #pragma unroll
#           |
#     [29/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/rotated_feature_align.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/rotated_feature_align.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/rotated_feature_align.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [30/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/roi_align.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/roi_align.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/roi_align.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [31/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/roi_align_rotated.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/roi_align_rotated.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/roi_align_rotated.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [32/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/sparse_indice.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/sparse_indice.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/cpu/sparse_indice.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     In file included from /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:18,
#                      from /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/sparse_indice.cpp:16:
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:387: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       387 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:412: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       412 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:436: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       436 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:447: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       447 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:885: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       885 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:895: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       895 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:901: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       901 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/tensorview/tensorview.h:907: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       907 | #pragma unroll
#           |
#     In file included from /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/sparse_indice.cpp:16:
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:38: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#        38 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:46: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#        46 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:52: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#        52 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:60: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#        60 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:75: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#        75 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:100: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       100 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:105: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       105 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:110: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       110 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:118: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       118 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:131: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       131 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:156: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       156 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:161: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       161 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:207: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       207 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:212: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       212 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:256: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       256 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h:261: warning: ignoring ‘#pragma unroll ’ [-Wunknown-pragmas]
#       261 | #pragma unroll
#           |
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/utils/spconv/spconv/geometry.h: In instantiation of ‘Index getIndicePairsDeConv(tv::TensorView<const scalar_t>, tv::TensorView<scalar_t>, tv::TensorView<IndexGrid>, tv::TensorView<scalar_t>, tv::TensorView<scalar_t>, const Index*, const Index*, const Index*, const Index*, const Index*) [with Index = int; IndexGrid = int; unsigned int NDim = 1]’:
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/sparse_indice.cpp:36:58:   required from ‘Index functor::CreateConvIndicePairFunctor<tv::CPU, Index, IndexGrid, NDim>::operator()(const tv::CPU&, tv::TensorView<const scalar_t>, tv::TensorView<scalar_t>, tv::TensorView<IndexGrid>, tv::TensorView<scalar_t>, tv::TensorView<scalar_t>, tv::SimpleVector<Index, NDim>, tv::SimpleVector<Index, NDim>, tv::SimpleVector<Index, NDim>, tv::SimpleVector<Index, NDim>, tv::SimpleVector<Index, NDim>, bool, bool) [with Index = int; IndexGrid = int; unsigned int NDim = 1]’
#     /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/cpu/sparse_indice.cpp:80:1:   required from here
# ...
#     [126/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/rotated_feature_align.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/rotated_feature_align.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/rotated_feature_align.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [127/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/scatter_points.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/scatter_points.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/scatter_points.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [128/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/sparse_pool_ops.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/sparse_pool_ops.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/sparse_pool_ops.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [129/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/spconv_ops.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/spconv_ops.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/spconv_ops.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [130/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/pybind.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/pybind.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/pybind.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [131/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/sync_bn.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/sync_bn.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/sync_bn.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [132/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/three_interpolate.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/three_interpolate.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/three_interpolate.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [133/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/three_nn.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/three_nn.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/three_nn.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [134/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/tin_shift.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/tin_shift.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/tin_shift.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [135/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/upfirdn2d.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/upfirdn2d.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/upfirdn2d.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     [136/136] c++ -MMD -MF /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/voxelization.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DMMCV_WITH_CUDA -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common -I/content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/common/cuda -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/SpacetimeGaussians/thirdparty/mmcv/mmcv/ops/csrc/pytorch/voxelization.cpp -o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/mmcv/ops/csrc/pytorch/voxelization.o -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext
#     creating build/lib.linux-x86_64-cpython-312/mmcv
#     x86_64-linux-gnu-g++ -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/active_rotated_filter.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/assign_score_withk.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/ball_query.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/bbox_overlaps.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/bezier_align.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/bias_act.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/border_align.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/box_iou_quadri.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/box_iou_rotated.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/carafe.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/carafe_naive.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/chamfer_distance.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/contour_expand.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/convex_iou.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/correlation.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/active_rotated_filter.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/bbox_overlaps_cpu.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/bezier_align.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/box_iou_quadri.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/box_iou_rotated.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/deform_conv.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/modulated_deform_conv.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/nms.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/nms_quadri.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/nms_rotated.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/pixel_group.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/points_in_boxes.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/psamask.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/roi_align.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/cpu/roi_align_rotated.o /content/SpacetimeGaussians/thirdparty/mmcv/build/temp.linux-x86_64-cpython-312/./mmcv/ops/csrc/pytorch/ ...
#     copying build/lib.linux-x86_64-cpython-312/mmcv/_ext.cpython-312-x86_64-linux-gnu.so -> mmcv
#     Creating /usr/local/lib/python3.12/dist-packages/mmcv.egg-link (link to .)
#     Adding mmcv 2.2.0 to easy-install.pth file
#
#     Installed /content/SpacetimeGaussians/thirdparty/mmcv
# Successfully installed addict-2.4.0 mmcv-2.2.0 mmengine-0.10.7 yapf-0.43.0

# %%
# !apt-get update
# !apt-get install -y colmap
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,290 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,595 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,482 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,532 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,876 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,222 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,832 kB]
# Fetched 31.4 MB in 4s (7,423 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libamd2 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libcamd2 libccolamd2 libceres2
#   libcholmod3 libcolamd2 libcxsparse3 libdouble-conversion3 libevdev2
#   libfreeimage3 libgflags2.2 libglew2.2 libgoogle-glog0v5 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libilmbase25 libinput-bin
#   libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1 libopenexr25 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libraw20
#   librsvg2-common libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common
#   libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcomposite1
#   libxkbcommon-x11-0 libxtst6 qt5-gtk-platformtheme qttranslations5-l10n
#   session-migration
# Suggested packages:
#   glew-utils gvfs qt5-image-formats-plugins qtwayland5
# The following NEW packages will be installed:
#   at-spi2-core colmap gsettings-desktop-schemas libamd2 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libcamd2 libccolamd2 libceres2
#   libcholmod3 libcolamd2 libcxsparse3 libdouble-conversion3 libevdev2
#   libfreeimage3 libgflags2.2 libglew2.2 libgoogle-glog0v5 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libilmbase25 libinput-bin
#   libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1 libopenexr25 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libraw20
#   librsvg2-common libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common
#   libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcomposite1
#   libxkbcommon-x11-0 libxtst6 qt5-gtk-platformtheme qttranslations5-l10n
#   session-migration
# 0 upgraded, 59 newly installed, 0 to remove and 50 not upgraded.
# Need to get 22.4 MB of archives.
# After this operation, 86.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdouble-conversion3 amd64 3.1.7-4 [39.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libamd2 amd64 1:5.10.1+dfsg-4build1 [21.6 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcamd2 amd64 1:5.10.1+dfsg-4build1 [23.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libccolamd2 amd64 1:5.10.1+dfsg-4build1 [25.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis5 amd64 5.1.0.dfsg-7build2 [181 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcholmod3 amd64 1:5.10.1+dfsg-4build1 [346 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcxsparse3 amd64 1:5.10.1+dfsg-4build1 [70.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags2.2 amd64 2.2.2-2 [78.1 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog0v5 amd64 0.5.0+really0.4.0-2 [60.3 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspqr2 amd64 1:5.10.1+dfsg-4build1 [71.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres2 amd64 2.0.0+dfsg1-5 [834 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraw20 amd64 0.20.2-2ubuntu2.22.04.2 [342 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libfreeimage3 amd64 3.18.0+ds2-6ubuntu5.1 [294 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew2.2 amd64 2.2.0-4 [196 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 colmap amd64 3.7-2 [2,998 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2.2 [69.6 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Fetched 22.4 MB in 6s (4,013 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libdouble-conversion3:amd64.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../00-libdouble-conversion3_3.1.7-4_amd64.deb ...
# Unpacking libdouble-conversion3:amd64 (3.1.7-4) ...
# Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../01-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../02-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../03-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../04-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../05-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../06-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../07-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../08-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../09-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../10-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../11-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../12-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../13-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../14-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../15-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../16-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../17-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../18-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../19-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../20-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../21-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../22-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../23-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../24-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../25-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../26-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../27-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../28-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../29-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../30-libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../31-libcamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../32-libccolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../33-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../34-libmetis5_5.1.0.dfsg-7build2_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../35-libcholmod3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../36-libcxsparse3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../37-libgflags2.2_2.2.2-2_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-2) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../38-libgoogle-glog0v5_0.5.0+really0.4.0-2_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../39-libspqr2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libceres2.
# Preparing to unpack .../40-libceres2_2.0.0+dfsg1-5_amd64.deb ...
# Unpacking libceres2 (2.0.0+dfsg1-5) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../41-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../42-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../43-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libraw20:amd64.
# Preparing to unpack .../44-libraw20_0.20.2-2ubuntu2.22.04.2_amd64.deb ...
# Unpacking libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Selecting previously unselected package libfreeimage3:amd64.
# Preparing to unpack .../45-libfreeimage3_3.18.0+ds2-6ubuntu5.1_amd64.deb ...
# Unpacking libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Selecting previously unselected package libglew2.2:amd64.
# Preparing to unpack .../46-libglew2.2_2.2.0-4_amd64.deb ...
# Unpacking libglew2.2:amd64 (2.2.0-4) ...
# Selecting previously unselected package colmap.
# Preparing to unpack .../47-colmap_3.7-2_amd64.deb ...
# Unpacking colmap (3.7-2) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../48-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../49-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../50-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../51-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../52-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../53-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../54-libgtk-3-bin_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../55-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../56-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../57-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../58-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libdouble-conversion3:amd64 (3.1.7-4) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Setting up libglew2.2:amd64 (2.2.0-4) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libgflags2.2 (2.2.2-2) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Setting up libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libceres2 (2.0.0+dfsg1-5) ...
# Setting up colmap (3.7-2) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.6) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

SOURCE_PATH='/content/drive/MyDrive/your_folder/coffee_martini'
DEST_PATH='/content/SpacetimeGaussians/source'

shutil.copytree(SOURCE_PATH, DEST_PATH, dirs_exist_ok=True)
# Out:
# '/content/SpacetimeGaussians/source'

# %%
# !pip install opencv-python-headless pycolmap numpy matplotlib
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Collecting pycolmap
#   Downloading pycolmap-3.13.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading pycolmap-3.13.0-cp312-cp312-manylinux_2_28_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 81.8 MB/s eta 0:00:00
# Installing collected packages: pycolmap
# Successfully installed pycolmap-3.13.0

# %%
# !sed -i 's/np\.NaN/np.nan/g' /content/SpacetimeGaussians/thirdparty/colmap/pre_colmap.py

# %%
# !apt-get update && apt-get install -y xvfb
# !xvfb-run -a python script/pre_n3d.py --videopath source
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3642
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3798
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3878
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        3868
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4475
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        5037
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5544
# Elapsed time: 0.530 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1] in 350.386s
# Elapsed time: 5.841 [minutes]
#
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 18 in 0.000s
# Loading matches... 149 in 0.001s
# Loading images... 18 in 0.008s (connected 18)
# Building correspondence graph... in 0.010s (ignored 0)
#
# Elapsed time: 0.000 [minutes]
#
#
# ==============================================================================
# Triangulating image #1 (0)
# ==============================================================================
#
#   => Image sees 0 / 1905 points
#   => Triangulated 1375 points
#
# ==============================================================================
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 150 / 1475 points
#   => Triangulated 704 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 757 / 1748 points
#   => Triangulated 284 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1066 / 2069 points
#   => Triangulated 479 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1364 / 2223 points
#   => Triangulated 247 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 913 / 1829 points
#   => Triangulated 331 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 847 / 1932 points
#   => Triangulated 345 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 780 / 1915 points
#   => Triangulated 272 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 637 / 1937 points
#   => Triangulated 229 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 513 / 1492 points
#   => Triangulated 184 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 679 / 1525 points
#   => Triangulated 330 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 627 / 1309 points
#   => Triangulated 149 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 892 / 1572 points
#   => Triangulated 268 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1099 / 1832 points
#   => Triangulated 235 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 693 / 1394 points
#   => Triangulated 236 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 619 / 1522 points
#   => Triangulated 209 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 605 / 1718 points
#   => Triangulated 150 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 439 / 1570 points
#   => Triangulated 199 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 2
#   => Merged observations: 3099
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.551524e+05    0.00e+00    1.18e+04   0.00e+00   0.00e+00  1.00e+04        0    1.13e-02    2.30e-02
#    1  1.090478e+05    4.61e+04    3.06e+03   6.05e+01   9.70e-01  3.00e+04        0    1.99e-02    4.29e-02
#    2  1.076356e+05    1.41e+03    3.15e+02   2.00e+01   9.84e-01  9.00e+04        0    1.53e-02    5.82e-02
#    3  1.076153e+05    2.03e+01    4.57e+00   4.16e+00   9.97e-01  2.70e+05        0    1.43e-02    7.25e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 37890
#    Parameters : 12177
#    Iterations : 4
#          Time : 0.0776432 [s]
#  Initial cost : 2.02356 [px]
#    Final cost : 1.68529 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 254
#   => Filtered observations: 1230
#   => Changed observations: 0.078332
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.867433e+04    0.00e+00    2.47e+03   0.00e+00   0.00e+00  1.00e+04        0    1.06e-02    2.02e-02
#    1  1.625945e+04    2.41e+03    1.77e+01   5.85e+00   1.00e+00  3.00e+04        0    1.40e-02    3.42e-02
#    2  1.625907e+04    3.81e-01    1.20e-01   6.12e-01   1.00e+00  9.00e+04        0    1.33e-02    4.76e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35420
#    Parameters : 11529
#    Iterations : 3
#          Time : 0.0482452 [s]
#  Initial cost : 0.726103 [px]
#    Final cost : 0.677522 [px]
#   Termination : Convergence
#
#   => Completed observations: 250
#   => Merged observations: 431
#   => Filtered observations: 20
#   => Changed observations: 0.039582
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.687445e+04    0.00e+00    1.48e+03   0.00e+00   0.00e+00  1.00e+04        0    1.06e-02    2.03e-02
#    1  1.650008e+04    3.74e+02    4.64e+00   2.75e+00   1.00e+00  3.00e+04        0    1.59e-02    3.63e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35880
#    Parameters : 11397
#    Iterations : 2
#          Time : 0.0416441 [s]
#  Initial cost : 0.685786 [px]
#    Final cost : 0.678136 [px]
#   Termination : Convergence
#
#   => Completed observations: 13
#   => Merged observations: 42
#   => Filtered observations: 8
#   => Changed observations: 0.003512
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.653991e+04    0.00e+00    9.27e+02   0.00e+00   0.00e+00  1.00e+04        0    1.65e-02    3.35e-02
#    1  1.648327e+04    5.66e+01    3.37e+00   1.60e+00   1.00e+00  3.00e+04        0    2.24e-02    5.59e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35890
#    Parameters : 11385
#    Iterations : 2
#          Time : 0.0637388 [s]
#  Initial cost : 0.678859 [px]
#    Final cost : 0.677696 [px]
#   Termination : Convergence
#
#   => Completed observations: 6
#   => Merged observations: 0
#   => Filtered observations: 2
#   => Changed observations: 0.000446
#
# ==============================================================================
# Extracting colors
# ==============================================================================
#
# colmap point_triangulator --database_path source/colmap_22/input.db --image_path source/colmap_22/input --output_path source/colmap_22/distorted/sparse --input_path source/colmap_22/manual --Mapper.ba_global_function_tolerance=0.000001
#
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 18 images and 3795 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorted image found; copying to location: source/colmap_22/images/cam13.png
# Undistorting image [1/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam12.png
# Undistorting image [2/18]
# Undistorting image [3/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam11.png
# Undistorted image found; copying to location: source/colmap_22/images/cam10.png
# Undistorted image found; copying to location: source/colmap_22/images/cam09.png
# Undistorting image [4/18]
# Undistorting image [5/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam08.png
# Undistorting image [6/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam07.png
# Undistorted image found; copying to location: source/colmap_22/images/cam06.png
# Undistorting image [7/18]
# Undistorting image [8/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam05.png
# Undistorting image [9/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam04.png
# Undistorted image found; copying to location: source/colmap_22/images/cam01.pngUndistorting image [10/18]
#
# Undistorting image [11/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam02.png
# Undistorting image [12/18]
# Undistorting image [13/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam14.png
# Undistorted image found; copying to location: source/colmap_22/images/cam00.png
# Undistorted image found; copying to location: source/colmap_22/images/cam16.png
# Undistorting image [14/18]
# Undistorting image [15/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam18.png
# Undistorting image [16/18]
# Undistorted image found; copying to location: source/colmap_22/images/cam19.png
# Undistorted image found; copying to location: source/colmap_22/images/cam20.png
# Undistorting image [17/18]
# Undistorting image [18/18]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.007 [minutes]
# colmap image_undistorter --image_path source/colmap_22/input --input_path source/colmap_22/distorted/sparse --output_path source/colmap_22 --output_type COLMAP
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/18]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4195
# Processed file [2/18]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.097, LON=1.144, ALT=2.128
#   Features:        4075
# Processed file [3/18]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
#   Camera:          #3 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-4.342, LON=1.139, ALT=1.682
#   Features:        4157
# Processed file [4/18]
#   Name:            cam04.png
#   Dimensions:      2704 x 2028
#   Camera:          #4 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.518, LON=1.035, ALT=0.979
#   Features:        4192
# Processed file [5/18]
#   Name:            cam05.png
#   Dimensions:      2704 x 2028
#   Camera:          #5 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.508, LON=1.082, ALT=0.534
#   Features:        4112
# Processed file [6/18]
#   Name:            cam06.png
#   Dimensions:      2704 x 2028
#   Camera:          #6 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.552, LON=1.128, ALT=0.368
#   Features:        4543
# Processed file [7/18]
#   Name:            cam07.png
#   Dimensions:      2704 x 2028
#   Camera:          #7 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=1.537, LON=1.137, ALT=0.711
#   Features:        4779
# Processed file [8/18]
#   Name:            cam08.png
#   Dimensions:      2704 x 2028
#   Camera:          #8 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.475, LON=1.116, ALT=1.272
#   Features:        5455
# Processed file [9/18]
#   Name:            cam09.png
#   Dimensions:      2704 x 2028
#   Camera:          #9 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=3.498, LON=1.143, ALT=1.151
#   Features:        6240
# Processed file [10/18]
#   Name:            cam10.png
#   Dimensions:      2704 x 2028
#   Camera:          #10 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.301, LON=1.195, ALT=1.406
#   Features:        6008
# Processed file [11/18]
#   Name:            cam11.png
#   Dimensions:      2704 x 2028
#   Camera:          #11 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-6.146, LON=-1.749, ALT=0.872
#   Features:        4035
# Processed file [12/18]
#   Name:            cam12.png
#   Dimensions:      2704 x 2028
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3625
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3735
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3844
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        3874
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4433
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        5032
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5557
# Elapsed time: 0.526 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1] in 341.296s
# Elapsed time: 5.690 [minutes]
#
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 18 in 0.000s
# Loading matches... 149 in 0.002s
# Loading images... 18 in 0.011s (connected 18)
# Building correspondence graph... in 0.017s (ignored 0)
#
# Elapsed time: 0.001 [minutes]
#
#
# ==============================================================================
# Triangulating image #1 (0)
# ==============================================================================
#
#   => Image sees 0 / 1889 points
#   => Triangulated 1392 points
#
# ==============================================================================
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 157 / 1482 points
#   => Triangulated 690 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 759 / 1744 points
#   => Triangulated 283 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1081 / 2078 points
#   => Triangulated 446 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1333 / 2202 points
#   => Triangulated 212 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 904 / 1821 points
#   => Triangulated 299 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 820 / 1918 points
#   => Triangulated 348 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 762 / 1963 points
#   => Triangulated 259 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 676 / 1952 points
#   => Triangulated 208 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 502 / 1510 points
#   => Triangulated 196 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 675 / 1576 points
#   => Triangulated 344 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 628 / 1343 points
#   => Triangulated 151 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 868 / 1583 points
#   => Triangulated 291 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1091 / 1807 points
#   => Triangulated 219 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 732 / 1361 points
#   => Triangulated 215 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 610 / 1497 points
#   => Triangulated 220 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 620 / 1743 points
#   => Triangulated 158 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 458 / 1560 points
#   => Triangulated 193 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 2
#   => Merged observations: 3300
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.907309e+05    0.00e+00    1.20e+04   0.00e+00   0.00e+00  1.00e+04        0    1.51e-02    3.05e-02
#    1  1.374454e+05    5.33e+04    3.10e+03   6.51e+01   9.76e-01  3.00e+04        0    2.72e-02    5.78e-02
#    2  1.361231e+05    1.32e+03    3.13e+02   1.94e+01   9.89e-01  9.00e+04        0    2.26e-02    8.05e-02
#    3  1.361116e+05    1.15e+01    4.29e+00   3.14e+00   9.96e-01  2.70e+05        0    2.34e-02    1.04e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 37686
#    Parameters : 11949
#    Iterations : 4
#          Time : 0.111609 [s]
#  Initial cost : 2.24968 [px]
#    Final cost : 1.90045 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 311
#   => Filtered observations: 1259
#   => Changed observations: 0.083320
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.845382e+04    0.00e+00    2.74e+03   0.00e+00   0.00e+00  1.00e+04        0    1.41e-02    2.75e-02
#    1  1.591588e+04    2.54e+03    2.25e+01   8.74e+00   1.00e+00  3.00e+04        0    2.01e-02    4.76e-02
#    2  1.591523e+04    6.48e-01    1.51e-01   1.00e+00   9.99e-01  9.00e+04        0    1.89e-02    6.65e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35152
#    Parameters : 11229
#    Iterations : 3
#          Time : 0.0672572 [s]
#  Initial cost : 0.72455 [px]
#    Final cost : 0.67287 [px]
#   Termination : Convergence
#
#   => Completed observations: 250
#   => Merged observations: 417
#   => Filtered observations: 13
#   => Changed observations: 0.038689
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.662893e+04    0.00e+00    1.40e+03   0.00e+00   0.00e+00  1.00e+04        0    1.40e-02    2.72e-02
#    1  1.624900e+04    3.80e+02    5.38e+00   1.47e+00   1.00e+00  3.00e+04        0    1.97e-02    4.69e-02
#    2  1.624898e+04    1.77e-02    5.65e-03   2.79e-01   1.00e+00  9.00e+04        0    1.90e-02    6.60e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35626
#    Parameters : 11100
#    Iterations : 3
#          Time : 0.0667219 [s]
#  Initial cost : 0.683201 [px]
#    Final cost : 0.675351 [px]
#   Termination : Convergence
#
#   => Completed observations: 9
#   => Merged observations: 28
#   => Filtered observations: 8
#   => Changed observations: 0.002526
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.624476e+04    0.00e+00    1.06e+03   0.00e+00   0.00e+00  1.00e+04        0    1.39e-02    2.72e-02
#    1  1.618428e+04    6.05e+01    3.99e+00   2.61e-01   1.00e+00  3.00e+04        0    2.03e-02    4.76e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35626
#    Parameters : 11088
#    Iterations : 2
#          Time : 0.0549819 [s]
#  Initial cost : 0.675263 [px]
#    Final cost : 0.674005 [px]
#   Termination : Convergence
#
#   => Completed observations: 2
#   => Merged observations: 0
#   => Filtered observations: 1
#   => Changed observations: 0.000168
#
# ==============================================================================
# Extracting colors
# ==============================================================================
#
# colmap point_triangulator --database_path source/colmap_23/input.db --image_path source/colmap_23/input --output_path source/colmap_23/distorted/sparse --input_path source/colmap_23/manual --Mapper.ba_global_function_tolerance=0.000001
#
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 18 images and 3696 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorting image [1/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam13.png
# Undistorted image found; copying to location: source/colmap_23/images/cam12.png
# Undistorting image [2/18]
# Undistorting image [3/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam11.png
# Undistorted image found; copying to location: source/colmap_23/images/cam10.png
# Undistorting image [4/18]
# Undistorting image [5/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam08.png
# Undistorted image found; copying to location: source/colmap_23/images/cam09.png
# Undistorted image found; copying to location: source/colmap_23/images/cam07.png
# Undistorting image [6/18]
# Undistorting image [7/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam06.png
# Undistorting image [8/18]
# Undistorting image [9/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam04.png
# Undistorted image found; copying to location: source/colmap_23/images/cam05.png
# Undistorting image [10/18]
# Undistorting image [11/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam01.png
# Undistorted image found; copying to location: source/colmap_23/images/cam02.png
# Undistorted image found; copying to location: source/colmap_23/images/cam14.png
# Undistorted image found; copying to location: source/colmap_23/images/cam00.png
# Undistorting image [12/18]
# Undistorting image [13/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam16.png
# Undistorted image found; copying to location: source/colmap_23/images/cam18.png
# Undistorting image [14/18]
# Undistorting image [15/18]
# Undistorting image [16/18]
# Undistorting image [17/18]
# Undistorted image found; copying to location: source/colmap_23/images/cam19.png
# Undistorted image found; copying to location: source/colmap_23/images/cam20.png
# Undistorting image [18/18]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.006 [minutes]
# colmap image_undistorter --image_path source/colmap_23/input --input_path source/colmap_23/distorted/sparse --output_path source/colmap_23 --output_type COLMAP
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/18]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4249
# Processed file [2/18]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.097, LON=1.144, ALT=2.128
#   Features:        4119
# Processed file [3/18]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
#   Camera:          #3 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-4.342, LON=1.139, ALT=1.682
#   Features:        4260
# Processed file [4/18]
#   Name:            cam04.png
#   Dimensions:      2704 x 2028
#   Camera:          #4 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.518, LON=1.035, ALT=0.979
#   Features:        4241
# Processed file [5/18]
#   Name:            cam05.png
#   Dimensions:      2704 x 2028
#   Camera:          #5 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.508, LON=1.082, ALT=0.534
#   Features:        4249
# Processed file [6/18]
#   Name:            cam06.png
#   Dimensions:      2704 x 2028
#   Camera:          #6 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.552, LON=1.128, ALT=0.368
#   Features:        4720
# Processed file [7/18]
#   Name:            cam07.png
#   Dimensions:      2704 x 2028
#   Camera:          #7 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=1.537, LON=1.137, ALT=0.711
#   Features:        4948
# Processed file [8/18]
#   Name:            cam08.png
#   Dimensions:      2704 x 2028
#   Camera:          #8 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.475, LON=1.116, ALT=1.272
#   Features:        5498
# Processed file [9/18]
#   Name:            cam09.png
#   Dimensions:      2704 x 2028
#   Camera:          #9 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=3.498, LON=1.143, ALT=1.151
#   Features:        6287
# Processed file [10/18]
#   Name:            cam10.png
#   Dimensions:      2704 x 2028
#   Camera:          #10 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.301, LON=1.195, ALT=1.406
#   Features:        6049
# Processed file [11/18]
#   Name:            cam11.png
#   Dimensions:      2704 x 2028
#   Camera:          #11 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-6.146, LON=-1.749, ALT=0.872
#   Features:        4181
# Processed file [12/18]
#   Name:            cam12.png
#   Dimensions:      2704 x 2028
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3754
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3802
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3884
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        3949
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4605
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        5108
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5694
# Elapsed time: 0.526 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1] in 354.059s
# Elapsed time: 5.903 [minutes]
#
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 18 in 0.001s
# Loading matches... 151 in 0.002s
# Loading images... 18 in 0.013s (connected 18)
# Building correspondence graph... in 0.019s (ignored 0)
#
# Elapsed time: 0.001 [minutes]
#
#
# ==============================================================================
# Triangulating image #1 (0)
# ==============================================================================
#
#   => Image sees 0 / 1866 points
#   => Triangulated 1359 points
#
# ==============================================================================
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 145 / 1455 points
#   => Triangulated 708 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 753 / 1746 points
#   => Triangulated 329 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1083 / 2048 points
#   => Triangulated 466 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1389 / 2209 points
#   => Triangulated 224 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 896 / 1820 points
#   => Triangulated 311 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 787 / 1872 points
#   => Triangulated 358 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 734 / 1895 points
#   => Triangulated 282 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 654 / 1952 points
#   => Triangulated 221 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 481 / 1506 points
#   => Triangulated 195 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 691 / 1561 points
#   => Triangulated 332 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 615 / 1326 points
#   => Triangulated 153 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 876 / 1591 points
#   => Triangulated 283 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1084 / 1810 points
#   => Triangulated 212 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 730 / 1322 points
#   => Triangulated 198 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 615 / 1506 points
#   => Triangulated 190 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 599 / 1656 points
#   => Triangulated 150 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 426 / 1530 points
#   => Triangulated 195 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 4
#   => Merged observations: 3042
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.984314e+05    0.00e+00    1.20e+04   0.00e+00   0.00e+00  1.00e+04        0    1.05e-02    2.18e-02
#    1  1.441492e+05    5.43e+04    7.44e+02   5.89e+01   9.94e-01  3.00e+04        0    1.42e-02    3.60e-02
#    2  1.437869e+05    3.62e+02    2.19e+01   1.96e+01   9.98e-01  9.00e+04        0    1.33e-02    4.94e-02
#    3  1.437859e+05    9.69e-01    3.15e-01   3.64e+00   9.99e-01  2.70e+05        0    1.32e-02    6.26e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 37518
#    Parameters : 11985
#    Iterations : 4
#          Time : 0.063271 [s]
#  Initial cost : 2.29977 [px]
#    Final cost : 1.95766 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 384
#   => Filtered observations: 1300
#   => Changed observations: 0.089770
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.857361e+04    0.00e+00    2.36e+03   0.00e+00   0.00e+00  1.00e+04        0    9.58e-03    1.87e-02
#    1  1.608509e+04    2.49e+03    2.27e+01   5.67e+00   1.00e+00  3.00e+04        0    1.43e-02    3.31e-02
#    2  1.608452e+04    5.70e-01    1.27e-01   5.55e-01   1.00e+00  9.00e+04        0    1.53e-02    4.84e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 34910
#    Parameters : 11244
#    Iterations : 3
#          Time : 0.0491161 [s]
#  Initial cost : 0.729413 [px]
#    Final cost : 0.67878 [px]
#   Termination : Convergence
#
#   => Completed observations: 222
#   => Merged observations: 423
#   => Filtered observations: 19
#   => Changed observations: 0.038041
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.672689e+04    0.00e+00    2.49e+03   0.00e+00   0.00e+00  1.00e+04        0    9.31e-03    1.87e-02
#    1  1.629928e+04    4.28e+02    5.76e+00   7.18e-01   1.00e+00  3.00e+04        0    1.30e-02    3.18e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35316
#    Parameters : 11115
#    Iterations : 2
#          Time : 0.0364149 [s]
#  Initial cost : 0.688211 [px]
#    Final cost : 0.679358 [px]
#   Termination : Convergence
#
#   => Completed observations: 13
#   => Merged observations: 35
#   => Filtered observations: 4
#   => Changed observations: 0.002945
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.635269e+04    0.00e+00    1.41e+03   0.00e+00   0.00e+00  1.00e+04        0    9.18e-03    1.83e-02
#    1  1.630568e+04    4.70e+01    1.84e+00   1.95e-01   1.00e+00  3.00e+04        0    1.31e-02    3.15e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35334
#    Parameters : 11100
#    Iterations : 2
#          Time : 0.0376101 [s]
#  Initial cost : 0.680297 [px]
#    Final cost : 0.679318 [px]
#   Termination : Convergence
#
#   => Completed observations: 2
#   => Merged observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000113
#
# ==============================================================================
# Extracting colors
# ==============================================================================
#
# colmap point_triangulator --database_path source/colmap_24/input.db --image_path source/colmap_24/input --output_path source/colmap_24/distorted/sparse --input_path source/colmap_24/manual --Mapper.ba_global_function_tolerance=0.000001
#
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 18 images and 3700 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorting image [1/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam13.png
# Undistorted image found; copying to location: source/colmap_24/images/cam12.png
# Undistorting image [2/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam11.png
# Undistorted image found; copying to location: source/colmap_24/images/cam10.png
# Undistorting image [3/18]
# Undistorting image [4/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam09.png
# Undistorted image found; copying to location: source/colmap_24/images/cam08.png
# Undistorting image [5/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam06.png
# Undistorted image found; copying to location: source/colmap_24/images/cam07.png
# Undistorting image [6/18]
# Undistorting image [7/18]
# Undistorting image [8/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam05.png
# Undistorting image [9/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam04.png
# Undistorting image [10/18]
# Undistorting image [11/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam01.png
# Undistorted image found; copying to location: source/colmap_24/images/cam02.png
# Undistorting image [12/18]
# Undistorting image [13/18]
# Undistorted image found; copying to location: source/colmap_24/images/cam14.png
# Undistorted image found; copying to location: source/colmap_24/images/cam00.png
# Undistorted image found; copying to location: source/colmap_24/images/cam16.png
# Undistorted image found; copying to location: source/colmap_24/images/cam18.png
# Undistorting image [14/18]
# Undistorting image [15/18]
# Undistorting image [16/18]
# Undistorted image found; copying to location: Undistorting image [17/18]source/colmap_24/images/cam19.png
#
# Undistorted image found; copying to location: source/colmap_24/images/cam20.png
# Undistorting image [18/18]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.006 [minutes]
# colmap image_undistorter --image_path source/colmap_24/input --input_path source/colmap_24/distorted/sparse --output_path source/colmap_24 --output_type COLMAP
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/18]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4141
# Processed file [2/18]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
# ...
# Triangulating image #2 (1)
# ==============================================================================
#
#   => Image sees 146 / 1474 points
#   => Triangulated 687 points
#
# ==============================================================================
# Triangulating image #3 (2)
# ==============================================================================
#
#   => Image sees 713 / 1714 points
#   => Triangulated 325 points
#
# ==============================================================================
# Triangulating image #4 (3)
# ==============================================================================
#
#   => Image sees 1053 / 2091 points
#   => Triangulated 478 points
#
# ==============================================================================
# Triangulating image #5 (4)
# ==============================================================================
#
#   => Image sees 1383 / 2276 points
#   => Triangulated 220 points
#
# ==============================================================================
# Triangulating image #6 (5)
# ==============================================================================
#
#   => Image sees 895 / 1832 points
#   => Triangulated 311 points
#
# ==============================================================================
# Triangulating image #7 (6)
# ==============================================================================
#
#   => Image sees 812 / 1945 points
#   => Triangulated 372 points
#
# ==============================================================================
# Triangulating image #8 (7)
# ==============================================================================
#
#   => Image sees 761 / 1982 points
#   => Triangulated 297 points
#
# ==============================================================================
# Triangulating image #9 (8)
# ==============================================================================
#
#   => Image sees 658 / 1946 points
#   => Triangulated 215 points
#
# ==============================================================================
# Triangulating image #10 (9)
# ==============================================================================
#
#   => Image sees 492 / 1525 points
#   => Triangulated 218 points
#
# ==============================================================================
# Triangulating image #11 (10)
# ==============================================================================
#
#   => Image sees 687 / 1578 points
#   => Triangulated 318 points
#
# ==============================================================================
# Triangulating image #12 (11)
# ==============================================================================
#
#   => Image sees 623 / 1334 points
#   => Triangulated 164 points
#
# ==============================================================================
# Triangulating image #13 (12)
# ==============================================================================
#
#   => Image sees 916 / 1613 points
#   => Triangulated 280 points
#
# ==============================================================================
# Triangulating image #14 (13)
# ==============================================================================
#
#   => Image sees 1106 / 1819 points
#   => Triangulated 227 points
#
# ==============================================================================
# Triangulating image #15 (14)
# ==============================================================================
#
#   => Image sees 723 / 1374 points
#   => Triangulated 237 points
#
# ==============================================================================
# Triangulating image #16 (15)
# ==============================================================================
#
#   => Image sees 610 / 1536 points
#   => Triangulated 211 points
#
# ==============================================================================
# Triangulating image #17 (16)
# ==============================================================================
#
#   => Image sees 608 / 1718 points
#   => Triangulated 155 points
#
# ==============================================================================
# Triangulating image #18 (17)
# ==============================================================================
#
#   => Image sees 424 / 1551 points
#   => Triangulated 209 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 5
#   => Merged observations: 3125
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.478268e+05    0.00e+00    1.26e+04   0.00e+00   0.00e+00  1.00e+04        0    1.63e-02    2.85e-02
#    1  1.205745e+05    2.73e+04    1.34e+04   1.13e+02   6.76e-01  1.05e+04        0    1.40e-02    4.26e-02
#    2  1.088648e+05    1.17e+04    3.04e+03   3.30e+01   8.95e-01  2.06e+04        0    1.31e-02    5.57e-02
#    3  1.075660e+05    1.30e+03    4.99e+02   1.72e+01   9.57e-01  6.17e+04        0    1.52e-02    7.10e-02
#    4  1.075100e+05    5.60e+01    2.89e+01   5.06e+00   9.94e-01  1.85e+05        0    1.45e-02    8.54e-02
#    5  1.075098e+05    2.23e-01    6.60e-02   3.81e-01   9.98e-01  5.56e+05        0    1.32e-02    9.86e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 37792
#    Parameters : 12030
#    Iterations : 6
#          Time : 0.0994091 [s]
#  Initial cost : 1.97777 [px]
#    Final cost : 1.68665 [px]
#   Termination : Convergence
#
#   => Completed observations: 1
#   => Merged observations: 347
#   => Filtered observations: 1230
#   => Changed observations: 0.083510
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.861067e+04    0.00e+00    1.67e+03   0.00e+00   0.00e+00  1.00e+04        0    1.03e-02    2.05e-02
#    1  1.652687e+04    2.08e+03    2.08e+01   7.04e+00   1.00e+00  3.00e+04        0    1.43e-02    3.49e-02
#    2  1.652646e+04    4.11e-01    1.52e-01   6.54e-01   1.00e+00  9.00e+04        0    1.33e-02    4.82e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35318
#    Parameters : 11322
#    Iterations : 3
#          Time : 0.0488541 [s]
#  Initial cost : 0.72591 [px]
#    Final cost : 0.684056 [px]
#   Termination : Convergence
#
#   => Completed observations: 156
#   => Merged observations: 443
#   => Filtered observations: 16
#   => Changed observations: 0.034826
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.713602e+04    0.00e+00    1.61e+03   0.00e+00   0.00e+00  1.00e+04        0    1.05e-02    2.07e-02
#    1  1.677922e+04    3.57e+02    6.00e+00   1.58e+00   1.00e+00  3.00e+04        0    1.47e-02    3.55e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35598
#    Parameters : 11181
#    Iterations : 2
#          Time : 0.0405011 [s]
#  Initial cost : 0.693813 [px]
#    Final cost : 0.686551 [px]
#   Termination : Convergence
#
#   => Completed observations: 5
#   => Merged observations: 12
#   => Filtered observations: 10
#   => Changed observations: 0.001517
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.670558e+04    0.00e+00    5.92e+02   0.00e+00   0.00e+00  1.00e+04        0    9.00e-03    2.01e-02
#    1  1.666953e+04    3.60e+01    4.18e+00   2.58e-01   1.00e+00  3.00e+04        0    1.32e-02    3.33e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 35588
#    Parameters : 11178
#    Iterations : 2
#          Time : 0.0415552 [s]
#  Initial cost : 0.685139 [px]
#    Final cost : 0.6844 [px]
#   Termination : Convergence
#
#   => Completed observations: 0
#   => Merged observations: 0
#   => Filtered observations: 1
#   => Changed observations: 0.000056
#
# ==============================================================================
# Extracting colors
# ==============================================================================
#
# colmap point_triangulator --database_path source/colmap_32/input.db --image_path source/colmap_32/input --output_path source/colmap_32/distorted/sparse --input_path source/colmap_32/manual --Mapper.ba_global_function_tolerance=0.000001
#
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 18 images and 3726 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorting image [1/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam13.png
# Undistorted image found; copying to location: source/colmap_32/images/cam12.png
# Undistorting image [2/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam11.png
# Undistorting image [3/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam10.png
# Undistorting image [4/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam09.png
# Undistorting image [5/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam08.png
# Undistorting image [6/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam07.png
# Undistorted image found; copying to location: source/colmap_32/images/cam06.png
# Undistorting image [7/18]
# Undistorting image [8/18]
# Undistorting image [9/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam04.png
# Undistorted image found; copying to location: source/colmap_32/images/cam05.png
# Undistorted image found; copying to location: source/colmap_32/images/cam02.png
# Undistorting image [10/18]
# Undistorting image [11/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam01.png
# Undistorting image [12/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam00.png
# Undistorted image found; copying to location: source/colmap_32/images/cam14.png
# Undistorting image [13/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam16.png
# Undistorting image [14/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam18.png
# Undistorting image [15/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam19.png
# Undistorting image [16/18]
# Undistorting image [17/18]
# Undistorted image found; copying to location: source/colmap_32/images/cam20.png
# Undistorting image [18/18]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.007 [minutes]
# colmap image_undistorter --image_path source/colmap_32/input --input_path source/colmap_32/distorted/sparse --output_path source/colmap_32 --output_type COLMAP
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/18]
#   Name:            cam00.png
#   Dimensions:      2704 x 2028
#   Camera:          #1 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-0.455, LON=1.111, ALT=0.309
#   Features:        4270
# Processed file [2/18]
#   Name:            cam01.png
#   Dimensions:      2704 x 2028
#   Camera:          #2 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.097, LON=1.144, ALT=2.128
#   Features:        4045
# Processed file [3/18]
#   Name:            cam02.png
#   Dimensions:      2704 x 2028
#   Camera:          #3 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-4.342, LON=1.139, ALT=1.682
#   Features:        4097
# Processed file [4/18]
#   Name:            cam04.png
#   Dimensions:      2704 x 2028
#   Camera:          #4 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.518, LON=1.035, ALT=0.979
#   Features:        4126
# Processed file [5/18]
#   Name:            cam05.png
#   Dimensions:      2704 x 2028
#   Camera:          #5 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.508, LON=1.082, ALT=0.534
#   Features:        4144
# Processed file [6/18]
#   Name:            cam06.png
#   Dimensions:      2704 x 2028
#   Camera:          #6 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.552, LON=1.128, ALT=0.368
#   Features:        4543
# Processed file [7/18]
#   Name:            cam07.png
#   Dimensions:      2704 x 2028
#   Camera:          #7 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=1.537, LON=1.137, ALT=0.711
#   Features:        4805
# Processed file [8/18]
#   Name:            cam08.png
#   Dimensions:      2704 x 2028
#   Camera:          #8 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.475, LON=1.116, ALT=1.272
#   Features:        5426
# Processed file [9/18]
#   Name:            cam09.png
#   Dimensions:      2704 x 2028
#   Camera:          #9 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=3.498, LON=1.143, ALT=1.151
#   Features:        6221
# Processed file [10/18]
#   Name:            cam10.png
#   Dimensions:      2704 x 2028
#   Camera:          #10 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.301, LON=1.195, ALT=1.406
#   Features:        6010
# Processed file [11/18]
#   Name:            cam11.png
#   Dimensions:      2704 x 2028
#   Camera:          #11 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-6.146, LON=-1.749, ALT=0.872
#   Features:        4060
# Processed file [12/18]
#   Name:            cam12.png
#   Dimensions:      2704 x 2028
#   Camera:          #12 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-5.157, LON=-1.907, ALT=0.131
#   Features:        3733
# Processed file [13/18]
#   Name:            cam13.png
#   Dimensions:      2704 x 2028
#   Camera:          #13 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-2.964, LON=-1.860, ALT=1.299
#   Features:        3730
# Processed file [14/18]
#   Name:            cam14.png
#   Dimensions:      2704 x 2028
#   Camera:          #14 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=-1.876, LON=-1.690, ALT=0.836
#   Features:        3768
# Processed file [15/18]
#   Name:            cam16.png
#   Dimensions:      2704 x 2028
#   Camera:          #15 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=0.156, LON=-1.639, ALT=0.403
#   Features:        3842
# Processed file [16/18]
#   Name:            cam18.png
#   Dimensions:      2704 x 2028
#   Camera:          #16 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=2.294, LON=-1.462, ALT=1.089
#   Features:        4442
# Processed file [17/18]
#   Name:            cam19.png
#   Dimensions:      2704 x 2028
#   Camera:          #17 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=4.313, LON=-1.395, ALT=0.885
#   Features:        5004
# Processed file [18/18]
#   Name:            cam20.png
#   Dimensions:      2704 x 2028
#   Camera:          #18 - PINHOLE
#   Focal Length:    1460.75px
#   GPS:             LAT=5.229, LON=-1.175, ALT=1.379
#   Features:        5606
# Elapsed time: 0.552 [minutes]
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
#
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/1, 1/1]
